# %% [markdown]
# #Version 1.0 (Python 2 & 3)
# Ajouter les styles et les acteurs correspondant aux intervenants

# %%
import codecs
from __future__ import print_function

# %% [markdown]
# ##Ouverture du fichier des sous-titres .ASS

# %%
fichier=open('../Videos/FranceArgentine-FR-commentaires.ass','r')
lignes=fichier.readlines()

# %% [markdown]
# ##Ajout des numéros d'action sur les éléments de dialogue
# Pour chaque *ligne* dans *lignes*
#
# - si la *ligne* contient "Dialogue"
#  - on coupe la *ligne* sur les virgules "," dans *dialogueElements*
#  - on coupe le dernier *dialogueElements* sur les espaces " " dans *dialogue*
#  - si le *dialogue* contient plus d'un élément
#    - on coupe le premier élément de *dialogue* sur le tiret "-" et on met le premier élément dans *speaker*
#    - on renseigne le style *dialogueElements[3]* et l'acteur *dialogueElements[4]* avec *speaker*
#  - sinon
#    - on renseigne le style *dialogueElements[3]* avec "pb"
#    - on ajoute "PROBLÈME " au dernier élément de *dialogueElements*
#  - on réassemble la ligne et on l'écrit
# - sinon on écrit la ligne telle quelle

# %%
pb=False
for ligne in lignes[:150]:
    if 'Dialogue' in ligne:
        dialogueElements=ligne.split(",")
        texte=dialogueElements[-1]
        if "-" in texte:
            dialogue=dialogueElements[-1].split(" ")
            if len(dialogue)>1:
                speaker=dialogue[0].split("-")[0]
                if len(texte)>1:
                    dialogueElements[3]=speaker
                    dialogueElements[4]=speaker
                else:
                    dialogueElements[3]="pb"
                    dialogueElements[-1]="PROBLÈME"+dialogueElements[-1]
            else:
                pb=True
                dialogueElements[3]="pb"
                dialogueElements[-1]="PROBLÈME "+dialogueElements[-1]
            print(",".join(dialogueElements))
        else:
            if pb:
                pb=False
                dialogueElements[3]="pb"
                dialogueElements[4]=speaker
                dialogueElements[-1]="PROBLÈME "+dialogueElements[-1]                
    else:
        print(ligne)
# Out:
# ﻿[Script Info]
#
# ; Script generated by Aegisub 3.1.3
#
# ; http://www.aegisub.org/
#
# Title: Default Aegisub file
#
# ScriptType: v4.00+
#
# WrapStyle: 0
#
# ScaledBorderAndShadow: yes
#
# YCbCr Matrix: TV.601
#
# PlayResX: 640
#
# PlayResY: 350
#
# Aegisub Video Zoom Percent: 1.000000
#
# Video File: ../Videos/FranceArgentine-FR.mp4
#
# Aegisub Video Aspect Ratio: c1.833333
#
# Aegisub Video Position: 23299
#
# Audio URI: ../Videos/FranceArgentine-FR.mp4
#
# Aegisub Scroll Position: 2756
#
# Aegisub Active Line: 77
#
# Last Style Storage: Default
#
# Export Encoding: Unicode (UTF-8)
#
#
#
# [V4+ Styles]
#
# Format: Name, Fontname, Fontsize, PrimaryColour, SecondaryColour, OutlineColour, BackColour, Bold, Italic, Underline, StrikeOut, ScaleX, ScaleY, Spacing, Angle, BorderStyle, Outline, Shadow, Alignment, MarginL, MarginR, MarginV, Encoding
#
# Style: Default,Arial,20,&H00FFFFFF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,2,2,2,10,10,10,1
#
# Style: spk1,Arial,20,&H0000FF00,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,2,2,2,10,10,10,1
#
# Style: spk2,Arial,20,&H0000FFFF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,2,2,2,10,10,10,1
#
# Style: spk3,Arial,20,&H00FF00FF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,2,2,2,10,10,10,1
#
# Style: pb,Arial,20,&H000000FF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,10,2,5,10,10,10,1
#
#
#
# [Events]
#
# Format: Layer, Start, End, Style, Name, MarginL, MarginR, MarginV, Effect, Text
#
# Dialogue: 0,0:12:24.60,0:12:28.32,spk1,spk1,0,0,0,,spk1-001  après avoir demandé si tout le monde était prêt le coup d'envoi de la coupe du monde deux mille sept
#
# Dialogue: 0,0:12:28.56,0:12:30.92,spk1,spk1,0,0,0,,spk1-002  est donné par David Skrela
#
# Dialogue: 0,0:12:32.00,0:12:33.40,spk2,spk2,0,0,0,,spk2-001  allez de suite dans le camp euh
#
# Dialogue: 0,0:12:34.00,0:12:34.56,spk2,spk2,0,0,0,,spk2-002  argentin
#
# Dialogue: 0,0:12:34.72,0:12:36.24,spk1,spk1,0,0,0,,spk1-003  avec un départ de Roncero
#
# Dialogue: 0,0:12:36.96,0:12:38.16,spk1,spk1,0,0,0,,spk1-004  Pichot a appelé le ballon
#
# Dialogue: 0,0:12:38.96,0:12:40.20,spk1,spk1,0,0,0,,spk1-005  pour Hernandez
#
# Dialogue: 0,0:12:40.88,0:12:42.40,spk1,spk1,0,0,0,,spk1-006  avec le pied droit
#
# Dialogue: 0,0:12:42.96,0:12:44.68,spk1,spk1,0,0,0,,spk1-007  pour trouver une très jolie touche
#
# Dialogue: 0,0:12:45.40,0:12:49.04,spk1,spk1,0,0,0,,spk1-008  direct il en avait le droit il était à l'intérieur de ses vingt-deux mètres
#
# Dialogue: 0,0:12:49.48,0:12:50.16,spk1,spk1,0,0,0,,spk1-009  dans ces cas-là
#
# Dialogue: 0,0:12:50.32,0:12:51.44,spk1,spk1,0,0,0,,spk1-010  on peut trouver une touche
#
# Dialogue: 0,0:12:51.76,0:12:52.44,spk1,spk1,0,0,0,,spk1-011  directement
#
# Dialogue: 0,0:12:54.76,0:12:55.48,spk1,spk1,0,0,0,,spk1-012  alors la touche
#
# Dialogue: 0,0:12:55.64,0:12:57.20,spk1,spk1,0,0,0,,spk1-013  ça ça sera une des clefs de cette rencontre
#
# Dialogue: 0,0:12:57.52,0:12:58.56,spk1,spk1,0,0,0,,spk1-014  le bloc français
#
# Dialogue: 0,0:12:59.12,0:13:00.36,spk1,spk1,0,0,0,,spk1-015  contre le bloc argentin
#
# Dialogue: 0,0:13:01.72,0:13:02.44,spk1,spk1,0,0,0,,spk1-016  lancer
#
# Dialogue: 0,0:13:03.84,0:13:06.24,spk1,spk1,0,0,0,,spk1-017  pour le capitaine de l'équipe de France Raphaël Ibañez
#
# Dialogue: 0,0:13:07.16,0:13:08.68,spk1,spk1,0,0,0,,spk1-018  qui a donc le choix de la combinaison
#
# Dialogue: 0,0:13:10.96,0:13:13.32,spk1,spk1,0,0,0,,spk1-019  ah un ballon bien pris ah quoique relâché
#
# Dialogue: 0,0:13:13.60,0:13:14.80,spk1,spk1,0,0,0,,spk1-020  et ça profite à Pichot
#
# Dialogue: 0,0:13:15.32,0:13:16.68,spk1,spk1,0,0,0,,spk1-021  un petit coup de pied par-dessus
#
# Dialogue: 0,0:13:17.12,0:13:20.52,spk1,spk1,0,0,0,,spk1-022  Cédric Heymans en couverture il va devoir
#
# Dialogue: 0,0:13:20.84,0:13:22.84,spk1,spk1,0,0,0,,spk1-023  oui avec la cuillère de Pichot
#
# Dialogue: 0,0:13:23.32,0:13:24.28,spk1,spk1,0,0,0,,spk1-024  Heymans est au sol
#
# Dialogue: 0,0:13:24.72,0:13:25.92,spk1,spk1,0,0,0,,spk1-025  attention à ne pas garder le ballon
#
# Dialogue: 0,0:13:26.20,0:13:27.00,spk1,spk1,0,0,0,,spk1-026  à le libérer vite
#
# Dialogue: 0,0:13:28.36,0:13:29.36,spk1,spk1,0,0,0,,spk1-027  David Skrela
#
# Dialogue: 0,0:13:29.52,0:13:31.24,spk1,spk1,0,0,0,,spk1-028  première gross alerte
#
# Dialogue: 0,0:13:31.60,0:13:32.04,spk3,spk3,0,0,0,,spk3-001  Thierry
#
# Dialogue: 0,0:13:32.40,0:13:34.76,spk2,spk2,0,0,0,,spk2-003  oui effectivement ces Argentins avec Agustin Pichot
#
# Dialogue: 0,0:13:35.04,0:13:37.24,spk2,spk2,0,0,0,,spk2-004  alors il faut en parler aussi parce que la clef du match aujourd'hui
#
# Dialogue: 0,0:13:37.40,0:13:38.16,spk2,spk2,0,0,0,,spk2-005  c'est le numéro neuf
#
# Dialogue: 0,0:13:38.44,0:13:40.80,spk2,spk2,0,0,0,,spk2-006  on voit regardez la cuillère c'est ça c'est le petit coup de main
#
# Dialogue: 0,0:13:41.00,0:13:43.12,spk2,spk2,0,0,0,,spk2-007  sur le le la le la la cheville de
#
# Dialogue: 0,0:13:43.44,0:13:44.80,spk2,spk2,0,0,0,,spk2-008  de Heymans et le déséquilibre
#
# Dialogue: 0,0:13:44.96,0:13:46.68,spk2,spk2,0,0,0,,spk2-009  attention ça peut être dangereux hein des fois quand on tombe comme ça
#
# Dialogue: 0,0:13:47.04,0:13:49.08,spk2,spk2,0,0,0,,spk2-010  y'a une clef aussi c'est les demis de mêlée on vous en parlera tout à l'heure
#
# Dialogue: 0,0:13:49.24,0:13:49.64,spk2,spk2,0,0,0,,spk2-011  place au jeu
#
# Dialogue: 0,0:13:49.80,0:13:50.84,spk2,spk2,0,0,0,,spk2-012  place à la touche Ledesma
#
# Dialogue: 0,0:13:51.12,0:13:54.04,spk1,spk1,0,0,0,,spk1-029  Mario Ledesma super Mario pour cette remise en jeu
#
# Dialogue: 0,0:13:55.40,0:13:57.80,spk1,spk1,0,0,0,,spk1-030  ah les Argentins qui ont bien démarré en chipant un premier ballon
#
# Dialogue: 0,0:13:58.16,0:13:59.28,spk1,spk1,0,0,0,,spk1-031  à l'alignement français
#
# Dialogue: 0,0:13:59.80,0:14:00.76,spk1,spk1,0,0,0,,spk1-032  et en s'emparant
#
# Dialogue: 0,0:14:01.20,0:14:01.92,spk1,spk1,0,0,0,,spk1-033  proprement
#
# Dialogue: 0,0:14:02.40,0:14:03.28,spk1,spk1,0,0,0,,spk1-034  du deuxième
#
# Dialogue: 0,0:14:03.88,0:14:04.48,spk1,spk1,0,0,0,,spk1-035  des grosses
#
# Dialogue: 0,0:14:04.80,0:14:05.92,spk1,spk1,0,0,0,,spk1-036  poussées défensives
#
# Dialogue: 0,0:14:06.28,0:14:07.20,spk1,spk1,0,0,0,,spk1-037  du pack français
#
# Dialogue: 0,0:14:08.08,0:14:09.20,spk1,spk1,0,0,0,,spk1-038  Ledesma encore
#
# Dialogue: 0,0:14:12.60,0:14:15.04,spk1,spk1,0,0,0,,spk1-039  et vous entendez Monsieur Spreadbury qui fait de la prévention
#
# Dialogue: 0,0:14:16.00,0:14:18.52,spk1,spk1,0,0,0,,spk1-040  Hernandez le drop avec le pied gauche
#
# Dialogue: 0,0:14:19.84,0:14:23.04,spk1,spk1,0,0,0,,spk1-041  qui va mourir sous les poteaux où se trouve Cédric Heymans
#
# Dialogue: 0,0:14:25.92,0:14:28.28,spk1,spk1,0,0,0,,spk1-042  avec un arrêt de volée accordé par Monsieur Spreadbury
#
# Dialogue: 0,0:14:32.96,0:14:36.20,spk1,spk1,0,0,0,,spk1-043  tentative qui a échoué d'un rien hein de la part de Juan Martin Hernandez
#
# Dialogue: 0,0:14:37.20,0:14:39.04,spk1,spk1,0,0,0,,spk1-044  et le pied gauche de Cédric Heymans
#
# Dialogue: 0,0:14:40.12,0:14:41.32,spk1,spk1,0,0,0,,spk1-045  hou pour soulager
#
# Dialogue: 0,0:14:41.52,0:14:42.12,spk1,spk1,0,0,0,,spk1-046  difficilement
#
# Dialogue: 0,0:14:42.96,0:14:43.56,spk1,spk1,0,0,0,,spk1-047  l'équipe
#
# Dialogue: 0,0:14:42.96,0:14:43.56,spk2,spk2,0,0,0,,spk2-013  oh hé bien
#
# Dialogue: 0,0:14:43.56,0:14:44.12,spk1,spk1,0,0,0,,spk1-048  de France
#
# Dialogue: 0,0:14:44.12,0:14:46.76,spk2,spk2,0,0,0,,spk2-014  on a besoin de se rassurer on est pris euh d'entrée par le
#
# Dialogue: 0,0:14:47.28,0:14:51.52,spk2,spk2,0,0,0,,spk2-015  la vigueur l'agressivité euh argentine le drop qui vient mourir juste au bord
#
# Dialogue: 0,0:14:51.84,0:14:53.40,spk2,spk2,0,0,0,,spk2-016  du poteau euh gauche français
#
# Dialogue: 0,0:14:54.04,0:14:54.88,spk2,spk2,0,0,0,,spk2-017  de Hernandez
#
# Dialogue: 0,0:14:55.36,0:15:00.16,spk2,spk2,0,0,0,,spk2-018  ah il faut vite aller réoccuper le terrain pour se rassurer parce qu'en tout cas ce début de partie il est argentin vous le voyez
#
# Dialogue: 0,0:15:03.08,0:15:06.44,spk1,spk1,0,0,0,,spk1-049  et ouais Mario Ledesma l'ambiance est telle dans ce stade de France il a du mal
#
# Dialogue: 0,0:15:07.20,0:15:09.04,spk1,spk1,0,0,0,,spk1-050  à comprendre les combinaisons annoncées
#
# Dialogue: 0,0:15:11.12,0:15:14.32,spk1,spk1,0,0,0,,spk1-051  joue plutôt en fond de touche où Rémy Martin a essayé de batailler
#
# Dialogue: 0,0:15:15.08,0:15:16.08,spk1,spk1,0,0,0,,spk1-052  mais le départ
#
# Dialogue: 0,0:15:17.08,0:15:18.20,spk1,spk1,0,0,0,,spk1-053  d'Albacete
#
# Dialogue: 0,0:15:19.56,0:15:21.16,spk1,spk1,0,0,0,,spk1-054  relayé par Fernandez Lobbe
#
# Dialogue: 0,0:15:23.84,0:15:27.88,spk1,spk1,0,0,0,,spk1-055  voilà ce petit jeu de pick and go on prend le ballon et on vient défier l'adversaire
#
# Dialogue: 0,0:15:28.32,0:15:28.72,spk1,spk1,0,0,0,,spk1-056  au ras
#
# Dialogue: 0,0:15:31.96,0:15:33.12,spk1,spk1,0,0,0,,spk1-057  peut-être pour mettre Hernandez
#
# Dialogue: 0,0:15:31.96,0:15:33.12,pb,,0,0,0,,PROBLÈME spk2-019
#
# Dialogue: 0,0:15:33.12,0:15:35.44,spk1,spk1,0,0,0,,spk1-058  encore dans une position de drop il est contré
#
# Dialogue: 0,0:15:35.76,0:15:37.76,spk1,spk1,0,0,0,,spk1-059  Hernandez le ballon pour Dominici
#
# Dialogue: 0,0:15:41.24,0:15:42.20,spk1,spk1,0,0,0,,spk1-060  allez un regroupement
#
# Dialogue: 0,0:15:44.00,0:15:46.72,spk1,spk1,0,0,0,,spk1-061  avec euh Mignoni son premier ballon dans le fermé
#
# Dialogue: 0,0:15:47.04,0:15:48.16,spk1,spk1,0,0,0,,spk1-062  pour lancer de Villiers
#
# Dialogue: 0,0:15:50.48,0:15:53.84,spk1,spk1,0,0,0,,spk1-063  et pénalité contre l'équipe de France Pieter de Villiers accusé
#
# Dialogue: 0,0:15:54.20,0:15:54.44,spk1,spk1,0,0,0,,spk1-064  d'avoir
#
# Dialogue: 0,0:15:54.60,0:15:55.56,spk1,spk1,0,0,0,,spk1-065  tenu le ballon
#
# Dialogue: 0,0:15:55.92,0:15:56.40,spk1,spk1,0,0,0,,spk1-066  au sol
#
# Dialogue: 0,0:15:57.00,0:15:58.96,spk1,spk1,0,0,0,,spk1-067  quand on est au sol on est un joueur
#
# Dialogue: 0,0:15:59.20,0:16:00.88,spk1,spk1,0,0,0,,spk1-068  mort Thierry on ne doit plus rien faire hein
#
# Dialogue: 0,0:16:01.12,0:16:03.00,spk1,spk1,0,0,0,,spk1-069  si ce n'est que s'écarter le plus vite possible
#
# Dialogue: 0,0:16:03.32,0:16:03.92,spk1,spk1,0,0,0,,spk1-070  de la zone de jeu
#
# Dialogue: 0,0:16:04.16,0:16:06.92,spk2,spk2,0,0,0,,spk2-020  ouais effectivement dès que vous allez voir là on va aller au sol par Pieter de Villiers
#
# Dialogue: 0,0:16:07.16,0:16:12.40,spk2,spk2,0,0,0,,spk2-021  et là il doit lâcher la balle regardez il le garde auprès du corps pourquoi y'a trois Argentins dessus ils ont beaucoup ils sont beaucoup plus rapides que nous
#
# Dialogue: 0,0:16:12.72,0:16:14.04,spk2,spk2,0,0,0,,spk2-022  sur toutes les phases de contact
#
# Dialogue: 0,0:16:14.40,0:16:15.48,spk2,spk2,0,0,0,,spk2-023  donc on revoit le drop contré
#
# Dialogue: 0,0:16:16.04,0:16:17.36,spk2,spk2,0,0,0,,spk2-024  euh sur vos sur votre écran
#
# Dialogue: 0,0:16:18.44,0:16:18.76,spk1,spk1,0,0,0,,spk1-071  euh oui
#
# Dialogue: 0,0:16:18.76,0:16:20.20,spk2,spk2,0,0,0,,spk2-025  euh Bernard Laporte euh
#
# Dialogue: 0,0:16:18.76,0:16:20.20,spk1,spk1,0,0,0,,spk1-072  et oui pas content Bernard
#
# Dialogue: 0,0:16:20.20,0:16:22.40,spk1,spk1,0,0,0,,spk1-073  Laporte pas content du tout de cette entame de match
#
# Dialogue: 0,0:16:22.88,0:16:23.64,spk1,spk1,0,0,0,,spk1-074  de l'équipe de France
#
# Dialogue: 0,0:16:23.64,0:16:24.44,spk1,spk1,0,0,0,,spk1-075  on sent les français
#
# Dialogue: 0,0:16:25.00,0:16:27.40,spk1,spk1,0,0,0,,spk1-076  crispés hein qui ne se sont encore pas libérés
#
# Dialogue: 0,0:16:28.64,0:16:30.80,spk1,spk1,0,0,0,,spk1-077  et qui offrent à Felipe Contepomi
#
# Dialogue: 0,0:16:31.24,0:16:32.48,spk1,spk1,0,0,0,,spk1-078  la première occasion
#
# Dialogue: 0,0:16:33.20,0:16:34.12,spk1,spk1,0,0,0,,spk1-079  d'ouvrir le score
#
# Dialogue: 0,0:16:34.88,0:16:36.88,spk1,spk1,0,0,0,,spk1-080  coup de pied pas facile hein quarante-cinq mètres
#
# Dialogue: 0,0:16:37.16,0:16:37.84,spk1,spk1,0,0,0,,spk1-081  sur le côté
#
# Dialogue: 0,0:16:38.32,0:16:38.80,pb,,0,0,0,,PROBLÈME spk2-026
#
# Dialogue: 0,0:16:38.80,0:16:39.44,spk2,spk2,0,0,0,,spk2-027  droite du poteau
#
# Dialogue: 0,0:16:40.36,0:16:41.12,spk2,spk2,0,0,0,,spk2-028  quand reviendra euh
#
# Dialogue: 0,0:16:41.32,0:16:42.60,spk2,spk2,0,0,0,,spk2-029  alors allez sur tf1.fr
#
# Dialogue: 0,0:16:42.76,0:16:45.32,spk2,spk2,0,0,0,,spk2-030  parce que je vais reprendre une phrase de Marc Antoine Jamet
#
# Dialogue: 0,0:16:45.88,0:16:51.16,spk2,spk2,0,0,0,,spk2-031  de Val-de-Reuil l'excellent Marc-Antoine Jamet qui disait aujourd'hui la clef du succès c'est le dyna- dynamisme
#
# Dialogue: 0,0:16:51.52,0:16:52.24,spk2,spk2,0,0,0,,spk2-032  de Mignoni
#
# Dialogue: 0,0:16:52.44,0:16:53.56,spk2,spk2,0,0,0,,spk2-033  face à l'expérience
#
# Dialogue: 0,0:16:53.88,0:16:54.36,spk2,spk2,0,0,0,,spk2-034  au vice
#
# Dialogue: 0,0:16:54.76,0:16:55.36,spk2,spk2,0,0,0,,spk2-035  de Pichot
#
# Dialogue: 0,0:16:55.56,0:16:56.32,spk2,spk2,0,0,0,,spk2-036  et c'est vrai vous le verrez
