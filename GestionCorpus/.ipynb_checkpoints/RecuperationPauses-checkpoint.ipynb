# %% [markdown]
# # Calcul du débit sur la base du traitement phonétique du TRS
# => ATTENTION LA TIMELINE EST DIFFERENTE DE CELLE DE LA VIDEO
# - Première mi-temps TRS "0.000" => Vidéo "00:11:52.4"
# - Deuxième mi-temps TRS "3257.608" => Vidéo "00:57:22.70"

# %%
import pandas as pd
from numpy import arange
import codecs

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle

# %%
repertoire="/Users/gilles/Copy/Recherche/Rugby/CorpusRugby2007/"
textgridName="/Users/gilles/Copy/Recherche/Rugby/CorpusRugby2007/phonTimelineSorted.csv"
textgridFile=open(textgridName,"r")
textgrid=textgridFile.readlines()

# %%
timing=[]
for ligne in textgrid[1:]:
    timing.append(ligne.strip().split(","))

# %%
timeLine=pd.DataFrame(columns=["début","fin","pause","suivant"])

# %%
for num,ligne1 in enumerate(timing):
    debut=int(float(ligne1[0])*100)
    speaker=ligne1[3]
    if num+2<longueur:
        ligne2=timing[num+1]
        ligne3=timing[num+2]
        if ligne1[2]=="SIL" and ligne1[1]==ligne2[0]:
            if ligne2[2]!="":
                timeLine.loc[debut]=[ligne1[0],ligne1[1],speaker,ligne2[3]]
            else:
                timeLine.loc[debut]=[ligne1[0],ligne3[0],speaker,ligne3[3]]

# %%
timeLine[(timeLine["pause"]=="spk1")&(timeLine["suivant"]=="spk2")]
# Out:
#           début      fin pause suivant  durée
# 3934      39.34    40.55  spk1    spk2   1.21
# 17062    170.62   171.52  spk1    spk2   0.90
# 17242    172.42   172.75  spk1    spk2   0.33
# 25240     252.4    252.7  spk1    spk2   0.30
# 26714    267.15   267.29  spk1    spk2   0.14
# 28633    286.34   287.33  spk1    spk2   0.99
# 33487    334.87   335.93  spk1    spk2   1.06
# 38475    384.75   385.04  spk1    spk2   0.29
# 52941    529.41   529.52  spk1    spk2   0.11
# 60524    605.24   606.57  spk1    spk2   1.33
# 67110     671.1   671.39  spk1    spk2   0.29
# 69040     690.4   690.47  spk1    spk2   0.07
# 69180     691.8   692.17  spk1    spk2   0.37
# 69621    696.21   696.52  spk1    spk2   0.31
# 71142    711.42   712.04  spk1    spk2   0.62
# 74846    748.46   748.93  spk1    spk2   0.47
# 77770     777.7   777.92  spk1    spk2   0.22
# 85811    858.11   858.25  spk1    spk2   0.14
# 86276    862.76   863.02  spk1    spk2   0.26
# 87059    870.59   873.18  spk1    spk2   2.59
# 88518    885.18   887.17  spk1    spk2   1.99
# 93666    936.66   936.84  spk1    spk2   0.18
# 93920     939.2   939.55  spk1    spk2   0.35
# 96475    964.75   965.75  spk1    spk2   1.00
# 98718    987.18   987.75  spk1    spk2   0.57
# 105334  1053.35  1053.45  spk1    spk2   0.10
# 107534  1075.35  1075.54  spk1    spk2   0.19
# 110626  1106.26  1108.04  spk1    spk2   1.78
# 113718  1137.18  1137.99  spk1    spk2   0.81
# 114222  1142.22  1143.26  spk1    spk2   1.04
# ...         ...      ...   ...     ...    ...
# 571409  5714.09  5714.45  spk1    spk2   0.36
# 578046  5780.46  5780.89  spk1    spk2   0.43
# 578708  5787.08  5787.55  spk1    spk2   0.47
# 578943  5789.43  5789.57  spk1    spk2   0.14
# 583836  5838.36   5839.3  spk1    spk2   0.94
# 584571  5845.71  5846.04  spk1    spk2   0.33
# 585839  5858.39  5859.27  spk1    spk2   0.88
# 587155  5871.55  5875.98  spk1    spk2   4.43
# 590580   5905.8  5905.95  spk1    spk2   0.15
# 590719  5907.19   5907.5  spk1    spk2   0.31
# 591174  5911.74  5911.86  spk1    spk2   0.12
# 591982  5919.82  5920.66  spk1    spk2   0.84
# 594122  5941.22  5942.54  spk1    spk2   1.32
# 594889  5948.89  5949.97  spk1    spk2   1.08
# 603473  6034.73  6035.11  spk1    spk2   0.38
# 603722  6037.22   6037.9  spk1    spk2   0.68
# 607674  6076.74  6076.86  spk1    spk2   0.12
# 609395  6093.95  6094.21  spk1    spk2   0.26
# 614572  6145.72  6147.05  spk1    spk2   1.33
# 615032  6150.32  6150.52  spk1    spk2   0.20
# 618624  6186.24   6188.6  spk1    spk2   2.36
# 619662  6196.62  6196.96  spk1    spk2   0.34
# 619857  6198.57  6199.04  spk1    spk2   0.47
# 620571  6205.71  6207.48  spk1    spk2   1.77
# 622955  6229.55  6230.33  spk1    spk2   0.78
# 624861  6248.61  6249.25  spk1    spk2   0.64
# 630354  6303.54  6304.09  spk1    spk2   0.55
# 633900   6339.0   6339.4  spk1    spk2   0.40
# 637015  6370.15  6370.42  spk1    spk2   0.27
# 637906  6379.06  6379.26  spk1    spk2   0.20
#
# [225 rows x 5 columns]

# %%
#print len(timeLine[timeLine.index<4400][timeLine[timeLine.index<4400].index>3300][["V1","V2","V3"]].dropna(thresh=1))
timeLine["durée"]=timeLine["fin"].astype(float)-timeLine["début"].astype(float)

# %%
def arrondirTemps(temps):
    return round(temps,2)

# %%
timeLine["plage"]=timeLine.apply(lambda row: arrondirTemps(row["durée"]),axis=1)

# %%
timeLine["même"]=timeLine["pause"]==timeLine["suivant"]

# %%
timeLine[(timeLine["durée"]>100)]
#timeLine
# Out:
#           début      fin pause suivant   durée   plage  même
# 271985  2719.85  3257.68  spk1    spk1  537.83  537.83  True

# %%
timeLine[(timeLine["même"])&(timeLine["durée"]<100)].groupby("plage")["pause"].count().plot(kind="bar",figsize=(50,4))
