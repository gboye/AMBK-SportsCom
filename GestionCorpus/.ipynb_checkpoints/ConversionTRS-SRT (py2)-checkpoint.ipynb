# %% [markdown]
# # Conversion d'une transcription à un fichier de sous-titres SRT V1.0

# %%
from lxml import etree
import codecs

# %%
bSpeaker=False
fTRS="/Users/gilles/Downloads/Japon-Fidji/2007-09-12_Japon-Fidji.trs"

# %%
# fichierTranscription=open("../AnnotationsCommentaires/France_Argentine_ANNOT-REF_Révisé.trs","r")
# fichierTranscription=open("./TEST-lxml.xml","r")
fichierTranscription=open(fTRS,"r")

xmlTranscription=fichierTranscription.read()
# print xmlTranscription

# %%
root=etree.XML(xmlTranscription)

# %%
def calculChaine(chaineTemps,sep=","):
    temps=float(chaineTemps)*ratio
    heures=temps//3600
    reste=temps-heures*3600
    minutes=reste//60
    secondes=reste-minutes*60
    result="%02d:%02d:%06.3f" % (heures,minutes,secondes)
    if sep==",":
        result=result.replace(".",",")
    return result

# %%
calculChaine(1212.45)
# Out:
# '00:20:06,778'

# %%
# Topics=root[1]
# Episodes=root[2]
Episodes=root[1]
sections=[]
for section in Episodes.findall('Section'):
	sectionType=section.get('type')
	sectionTopic=section.get('topic')
	sectionStart=section.get('startTime')
	sectionEnd=section.get('endTime')
	turns=[]
	for turn in section.findall('Turn'):
		speaker=turn.get('speaker')
		if speaker:
			speakers=speaker.split(" ")
		else:
			speakers=[""]
		startTime=turn.get('startTime')
		endTime=turn.get('endTime')
		syncs=[]
		whos=0
		for element in turn.iter():
			if element.tag=="Sync":
				syncs.append((element.get('time'),speakers[0]))
			elif element.tag=="Who":
				whos+=1
				if whos>1:
					syncs.append((syncs[-1][0],speakers[-1]))
			elif element.tag!="Turn":
				contents=[element.tag]
				for attrib in element.attrib:
					contents.append(attrib)
					contents.append(element.attrib[attrib])
				content=" ".join(contents)
				syncs.append((syncs[-1][0],content))
		texts=[]
		for text in turn.itertext():
			if text!="\n":
				texts.append(text.strip("\n"))
		elements=[]
		for i in range(len(texts)):
			elements.append((syncs[i][0],syncs[i][1],texts[i]))
		turns.append((startTime,endTime,speaker,elements))
	sections.append((sectionType,sectionTopic,sectionStart,sectionEnd,turns))

# %%
printSelection="Sync"
srtLines=[]
numSection=0
numTurn=0
numSync=0
nSync={}
for stype,stopic,sstart,send,turns in sections:
	numSection+=1
#	 print "Section",numSection,stype,stopic,sstart,send
	if printSelection=="Section":
		print sstart,";",send,";",stype,";",stopic
	numTurnIn=0
	for tstart,tend,speaker,text in turns[:]:
		if speaker not in nSync:
			nSync[speaker]=0
		numTurn+=1
		numTurnIn+=1
#		 print "\tTurn",numTurn,tstart, tend, speaker
		if printSelection=="Turn":
			print tstart,";",tend,";",speaker
		numSyncIn=0
		for sync in text[:]:
			numSync+=1
			numSyncIn+=1
#			 print "\t\tSync",numSync, sync[0], sync[1], sync[2]
			if printSelection=="Sync":
				prefix=""
				if 220<=numSync<=225:
					print numSync
					print calculChaine(sync[0])," --> ", calculChaine(tend)
					print sync[2].encode("utf8")
				if sync[1]!="" and sync[1] in nSync and bSpeaker:
					nSync[sync[1]]+=1
					# print sync[1]+"-%03d "%nSync[sync[1]],
					prefix=sync[1]+"-%03d "%nSync[sync[1]]
				# print
				srtLines.append(str(numSync))
				srtLines.append(calculChaine(sync[0])+" --> "+ calculChaine(tend))
				srtLines.append(prefix+sync[2])
				srtLines.append("")
# Out:
# 220
# 00:07:59,722  -->  00:08:00,087
#
# 221
# 00:08:00,087  -->  00:08:01,146
# nan c'est la tentative
# 222
# 00:08:00,087  -->  00:08:01,146
# oh ouais
# 223
# 00:08:01,146  -->  00:08:01,422
#
# 224
# 00:08:01,422  -->  00:08:02,597
# et tout ça c'est parti euh
# 225
# 00:08:02,597  -->  00:08:03,063

# %%
srtLines[850:]
# Out:
# [u'les Japonais ne sont toujours pas all\xe9s dans le camp fidjien',
#  '',
#  '214',
#  '00:07:55,093 --> 00:07:56,749',
#  '',
#  '',
#  '215',
#  '00:07:56,749 --> 00:07:57,827',
#  'la touche a priori',
#  '',
#  '216',
#  '00:07:57,827 --> 00:07:58,256',
#  '',
#  '',
#  '217',
#  '00:07:58,256 --> 00:07:58,688',
#  'la touche ',
#  '',
#  '218',
#  '00:07:58,688 --> 00:07:58,859',
#  '',
#  '',
#  '219',
#  '00:07:58,859 --> 00:07:59,722',
#  'ou la tentative',
#  '',
#  '220',
#  '00:07:59,722 --> 00:08:00,087',
#  '',
#  '',
#  '221',
#  '00:08:00,087 --> 00:08:01,146',
#  "nan c'est la tentative",
#  '',
#  '222',
#  '00:08:00,087 --> 00:08:01,146',
#  'oh ouais',
#  '',
#  '223',
#  '00:08:01,146 --> 00:08:01,422',
#  '',
#  '',
#  '224',
#  '00:08:01,422 --> 00:08:02,597',
#  u"et tout \xe7a c'est parti euh",
#  '',
#  '225',
#  '00:08:02,597 --> 00:08:03,063',
#  '',
#  '',
#  '226',
#  '00:08:03,063 --> 00:08:03,881',
#  'effectivement ',
#  '',
#  '227',
#  '00:08:03,881 --> 00:08:04,044',
#  '',
#  '',
#  '228',
#  '00:08:04,044 --> 00:08:06,687',
#  u"d'un une touche pas trouv\xe9e euh par le dix euh",
#  '',
#  '229',
#  '00:08:06,687 --> 00:08:06,891',
#  '',
#  '',
#  '230',
#  '00:08:06,891 --> 00:08:07,701',
#  'japonais euh',
#  '',
#  '231',
#  '00:08:07,701 --> 00:08:08,642',
#  '',
#  '',
#  '232',
#  '00:08:08,642 --> 00:08:09,354',
#  'Robins',
#  '',
#  '233',
#  '00:08:09,354 --> 00:08:09,763',
#  '',
#  '',
#  '234',
#  '00:08:09,763 --> 00:08:11,579',
#  u'et derri\xe8re euh vous avez vu la relance',
#  '',
#  '235',
#  '00:08:11,579 --> 00:08:11,778',
#  '',
#  '',
#  '236',
#  '00:08:11,778 --> 00:08:14,445',
#  u"de l'ailier de la star Neivua qui a men\xe9 cette p\xe9nalit\xe9",
#  '',
#  '237',
#  '00:08:14,445 --> 00:08:14,709',
#  '',
#  '',
#  '238',
#  '00:08:14,709 --> 00:08:17,048',
#  u'le d\xe9tail est important \xe0 ce niveau de la comp\xe9tition en coupe du monde',
#  '',
#  '239',
#  '00:08:17,048 --> 00:08:17,374',
#  '',
#  '',
#  '240',
#  '00:08:17,374 --> 00:08:21,355',
#  u'chaque touche non trouv\xe9e chaque faute vous \xeates sanctionn\xe9 derri\xe8re en tout cas on va voir si Little',
#  '',
#  '241',
#  '00:08:21,355 --> 00:08:21,875',
#  '',
#  '',
#  '242',
#  '00:08:21,875 --> 00:08:25,588',
#  u"qui est le premier d'ailleurs hein buteur reconnu euh de ces \xeeles Fidji puisque",
#  '',
#  '243',
#  '00:08:25,588 --> 00:08:26,151',
#  '',
#  '',
#  '244',
#  '00:08:26,151 --> 00:08:27,431',
#  u'ils avaient pas de buteur jusque-l\xe0',
#  '',
#  '245',
#  '00:08:27,431 --> 00:08:30,073',
#  '',
#  '',
#  '246',
#  '00:08:30,073 --> 00:08:32,456',
#  u'et un ballon qui est bien dos\xe9 et qui passe ',
#  '',
#  '247',
#  '00:08:32,456 --> 00:08:32,726',
#  '',
#  '',
#  '248',
#  '00:08:32,726 --> 00:08:35,522',
#  "et bien c'est historique il passe ainsi la barre des six cents points",
#  '',
#  '249',
#  '00:08:35,522 --> 00:08:35,741',
#  '',
#  '',
#  '250',
#  '00:08:35,741 --> 00:08:37,239',
#  u'pour son pays on est \xe0 six cent deux',
#  '',
#  '251',
#  '00:08:37,239 --> 00:08:37,558',
#  '',
#  '',
#  '252',
#  '00:08:37,558 --> 00:08:37,833',
#  'mais',
#  '',
#  '253',
#  '00:08:37,833 --> 00:08:37,990',
#  '',
#  '',
#  '254',
#  '00:08:37,990 --> 00:08:38,639',
#  'seulement trois ',
#  '',
#  '255',
#  '00:08:38,639 --> 00:08:38,843',
#  '',
#  '',
#  '256',
#  '00:08:38,843 --> 00:08:40,366',
#  u"aujourd'hui trois z\xe9ro pour les Fidjiens",
#  '',
#  '257',
#  '00:08:40,366 --> 00:08:45,745',
#  '',
#  '',
#  '258',
#  '00:08:45,745 --> 00:08:48,365',
#  u"oui parce qu'on se souvient de l'\xe9quipe figji avec euh une euh",
#  '',
#  '259',
#  '00:08:48,365 --> 00:08:49,137',
#  '',
#  '',
#  '260',
#  '00:08:49,137 --> 00:08:52,248',
#  u"pr\xe9sence \xe9norme de S\xe9r\xe9vi le petit 10 qui a jou\xe9 \xe0 Mont-de-Marsan d'ailleurs",
#  '',
#  '261',
#  '00:08:52,248 --> 00:08:52,615',
#  '',
#  '',
#  '262',
#  '00:08:52,615 --> 00:08:53,864',
#  u'et dans pas mal de clubs fran\xe7ais',
#  '',
#  '263',
#  '00:08:53,864 --> 00:08:54,681',
#  '',
#  '',
#  '264',
#  '00:08:54,681 --> 00:08:58,756',
#  u"mais c'\xe9tait pas un grand buteur aujourd'hui ils ont trouv\xe9 leur buteur r\xe9gulier avec Little",
#  '',
#  '265',
#  '00:08:58,756 --> 00:08:59,203',
#  '',
#  '',
#  '266',
#  '00:08:59,203 --> 00:09:00,707',
#  u"qui s'est frott\xe9 au championnat anglais",
#  '',
#  '267',
#  '00:09:00,707 --> 00:09:03,198',
#  '',
#  '',
#  '268',
#  '00:09:03,198 --> 00:09:05,415',
#  'avec un un joueur fidjien qui saigne Thierry ',
#  '',
#  '269',
#  '00:09:05,415 --> 00:09:05,551',
#  '',
#  '',
#  '270',
#  '00:09:05,551 --> 00:09:07,289',
#  'et qui va sortir pour quelques minutes',
#  '',
#  '271',
#  '00:09:07,289 --> 00:09:07,834',
#  '',
#  '',
#  '272',
#  '00:09:07,834 --> 00:09:10,974',
#  u'remplac\xe9 provisoirement par euh Norman Ligairi',
#  '',
#  '273',
#  '00:09:10,974 --> 00:09:11,408',
#  '',
#  '',
#  '274',
#  '00:09:11,408 --> 00:09:12,964',
#  u'un joueur qui \xe9volue \xe0 Brive',
#  '',
#  '275',
#  '00:09:12,964 --> 00:09:15,519',
#  '',
#  '',
#  '276',
#  '00:09:15,519 --> 00:09:16,821',
#  "et c'est Kameli Ratuvou",
#  '',
#  '277',
#  '00:09:16,821 --> 00:09:17,331',
#  '',
#  '',
#  '278',
#  '00:09:17,331 --> 00:09:19,411',
#  u"l'arri\xe8re des Saracens qui est sorti",
#  '',
#  '279',
#  '00:09:19,411 --> 00:09:19,957',
#  '',
#  '',
#  '280',
#  '00:09:19,957 --> 00:09:20,992',
#  'allez Delasau',
#  '',
#  '281',
#  '00:09:20,992 --> 00:09:24,548',
#  '',
#  '',
#  '282',
#  '00:09:24,548 --> 00:09:27,671',
#  u'avec Rauluni pour \xe9jecter ce ballon ils ont des difficult\xe9s',
#  '',
#  '283',
#  '00:09:27,671 --> 00:09:28,426',
#  '',
#  '',
#  '284',
#  '00:09:28,426 --> 00:09:30,128',
#  u"\xe7a y est c'est propre pour Little",
#  '',
#  '285',
#  '00:09:30,128 --> 00:09:30,941',
#  '',
#  '',
#  '286',
#  '00:09:30,941 --> 00:09:32,177',
#  u"la touche n'est toujours pas trouv\xe9e",
#  '',
#  '287',
#  '00:09:32,177 --> 00:09:34,265',
#  '',
#  '',
#  '288',
#  '00:09:34,265 --> 00:09:36,122',
#  'et la relance hein avec Endo',
#  '',
#  '289',
#  '00:09:36,122 --> 00:09:36,567',
#  '',
#  '',
#  '290',
#  '00:09:36,567 --> 00:09:38,224',
#  'et percussion de Loamanu',
#  '',
#  '291',
#  '00:09:38,224 --> 00:09:42,830',
#  '',
#  '',
#  '292',
#  '00:09:42,830 --> 00:09:44,828',
#  "avec le bras tendu de l'arbitre vous le voyez",
#  '',
#  '293',
#  '00:09:44,828 --> 00:09:45,800',
#  '',
#  '',
#  '294',
#  '00:09:45,800 --> 00:09:47,823',
#  u'les Fidjiens qui ont arrach\xe9 cette balle',
#  '',
#  '295',
#  '00:09:47,823 --> 00:09:49,875',
#  '',
#  '',
#  '296',
#  '00:09:49,875 --> 00:09:51,583',
#  'mis au sol euh Leawere',
#  '',
#  '297',
#  '00:09:51,583 --> 00:09:52,603',
#  '',
#  '',
#  '298',
#  '00:09:52,603 --> 00:09:53,330',
#  'et on sort ',
#  '',
#  '299',
#  '00:09:53,330 --> 00:09:53,464',
#  '',
#  '',
#  '300',
#  '00:09:53,464 --> 00:09:54,650',
#  u'avec euh Ba\xef ',
#  '',
#  '301',
#  '00:09:54,650 --> 00:09:54,847',
#  '',
#  '',
#  '302',
#  '00:09:54,847 --> 00:09:55,694',
#  'Rabeni',
#  '',
#  '303',
#  '00:09:55,694 --> 00:09:56,188',
#  '',
#  '',
#  '304',
#  '00:09:56,188 --> 00:09:57,091',
#  u'Ba\xef de nouveau',
#  '',
#  '305',
#  '00:09:57,091 --> 00:10:00,080',
#  '',
#  '',
#  '306',
#  '00:10:00,080 --> 00:10:03,118',
#  u'ballon qui sort relativement rapidement pour permettre \xe0 \xe0 Rauluni',
#  '',
#  '307',
#  '00:10:03,118 --> 00:10:03,405',
#  '',
#  '',
#  '308',
#  '00:10:03,405 --> 00:10:04,960',
#  'de relancer le jeu et la faute',
#  '',
#  '309',
#  '00:10:04,960 --> 00:10:05,189',
#  '',
#  '',
#  '310',
#  '00:10:05,189 --> 00:10:06,084',
#  'faute de Rabeni',
#  '',
#  '311',
#  '00:10:06,084 --> 00:10:07,342',
#  '',
#  '',
#  '312',
#  '00:10:07,342 --> 00:10:11,158',
#  u'oui alors vous verrez euh les Fidjiens bien s\xfbr dans les sorties rapides pourquoi parce que',
#  '',
#  '313',
#  '00:10:11,158 --> 00:10:11,446',
#  '',
#  '',
#  '314',
#  '00:10:11,446 --> 00:10:12,035',
#  'on arrive',
#  '',
#  '315',
#  '00:10:12,035 --> 00:10:12,299',
#  '',
#  '',
#  '316',
#  '00:10:12,299 --> 00:10:13,845',
#  'sur le porteur du ballon qui va au sol',
#  '',
#  '317',
#  '00:10:13,845 --> 00:10:14,023',
#  '',
#  '',
#  '318',
#  '00:10:14,023 --> 00:10:16,046',
#  'le joueur ou les deux joueurs suivants arrivent agressifs',
#  '',
#  '319',
#  '00:10:16,046 --> 00:10:16,353',
#  '',
#  '',
#  '320',
#  '00:10:16,353 --> 00:10:19,755',
#  u"pour ce qu'on appelle nettoyer c'est-\xe0-dire sortir les joueurs adverses de la zone du ballon",
#  '',
#  '321',
#  '00:10:19,755 --> 00:10:20,203',
#  '',
#  '',
#  '322',
#  '00:10:20,203 --> 00:10:23,594',
#  u"pour pas qu'ils y mettent les mains dessus et l\xe0 le ballon est propre pour une deuxi\xe8me phase de jeu",
#  '',
#  '323',
#  '00:10:23,594 --> 00:10:23,996',
#  '',
#  '',
#  '324',
#  '00:10:23,996 --> 00:10:26,976',
#  u"c'est \xe7a les ballons rapides \xe7a demande une technicit\xe9 du joueur au sol",
#  '',
#  '325',
#  '00:10:26,976 --> 00:10:27,167',
#  '',
#  '',
#  '326',
#  '00:10:27,167 --> 00:10:28,340',
#  'de mettre le ballon au bon endroit',
#  '',
#  '327',
#  '00:10:28,340 --> 00:10:28,684',
#  '',
#  '',
#  '328',
#  '00:10:28,684 --> 00:10:31,544',
#  "et les suivants de nettoyer agressif pour sortir l'adversaire",
#  '',
#  '329',
#  '00:10:31,544 --> 00:10:32,046',
#  '',
#  '',
#  '330',
#  '00:10:32,046 --> 00:10:36,844',
#  u"c'est le jeu fidjien on le sait il fait beau en plus donc euh tout est r\xe9uni aujourd'hui pour avoir un excellent spectacle",
#  '',
#  '331',
#  '00:10:36,844 --> 00:10:37,146',
#  '',
#  '',
#  '332',
#  '00:10:37,146 --> 00:10:38,300',
#  "oh le jeu fidjien c'est",
#  '',
#  '333',
#  '00:10:38,300 --> 00:10:38,708',
#  '',
#  '',
#  '334',
#  '00:10:38,708 --> 00:10:39,422',
#  'des essais',
#  '',
#  '335',
#  '00:10:39,422 --> 00:10:39,638',
#  '',
#  '',
#  '336',
#  '00:10:39,638 --> 00:10:41,958',
#  u'des spect- et du spectacle \xe9galement alors que vous le voyez',
#  '',
#  '337',
#  '00:10:41,958 --> 00:10:42,343',
#  '',
#  '',
#  '338',
#  '00:10:42,343 --> 00:10:44,978',
#  u'le pack fidjien d\xe9passe les neuf cents kilos',
#  '',
#  '339',
#  '00:10:44,978 --> 00:10:46,675',
#  '',
#  '',
#  '340',
#  '00:10:46,675 --> 00:10:50,038',
#  u'allez premi\xe8re m\xeal\xe9e ferm\xe9e avec une premi\xe8re indication des forces en pr\xe9sence',
#  '',
#  '341',
#  '00:10:50,038 --> 00:10:50,637',
#  '',
#  '',
#  '342',
#  '00:10:50,637 --> 00:10:51,504',
#  u'les m\xeal\xe9s ont boug\xe9',
#  '',
#  '343',
#  '00:10:51,504 --> 00:10:51,969',
#  '',
#  '',
#  '344',
#  '00:10:51,969 --> 00:10:52,510',
#  u'Ba\xef',
#  '',
#  '345',
#  '00:10:52,510 --> 00:10:52,784',
#  '',
#  '',
#  '346',
#  '00:10:52,784 --> 00:10:56,127',
#  u'en p\xe9n\xe9tration encore une faute de main de Seru Rabeni',
#  '',
#  '347',
#  '00:10:56,127 --> 00:10:58,074',
#  '',
#  '',
#  '348',
#  '00:10:58,074 --> 00:10:59,434',
#  "et le contre japonais n'ira pas loin",
#  '',
#  '349',
#  '00:10:59,434 --> 00:11:00,065',
#  '',
#  '',
#  '350',
#  '00:11:00,065 --> 00:11:01,620',
#  u"c'est le probl\xe8me de ces Fidjiens tr\xe8s joueurs",
#  '',
#  '351',
#  '00:11:01,620 --> 00:11:02,104',
#  '',
#  '',
#  '352',
#  '00:11:02,104 --> 00:11:02,907',
#  'qui sont capables de',
#  '',
#  '353',
#  '00:11:02,907 --> 00:11:03,386',
#  '',
#  '',
#  '354',
#  '00:11:03,386 --> 00:11:05,342',
#  'tous les plus beaux gestes du rugby mais aussi euh',
#  '',
#  '355',
#  '00:11:05,342 --> 00:11:06,204',
#  '',
#  '',
#  '356',
#  '00:11:06,204 --> 00:11:06,773',
#  'les plus',
#  '',
#  '357',
#  '00:11:06,773 --> 00:11:07,214',
#  '',
#  '',
#  '358',
#  '00:11:07,214 --> 00:11:10,711',
#  u"les fautes les plus simples qu'on apprend \xe0 l'\xe9cole de rugby se saisir d'un ballon",
#  '',
#  '359',
#  '00:11:10,711 --> 00:11:11,310',
#  '',
#  '',
#  '360',
#  '00:11:11,310 --> 00:11:13,831',
#  u"et oui si on ne se saisit pas le ballon c'est difficile de cr\xe9er des temps de jeu",
#  '',
#  '361',
#  '00:11:13,831 --> 00:11:14,391',
#  '',
#  '',
#  '362',
#  '00:11:14,391 --> 00:11:19,896',
#  u'en tout cas ces Fidjiens cr\xe9ent beaucoup on le voit une fois euh une crois\xe9e une fois le jeu au large alternance du jeu',
#  '',
#  '363',
#  '00:11:19,896 --> 00:11:20,189',
#  '',
#  '',
#  '364',
#  '00:11:20,189 --> 00:11:21,127',
#  'intelligence du jeu ',
#  '',
#  '365',
#  '00:11:21,127 --> 00:11:21,726',
#  '',
#  '',
#  '366',
#  '00:11:21,726 --> 00:11:22,602',
#  u'attention \xe0 la finition',
#  '',
#  '367',
#  '00:11:22,602 --> 00:11:23,084',
#  '',
#  '',
#  '368',
#  '00:11:23,084 --> 00:11:25,552',
#  "et on le sait hein c'est traditionnel ces Fidjiens ils sont euh ",
#  '',
#  '369',
#  '00:11:25,552 --> 00:11:25,762',
#  '',
#  '',
#  '370',
#  '00:11:25,762 --> 00:11:26,490',
#  'talentueux',
#  '',
#  '371',
#  '00:11:26,490 --> 00:11:26,831',
#  '',
#  '',
#  '372',
#  '00:11:26,831 --> 00:11:30,050',
#  u'parfois g\xe9niaux mais souvent inconstants et produisant parfois des ',
#  '',
#  '373',
#  '00:11:30,050 --> 00:11:30,499',
#  '',
#  '',
#  '374',
#  '00:11:30,499 --> 00:11:31,197',
#  'des fautes de main',
#  '',
#  '375',
#  '00:11:31,197 --> 00:11:31,398',
#  '',
#  '',
#  '376',
#  '00:11:31,398 --> 00:11:34,206',
#  u"au plus mauvais moment l'\xe9quipe de France en a profit\xe9 il y a quelques ann\xe9es",
#  '',
#  '377',
#  '00:11:34,206 --> 00:11:34,729',
#  '',
#  '',
#  '378',
#  '00:11:34,729 --> 00:11:36,571',
#  u"l'\xe9quipe de France qui en quart de finale en",
#  '',
#  '379',
#  '00:11:36,571 --> 00:11:37,479',
#  'quatre-vingt-sept avait ',
#  '',
#  '380',
#  '00:11:36,571 --> 00:11:37,479',
#  'quatre-vingt-sept',
#  '',
#  '381',
#  '00:11:37,479 --> 00:11:39,312',
#  u'eu du mal \xe0 battre cette \xe9quipe fidjienne',
#  '',
#  '382',
#  '00:11:39,312 --> 00:11:40,121',
#  '',
#  '',
#  '383',
#  '00:11:40,121 --> 00:11:44,526',
#  u"elle \xe9tait revenue en jeu simple c'est-\xe0-dire de percussion de jeu au ras avec des Rodriguez de gens euh",
#  '',
#  '384',
#  '00:11:44,526 --> 00:11:44,977',
#  '',
#  '',
#  '385',
#  '00:11:44,977 --> 00:11:45,796',
#  u'p\xe9n\xe9trants comme \xe7a',
#  '',
#  '386',
#  '00:11:45,796 --> 00:11:46,131',
#  '',
#  '',
#  '387',
#  '00:11:46,131 --> 00:11:48,576',
#  'pour battre ces Figjiens qui eux donnaient un spectacle euh',
#  '',
#  '388',
#  '00:11:48,576 --> 00:11:48,843',
#  '',
#  '',
#  '389',
#  '00:11:48,843 --> 00:11:51,986',
#  u'sur les largeurs ol\xe9 ol\xe9 euh rugby \xe0 sept des passes dans le dos euh',
#  '',
#  '390',
#  '00:11:51,986 --> 00:11:52,454',
#  '',
#  '',
#  '391',
#  '00:11:52,454 --> 00:11:55,085',
#  u"d'ailleurs un joueur fidjien avait \xe9chapp\xe9 m\xeame le ballon en le tenant du bout de",
#  '',
#  '392',
#  '00:11:55,085 --> 00:11:55,340',
#  '',
#  '',
#  '393',
#  '00:11:55,340 --> 00:11:56,598',
#  'du bout de sa main en courrant ',
#  '',
#  '394',
#  '00:11:56,598 --> 00:11:57,105',
#  '',
#  '',
#  '395',
#  '00:11:57,105 --> 00:11:57,580',
#  'tant mieux pour nous',
#  '',
#  '396',
#  '00:11:57,580 --> 00:11:59,165',
#  '',
#  '',
#  '397',
#  '00:11:59,165 --> 00:12:00,425',
#  u'allez m\xeal\xe9e de nouveau',
#  '',
#  '398',
#  '00:12:00,425 --> 00:12:01,360',
#  '',
#  '',
#  '399',
#  '00:12:01,360 --> 00:12:02,350',
#  'avec introduction',
#  '',
#  '400',
#  '00:12:02,350 --> 00:12:02,825',
#  '',
#  '',
#  '401',
#  '00:12:02,825 --> 00:12:04,533',
#  'pour euh Tomoki Yoshida',
#  '',
#  '402',
#  '00:12:04,533 --> 00:12:05,671',
#  '',
#  '',
#  '403',
#  '00:12:05,671 --> 00:12:06,939',
#  u'le demi de m\xeal\xe9e japonais',
#  '',
#  '404',
#  '00:12:06,939 --> 00:12:12,310',
#  '',
#  '',
#  '405',
#  '00:12:12,310 --> 00:12:15,074',
#  "allez sortie pour Bryce Robins sur le demi d'ouverture",
#  '',
#  '406',
#  '00:12:15,074 --> 00:12:15,236',
#  '',
#  '',
#  '407',
#  '00:12:15,236 --> 00:12:16,246',
#  'et le long coup de pied ',
#  '',
#  '408',
#  '00:12:16,246 --> 00:12:16,444',
#  '',
#  '',
#  '409',
#  '00:12:16,444 --> 00:12:17,338',
#  'de Onishi',
#  '',
#  '410',
#  '00:12:17,338 --> 00:12:18,616',
#  '',
#  '',
#  '411',
#  '00:12:18,616 --> 00:12:20,803',
#  u'coup de pied qui sort en touche au-del\xe0 de la m\xe9diane',
#  '',
#  '412',
#  '00:12:20,803 --> 00:12:21,880',
#  '',
#  '',
#  '413',
#  '00:12:21,880 --> 00:12:23,607',
#  u'voil\xe0 une basique int\xe9resssante',
#  '',
#  '414',
#  '00:12:23,607 --> 00:12:24,133',
#  '',
#  '',
#  '415',
#  '00:12:24,133 --> 00:12:25,312',
#  u"qu'on avait un peu de mal \xe0 ",
#  '',
#  '416',
#  '00:12:25,312 --> 00:12:25,666',
#  '',
#  '',
#  '417',
#  '00:12:25,666 --> 00:12:29,229',
#  u'\xe0 utiliser nous Fran\xe7ais sur notre premier match mais que toutes les \xe9quipes utilisent \xe0 savoir',
#  '',
#  '418',
#  '00:12:29,229 --> 00:12:30,062',
#  '',
#  '',
#  '419',
#  '00:12:30,062 --> 00:12:30,597',
#  'le dix qui',
#  '',
#  '420',
#  '00:12:30,597 --> 00:12:30,902',
#  '',
#  '',
#  '421',
#  '00:12:30,902 --> 00:12:34,130',
#  u'donne sur une passe \xe0 son premier centre qui tape en touche alors pourquoi il le fait',
#  '',
#  '422',
#  '00:12:34,130 --> 00:12:34,490',
#  '',
#  '',
#  '423',
#  '00:12:34,490 --> 00:12:39,501',
#  u"parce que \xe0 partir du moment o\xf9 le dix donne le ballon au joueur suivant l'ailier est oblig\xe9 de monter donc on peut taper derri\xe8re son dos",
#  '',
#  '424',
#  '00:12:39,501 --> 00:12:40,123',
#  '',
#  '',
#  '425',
#  '00:12:40,123 --> 00:12:44,041',
#  u"tant que le dix n'a pas tap\xe9 le di- le l'ailier reste l\xe0 voil\xe0 pourquoi c'est int\xe9ressant de faire une passe",
#  '',
#  '426',
#  '00:12:44,041 --> 00:12:44,209',
#  '',
#  '',
#  '427',
#  '00:12:44,209 --> 00:12:46,500',
#  'ah la prise de balle elle est belle celle de Kele Leawere',
#  '',
#  '428',
#  '00:12:46,500 --> 00:12:47,518',
#  '',
#  '',
#  '429',
#  '00:12:47,518 --> 00:12:48,786',
#  'lancement de jeu dynamique',
#  '',
#  '430',
#  '00:12:48,786 --> 00:12:49,149',
#  '',
#  '',
#  '431',
#  '00:12:49,149 --> 00:12:50,105',
#  'avec Rauluni',
#  '',
#  '432',
#  '00:12:50,105 --> 00:12:51,061',
#  '',
#  '',
#  '433',
#  '00:12:51,061 --> 00:12:53,679',
#  'encore une approximation au niveau de la passe',
#  '',
#  '434',
#  '00:12:53,679 --> 00:12:55,903',
#  '',
#  '',
#  '435',
#  '00:12:55,903 --> 00:12:57,047',
#  'Rauluni avec euh',
#  '',
#  '436',
#  '00:12:57,047 --> 00:12:57,324',
#  '',
#  '',
#  '437',
#  '00:12:57,324 --> 00:12:58,420',
#  'Little',
#  '',
#  '438',
#  '00:12:58,420 --> 00:12:58,707',
#  '',
#  '',
#  '439',
#  '00:12:58,707 --> 00:13:00,597',
#  u'et l\xe0 une troisi\xe8me fois Seru Rabeni',
#  '',
#  '440',
#  '00:13:00,597 --> 00:13:01,492',
#  '',
#  '',
#  '441',
#  '00:13:01,492 --> 00:13:02,167',
#  'qui va rendre ',
#  '',
#  '442',
#  '00:13:02,167 --> 00:13:02,349',
#  '',
#  '',
#  '443',
#  '00:13:02,349 --> 00:13:04,420',
#  u'malgr\xe9 lui \xe9videmment le ballon aux Japonais',
#  '',
#  '444',
#  '00:13:04,420 --> 00:13:06,065',
#  '',
#  '',
#  '445',
#  '00:13:06,065 --> 00:13:07,898',
#  u'coup de pied \xe0 suivre euh de Yoshida',
#  '',
#  '446',
#  '00:13:07,898 --> 00:13:08,400',
#  '',
#  '',
#  '447',
#  '00:13:08,400 --> 00:13:09,166',
#  'un rebond',
#  '',
#  '448',
#  '00:13:09,166 --> 00:13:09,448',
#  '',
#  '',
#  '449',
#  '00:13:09,448 --> 00:13:10,463',
#  u'qui est n\xe9goci\xe9',
#  '',
#  '450',
#  '00:13:10,463 --> 00:13:10,641',
#  '',
#  '',
#  '451',
#  '00:13:10,641 --> 00:13:12,407',
#  'euh par euh Ligairi',
#  '',
#  '452',
#  '00:13:12,407 --> 00:13:12,755',
#  '',
#  '',
#  '453',
#  '00:13:12,755 --> 00:13:15,396',
#  u"et d\xe9gag\xe9 finalement il s'en sortent bien l\xe0 les Fidjiens ",
#  '',
#  '454',
#  '00:13:15,396 --> 00:13:18,893',
#  '',
#  '',
#  '455',
#  '00:13:18,893 --> 00:13:19,665',
#  'Yoshida',
#  '',
#  '456',
#  '00:13:19,665 --> 00:13:20,637',
#  '',
#  '',
#  '457',
#  '00:13:20,637 --> 00:13:24,627',
#  u"attention cette passe c'\xe9tait pas un cadeau pour euh Takuro Miuchi le capitaine",
#  '',
#  '458',
#  '00:13:24,627 --> 00:13:28,057',
#  '',
#  '',
#  '459',
#  '00:13:28,057 --> 00:13:31,047',
#  'non le Japonais qui est mis en touche la puissance physique fidjienne',
#  '',
#  '460',
#  '00:13:31,047 --> 00:13:32,267',
#  '',
#  '',
#  '461',
#  '00:13:32,267 --> 00:13:33,660',
#  u"pour l'instant fait la diff\xe9rence",
#  '',
#  '462',
#  '00:13:33,660 --> 00:13:34,168',
#  '',
#  '',
#  '463',
#  '00:13:34,168 --> 00:13:35,360',
#  ...]

# %%
with codecs.open(fTRS.replace(".trs",".srt"),"w",encoding="utf8") as outFile:
    text="\n".join(srtLines)
    outFile.write(text)
    # for line in srtLines:
    #     outFile.write(line+"\n")
