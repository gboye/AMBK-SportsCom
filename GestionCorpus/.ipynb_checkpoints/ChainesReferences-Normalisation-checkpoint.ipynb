# %%
import pandas as pd
import numpy as np
import re

# %%
repChaines="/Users/gilles/pCloud Drive/FOD/GB/Copy/Recherche/Rugby/ChainesReferences/"
fChaines=repChaines+"FR-NZ-en.xlsx"

dfBrut=pd.read_excel(fChaines, sheet_name="Sheet1")

# %%
colSelection=dfBrut.columns[:10]
print ", ".join(colSelection)
dfChaines=dfBrut[colSelection]
dfChaines.head(25)
# Out:
# Transcription, Cat, Lemme, Modif, Referent, numChaineRef, numChaine, chaineIndex, chaineDep, MentionChaine
#    Transcription   Cat      Lemme Modif Referent numChaineRef  numChaine  \
# 0         nearly    RB     nearly   NaN      NaN          NaN        NaN
# 1          there    RB      there   NaN      NaN          NaN        NaN
# 2             in    IN         in   NaN      NaN          NaN        NaN
# 3         charge    NN     charge   NaN      NaN          NaN        NaN
# 4             of    IN         of   NaN      NaN          NaN        NaN
# 5            the    DT        the   NaN      NaN          NaN        NaN
# 6         second    JJ     second   NaN      NaN          NaN        NaN
# 7        weekend    NN    weekend   NaN      NaN          NaN        NaN
# 8        running    NN    running   NaN      NaN          NaN        NaN
# 9              .  SENT          .   NaN      NaN          NaN        NaN
# ...

# %%
dfChaines.numChaine=dfChaines.numChaine.astype("Int64")
dfChaines.chaineDep=dfChaines.chaineDep.astype("Int64")
dfChaines.MentionChaine=dfChaines.MentionChaine.astype("Int64")


dfChaines["newNumChaine"]=pd.np.nan
dfChaines["newChaineIndex"]=pd.np.nan
dfChaines["newChaineDep"]=pd.np.nan
dfChaines["newChaineApp"]=pd.np.nan

# %%
dfChaines=dfChaines[[ \
                     "Modif", "Referent", \
                     "newNumChaine", "newChaineIndex", "newChaineDep", "newChaineApp", \
                     "numChaineRef", "numChaine", "chaineIndex", "chaineDep", "MentionChaine", \
                     "Transcription", "Cat", "Lemme", \
                    ]]

# %%
dfChaines.head(50)
# Out:
#    Modif Referent  newNumChaine  newChaineIndex  newChaineDep  newChaineApp  \
# 0    NaN      NaN           NaN             NaN           NaN           NaN
# 1    NaN      NaN           NaN             NaN           NaN           NaN
# 2    NaN      NaN           NaN             NaN           NaN           NaN
# 3    NaN      NaN           NaN             NaN           NaN           NaN
# 4    NaN      NaN           NaN             NaN           NaN           NaN
# 5    NaN      NaN           NaN             NaN           NaN           NaN
# 6    NaN      NaN           NaN             NaN           NaN           NaN
# 7    NaN      NaN           NaN             NaN           NaN           NaN
# 8    NaN      NaN           NaN             NaN           NaN           NaN
# 9    NaN      NaN           NaN             NaN           NaN           NaN
# 10     A    A-NO1           NaN             NaN           NaN           NaN
# ...

# %%
dfChaines.numChaine=dfChaines[dfChaines.Referent.notnull()].numChaine.ffill()

# %% [raw]
# print '["'+'", "'.join(dfChaines.columns.tolist())+'"]'

# %%
def updateRows(row):
    numChaine=np.NaN
    chaineIndex=np.NaN
    chaineDep=np.NaN
    idx=row.index
    if pd.isna(row["Modif"]):
        row["newNumChaine"]=row["numChaine"]
        row["newChaineIndex"]=row["chaineIndex"]
        row["newChaineDep"]=row["chaineDep"]
    else:
        modif=row["Modif"]
        m=re.match(ur"R\+(\d+)",modif)
        if row["Modif"]=="A":
            row["newNumChaine"]=np.NaN
            row["newChaineApp"]=row["numChaine"]
        elif row["Modif"]=="D":
            row["Referent"]=np.NaN
        elif m:
            row["newNumChaine"]=int(m.group(1))            
            row["newChaineIndex"]=row["chaineIndex"]
            row["newChaineDep"]=row["chaineDep"]
        else:
            row["newNumChaine"]=row["numChaine"]
            row["newChaineIndex"]=row["chaineIndex"]
            row["newChaineDep"]=row["chaineDep"]            
    return row

# %%
dfResult=dfChaines.apply(updateRows,axis=1)

# %%
dfResult.to_excel(fChaines.replace(".xls","-GB.xls"))
