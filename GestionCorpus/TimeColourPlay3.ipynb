# %% [markdown]
# # Timeline des types de Commentaires
# => ATTENTION LA TIMELINE EST DIFFERENTE ENTRE LE TRS ET LA VIDEO
# - Première mi-temps TRS "0.000" => Vidéo "00:11:52.4"
# - Deuxième mi-temps TRS "3257.608" => Vidéo "00:57:22.70"

# %%
import pandas as pd
from numpy import arange
import codecs

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle

# %%
commentairesName="/Users/gilles/Copy/Recherche/Rugby/Videos/CorrespondancesAction-PlayVsColourVsSupportaire.csv"
commentairesTypesName="/Users/gilles/Copy/Recherche/Rugby/CorpusRugby2007/Timeline-TypeCommentaires3.pkl"
commentaireActionName="/Users/gilles/Copy/Recherche/Rugby/CorpusRugby2007/Timeline-CommentaireAction3.pkl"
commentairesFile=codecs.open(commentairesName,"r",encoding="utf8")
commentaires=commentairesFile.readlines()

# %%
finMT1=273300
debutMT2=324500

# %%
initialTime="00:11:52.4"
decalage=0
def decodeTime(temps):
    (heure,minute,seconde)=temps.split(":")
    result=int(100*(3600*int(heure)+60*int(minute)+float(seconde))-decalage)
    return result

decalage=decodeTime(initialTime)
print decalage, decodeTime(initialTime)
# Out:
# 71240 0

# %%
timeMT1="00:11:52.40"
timeMT2="00:57:22.70"
debutMT2=325760.8
decalage1=0
decalage2=600000
def decodeTime(temps):
    (heure,minute,seconde)=temps.split(":")
    timeCode=int(100*(3600*int(heure)+60*int(minute)+float(seconde))-decalage1)
    if timeCode>=decalage2:
        timeCode=timeCode-decalage2+int(debutMT2)
    return timeCode

decalage1=decodeTime(timeMT1)
decalage2=decodeTime(timeMT2)
print decalage1, decodeTime(timeMT1)
print decalage2, decodeTime(timeMT2)
# Out:
# 71240 0
# 273030 325760

# %%
def sliceDataFrame(df,debut,fin,seuil,colonnes):
    return df[df.index<fin][df[df.index<fin].index>=debut][colonnes].dropna(thresh=seuil)

# %%
#timeLine=pd.DataFrame(index=[float(i)/100 for i in range(6500000)],columns=["début","fin","V1","V2","V3"])
timeLine=pd.DataFrame(columns=["timecode","début","fin","numEvent","événement","numAct","action","commentaires","numSpk","Spk","texte","PxP","colour","support"])

# %%
for ligne in commentaires[1:]:
    elements=ligne.strip().split(";")
    if elements[14]=="":
        typeCommentaire=elements[13].lower()
    else:
        typeCommentaire=elements[14].lower()

    if typeCommentaire in ["play by play","ponctuant"]:
        boolPlay=1
        boolColour=np.nan
        boolSupport=np.nan
    elif typeCommentaire in ["colour commentary","color commentary"]:
        boolPlay=np.nan
        boolColour=1
        boolSupport=np.nan
    elif typeCommentaire in ["supportaire"]:
        boolPlay=np.nan
        boolColour=np.nan
        boolSupport=1
    elif typeCommentaire=="":
        boolPlay=np.nan
        boolColour=np.nan
        boolSupport=np.nan
    else:
        print "commentaire non-standard",typeCommentaire, ligne
    
    if " " in elements[5]:
        (numEvent,Event)=elements[5].split(" ",1)
        numEvent=int(numEvent)
    else:
        (numEvent,Event)=(np.nan,np.nan)
    if " " in elements[6]:
        (numAction,Action)=elements[6].split(" ",1)
        numAction=int(numAction.strip("A-"))
    else:
        (numAction,Action)=(np.nan,np.nan)
    if " " in elements[8]:
        (numSpk,texte)=elements[8].split(" ",1)
        if "-" in numSpk:
            (spk,numSpk)=numSpk.split("-",1)
            numSpk=int(numSpk)
        else:
            numSpk=np.nan
            spk=numSpk
    else:
        (numSpk,texte)=(np.nan,np.nan)

    timeLine.loc[decodeTime(elements[1])]=[elements[1],decodeTime(elements[1]),decodeTime(elements[2]),numEvent,Event,numAction,Action,elements[7].lower() ,numSpk,spk,texte, boolPlay, boolColour, boolSupport]

# %%
timeLine[timeLine.index<3400].dropna(subset=["PxP"]).iloc[-1]["fin"]

# %%
timeLine
# Out:
#            timecode   début     fin numEvent     événement numAct  \
# 3220    00:12:24.60    3220    3592      NaN           NaN    NaN
# 3254    00:12:24.94    3254    3690        1  coup d'envoi      1
# 3616    00:12:28.56    3616    3852      NaN           NaN    NaN
# 3694    00:12:29.34    3694    3738        1  coup d'envoi      2
# 3806    00:12:30.46    3806    4042        2  regroupement      3
# 3960    00:12:32.00    3960    4100      NaN           NaN    NaN
# 4042    00:12:32.82    4042    4070        2  regroupement      4
# 4070    00:12:33.10    4070    4146        3         porté      5
# 4146    00:12:33.86    4146    4214        4  regroupement      6
# 4160    00:12:34.00    4160    4216      NaN           NaN    NaN
# 4218    00:12:34.58    4218    4434        4  regroupement      7
# 4232    00:12:34.72    4232    4384      NaN           NaN    NaN
# 4456    00:12:36.96    4456    4576      NaN           NaN    NaN
# 4462    00:12:37.02    4462    4478        4  regroupement      8
# 4482    00:12:37.22    4482    4578        5         passe      9
# 4582    00:12:38.22    4582    4606        5         passe     10
# 4610    00:12:38.50    4610    5030        6  coup de pied     11
# 4656    00:12:38.96    4656    4780      NaN           NaN    NaN
# 4848    00:12:40.88    4848    5000      NaN           NaN    NaN
# 5030    00:12:42.70    5030    5126        7        touche     12
# 5056    00:12:42.96    5056    5228      NaN           NaN    NaN
# 5130    00:12:43.70    5130    7634        7       touche      13
# 5300    00:12:45.40    5300    5664      NaN           NaN    NaN
# 5708    00:12:49.48    5708    5776      NaN           NaN    NaN
# 5792    00:12:50.32    5792    5904      NaN           NaN    NaN
# 5936    00:12:51.76    5936    6004      NaN           NaN    NaN
# 6236    00:12:54.76    6236    6308      NaN           NaN    NaN
# 6324    00:12:55.64    6324    6480      NaN           NaN    NaN
# 6512    00:12:57.52    6512    6616      NaN           NaN    NaN
# 6672    00:12:59.12    6672    6796      NaN           NaN    NaN
# ...             ...     ...     ...      ...           ...    ...
# 638352  01:49:28.62  638352  638596      NaN           NaN    NaN
# 638624  01:49:31.34  638624  638672      NaN           NaN    NaN
# 638684  01:49:31.94  638684  638784      NaN           NaN    NaN
# 638872  01:49:33.82  638872  639276      NaN           NaN    NaN
# 639332  01:49:38.42  639332  639512      NaN           NaN    NaN
# 639604  01:49:41.14  639604  639832      NaN           NaN    NaN
# 639888  01:49:43.98  639888  640048      NaN           NaN    NaN
# 640136  01:49:46.46  640136  640240      NaN           NaN    NaN
# 640264  01:49:47.74  640264  640384      NaN           NaN    NaN
# 640416  01:49:49.26  640416  640532      NaN           NaN    NaN
# 640576  01:49:50.86  640576  640656      NaN           NaN    NaN
# 640704  01:49:52.14  640704  640860      NaN           NaN    NaN
# 640884  01:49:53.94  640884  641108      NaN           NaN    NaN
# 641156  01:49:56.66  641156  641268      NaN           NaN    NaN
# 641296  01:49:58.06  641296  641508      NaN           NaN    NaN
# 641532  01:50:00.42  641532  641716      NaN           NaN    NaN
# 641748  01:50:02.58  641748  641936      NaN           NaN    NaN
# 641964  01:50:04.74  641964  642052      NaN           NaN    NaN
# 642088  01:50:05.98  642088  642360      NaN           NaN    NaN
# 642396  01:50:09.06  642396  642480      NaN           NaN    NaN
# 642516  01:50:10.26  642516  642632      NaN           NaN    NaN
# 642672  01:50:11.82  642672  642780      NaN           NaN    NaN
# 642812  01:50:13.22  642812  642928      NaN           NaN    NaN
# 642948  01:50:14.58  642948  643000      NaN           NaN    NaN
# 643024  01:50:15.34  643024  643096      NaN           NaN    NaN
# 643132  01:50:16.42  643132  643232      NaN           NaN    NaN
# 643248  01:50:17.58  643248  643300      NaN           NaN    NaN
# 643324  01:50:18.34  643324  643452      NaN           NaN    NaN
# 643480  01:50:19.90  643480  643556      NaN           NaN    NaN
# 643580  01:50:20.90  643580  643704      NaN           NaN    NaN
#
#                     action commentaires  numSpk   Spk  \
# 3220                   NaN                    1  spk1
# 3254    grand coup de pied     spk1-002     NaN  spk1
# 3616                   NaN                    2  spk1
# 3694             réception                  NaN  spk1
# 3806          regroupement                  NaN  spk1
# 3960                   NaN                    1  spk2
# 4042            extraction                  NaN  spk2
# 4070                 porté     spk1-003     NaN  spk2
# 4146              plaquage                  NaN  spk2
# 4160                   NaN                    2  spk2
# 4218          regroupement                  NaN  spk2
# 4232                   NaN                    3  spk1
# 4456                   NaN                    4  spk1
# 4462            extraction                  NaN  spk1
# 4482                 passe     spk1-005     NaN  spk1
# 4582             réception                  NaN  spk1
# 4610    grand coup de pied     spk1-006     NaN  spk1
# 4656                   NaN                    5  spk1
# 4848                   NaN                    6  spk1
# 5030                sortie    spk1-007      NaN  spk1
# 5056                   NaN                    7  spk1
# 5130         mise en ligne                  NaN  spk1
# 5300                   NaN                    8  spk1
# 5708                   NaN                    9  spk1
# 5792                   NaN                   10  spk1
# 5936                   NaN                   11  spk1
# 6236                   NaN                   12  spk1
# 6324                   NaN                   13  spk1
# 6512                   NaN                   14  spk1
# 6672                   NaN                   15  spk1
# ...                    ...          ...     ...   ...
# 638352                 NaN                 1577  spk1
# 638624                 NaN                 1578  spk1
# 638684                 NaN                 1579  spk1
# 638872                 NaN                 1580  spk1
# 639332                 NaN                 1581  spk1
# 639604                 NaN                 1582  spk1
# 639888                 NaN                 1583  spk1
# 640136                 NaN                 1584  spk1
# 640264                 NaN                 1585  spk1
# 640416                 NaN                 1586  spk1
# 640576                 NaN                 1587  spk1
# 640704                 NaN                 1588  spk1
# 640884                 NaN                 1589  spk1
# 641156                 NaN                 1590  spk1
# 641296                 NaN                 1591  spk1
# 641532                 NaN                 1592  spk1
# 641748                 NaN                 1593  spk1
# 641964                 NaN                 1594  spk1
# 642088                 NaN                 1595  spk1
# 642396                 NaN                 1596  spk1
# 642516                 NaN                 1597  spk1
# 642672                 NaN                 1598  spk1
# 642812                 NaN                 1599  spk1
# 642948                 NaN                 1600  spk1
# 643024                 NaN                  NaN   NaN
# 643132                 NaN                 1602  spk1
# 643248                 NaN                 1603  spk1
# 643324                 NaN                 1604  spk1
# 643480                 NaN                 1605  spk1
# 643580                 NaN                 1606  spk1
#
#                                                     texte  PxP colour support
# 3220     après avoir demandé si tout le monde était pr...    1    NaN     NaN
# 3254                                                  NaN  NaN    NaN     NaN
# 3616                           est donné par David Skrela    1    NaN     NaN
# 3694                                                  NaN  NaN    NaN     NaN
# 3806                                                  NaN  NaN    NaN     NaN
# 3960                      allez de suite dans le camp euh    1    NaN     NaN
# 4042                                                  NaN  NaN    NaN     NaN
# 4070                                                  NaN  NaN    NaN     NaN
# 4146                                                  NaN  NaN    NaN     NaN
# 4160                                             argentin    1    NaN     NaN
# 4218                                                  NaN  NaN    NaN     NaN
# 4232                            avec un départ de Roncero    1    NaN     NaN
# 4456                            Pichot a appelé le ballon    1    NaN     NaN
# 4462                                                  NaN  NaN    NaN     NaN
# 4482                                                  NaN  NaN    NaN     NaN
# 4582                                                  NaN  NaN    NaN     NaN
# 4610                                                  NaN  NaN    NaN     NaN
# 4656                                       pour Hernandez    1    NaN     NaN
# 4848                                   avec le pied droit    1    NaN     NaN
# 5030                                                  NaN  NaN    NaN     NaN
# 5056                   pour trouver une très jolie touche    1    NaN     NaN
# 5130                                                  NaN  NaN    NaN     NaN
# 5300     direct il en avait le droit il était à l'inté...  NaN      1     NaN
# 5708                                      dans ces cas-là  NaN      1     NaN
# 5792                           on peut trouver une touche  NaN      1     NaN
# 5936                                          directement  NaN      1     NaN
# 6236                                      alors la touche  NaN      1     NaN
# 6324          ça ça sera une des clefs de cette rencontre  NaN      1     NaN
# 6512                                     le bloc français  NaN      1     NaN
# 6672                              contre le bloc argentin  NaN      1     NaN
# ...                                                   ...  ...    ...     ...
# 638352   la bonne récupération de Traille qui avait tr...  NaN      1     NaN
# 638624                                             Martin  NaN      1     NaN
# 638684                             et puis l'Interception  NaN      1     NaN
# 638872   l'interception qui va coûter cher puisque Con...  NaN      1     NaN
# 639332       et les jambes de Corleto vont faire le reste  NaN      1     NaN
# 639604      pour aller en terre promise pour aller à dame  NaN      1     NaN
# 639888                        et marquer l'essai argentin  NaN      1     NaN
# 640136                                cinq points l'essai  NaN      1     NaN
# 640264                   et ben cinq points c'est l'écart  NaN      1     NaN
# 640416                        qui sépare les deux équipes  NaN      1     NaN
# 640576                                            ce soir  NaN      1     NaN
# 640704                              on en a fini avec euh  NaN      1     NaN
# 640884      ce France Argentine le rugby continue sur tf1  NaN      1     NaN
# 641156               vous avez rendez-vous tout à l'heure  NaN      1     NaN
# 641296   après l'émission de Julien Courbet avec Denis...  NaN      1     NaN
# 641532   pour le magazine de la coupe du monde et puis...  NaN      1     NaN
# 641748            avec Christian Jean-Pierre aubin Hueber  NaN      1     NaN
# 641964                                      et Eric Champ  NaN      1     NaN
# 642088   l'ouverture des All Black la Nouvelle-Zélande...  NaN      1     NaN
# 642396                                         à l'Italie  NaN      1     NaN
# 642516                  puis on se retrouvera demain soir  NaN      1     NaN
# 642672                            avec Jean-Michel Larqué  NaN      1     NaN
# 642812                              pour un match de foot  NaN      1     NaN
# 642948                                      et quel match  NaN      1     NaN
# 643024                                          spk1-1601  NaN      1     NaN
# 643132                                     entre l'Italie  NaN      1     NaN
# 643248                                       et la France  NaN      1     NaN
# 643324                           très bonne fin de soirée  NaN      1     NaN
# 643480                                            sur tf1  NaN      1     NaN
# 643580               merci Thierry à la semaine prochaine  NaN      1     NaN
#
# [4318 rows x 14 columns]

# %%
def trancheTemps(duree):
    tranches=[i*25 for i in range(1,40)]
    for tranche in tranches:
        if duree<=tranche:
            return tranche

# %%
trancheTemps(600)
# Out:
# 600

# %%
timeLine["dureeS1"]=timeLine[(timeLine["Spk"]=="spk1") & (timeLine["texte"].dropna())].apply(lambda x: trancheTemps(x["fin"]-x["début"]),axis=1)
timeLine["dureeS2"]=timeLine[(timeLine["Spk"]=="spk2") & (timeLine["texte"].dropna())].apply(lambda x: trancheTemps(x["fin"]-x["début"]),axis=1)

# %%
for typeComm in ["PxP","colour"]:
    for duree in ["dureeS1","dureeS2"]:
        print typeComm,duree, int(timeLine[timeLine[typeComm]>0][duree].mean()), int(timeLine[timeLine[typeComm]>0][duree].std())
# Out:
# PxP dureeS1 169 76
# PxP dureeS2 177 128
# colour dureeS1 171 88
# colour dureeS2 186 122

# %% [markdown]
# ## Durées Spk1 en général

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS1=pd.pivot_table(timeLine[["début","dureeS1"]],index="dureeS1",values="début",aggfunc="count")
#tableS1.plot(kind="bar",ylim=(0,700),xlim=(-1,9))
tableS1.plot(kind="bar")

# %% [markdown]
# ## Durées Spk1 en général pour MT1

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS1=pd.pivot_table(timeLine[timeLine["début"]<finMT1][["début","dureeS1"]],index="dureeS1",values="début",aggfunc="count")
tableS1.plot(kind="bar",ylim=(0,250))

# %% [markdown]
# ## Durées Spk1 en général pour MT2

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS1=pd.pivot_table(timeLine[timeLine["début"]>debutMT2][["début","dureeS1"]],index="dureeS1",values="début",aggfunc="count")
tableS1.plot(kind="bar")

# %% [markdown]
# ## Durées Spk1 dans le CC

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS1=pd.pivot_table(timeLine[timeLine["colour"]>0][["début","dureeS1"]],index="dureeS1",values="début",aggfunc="count")
tableS1.plot(kind="bar")

# %% [markdown]
# ## Durées Spk2 en général

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS2=pd.pivot_table(timeLine[["début","dureeS2"]],index="dureeS2",values="début",aggfunc="count")
tableS2.plot(kind="bar")

# %% [markdown]
# ## Durées Spk2 en général dans MT1

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS2=pd.pivot_table(timeLine[timeLine["début"]<finMT1][["début","dureeS2"]],index="dureeS2",values="début",aggfunc="count")
tableS2.plot(kind="bar")

# %% [markdown]
# ## Durées Spk2 en général dans MT2

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS2=pd.pivot_table(timeLine[timeLine["début"]>debutMT2][["début","dureeS2"]],index="dureeS2",values="début",aggfunc="count")
tableS2.plot(kind="bar")

# %% [markdown]
# ## Durées Spk2 dans le CC

# %%
#timeLine[timeLine["numAction"].notnull()]["textAction"]=timeLine["action"].str.split(" ").str[1:]
tableS2=pd.pivot_table(timeLine[timeLine["colour"]>0][["début","dureeS2"]],index="dureeS2",values="début",aggfunc="count")
tableS2.plot(kind="bar")

# %%
#sliceDataFrame(timeLine,3200,3300,1,["colour"])

# %%
# %%time
timeCommentType=pd.DataFrame(columns=["PxP","colour","support","sumPxP","sumColour","sumSupport"])
step=100
for i in arange(3000,644000,step):
    if len(sliceDataFrame(timeLine,i,i+step,1,["PxP"])) > 0:
        PxP=1
        sumPxP=sliceDataFrame(timeLine,i,i+step,1,["PxP"])["PxP"].sum()
    else:
        PxP=0
        sumPxP=0
    if len(timeLine[timeLine.index<i].dropna(subset=["PxP"]))>0:
        if timeLine[timeLine.index<i].dropna(subset=["PxP"]).iloc[-1]["fin"]>i:
            PxP=1
            sumPxP+=1
    if len(sliceDataFrame(timeLine,i,i+step,1,["colour"])) > 0:
        colour=1
        sumColour=sliceDataFrame(timeLine,i,i+step,1,["colour"])["colour"].sum()
    else:
        colour=0
        sumColour=0
    if len(timeLine[timeLine.index<i].dropna(subset=["colour"]))>0:
        if timeLine[timeLine.index<i].dropna(subset=["colour"]).iloc[-1]["fin"]>i:
            colour=1
            sumColour+=1
    if len(sliceDataFrame(timeLine,i,i+step,1,["support"])) > 0:
        support=1
        sumSupport=sliceDataFrame(timeLine,i,i+step,1,["support"])["support"].sum()
    else:
        support=0
        sumSupport=0
    if len(timeLine[timeLine.index<i].dropna(subset=["support"]))>0:
        if timeLine[timeLine.index<i].dropna(subset=["support"]).iloc[-1]["fin"]>i:
            support=1
            sumSupport+=1
    timeCommentType.loc[i]=[PxP, colour, support, sumPxP, sumColour, sumSupport]
# Out:
# CPU times: user 1min 59s, sys: 652 ms, total: 2min
# Wall time: 2min 1s

# %%
#timeCommentType[0:5880][timeCommentType["sumPxP"]>1]
print "nbPxP", "Match",timeCommentType["PxP"].sum()
print "nbPxP", "MT1",timeCommentType[timeCommentType.index<finMT1]["PxP"].sum()
print "nbPxP", "MT2",timeCommentType[timeCommentType.index>debutMT2]["PxP"].sum()
print "nbColour", "Match",timeCommentType["colour"].sum()
print "nbColour", "MT1",timeCommentType[timeCommentType.index<finMT1]["colour"].sum()
print "nbColour", "MT2",timeCommentType[timeCommentType.index>debutMT2]["colour"].sum()
# Out:
# nbPxP Match 2006.0
# nbPxP MT1 1099.0
# nbPxP MT2 907.0
# nbColour Match 3362.0
# nbColour MT1 1395.0
# nbColour MT2 1966.0

# %%
#timeCommentType[0:5880][timeCommentType["sumPxP"]>1]
print "nbActions", "Match",timeLine["numAct"].count()
print "nbActions", "MT1",timeLine[timeLine.index<finMT1]["numAct"].count()
print "nbActions", "MT2",timeLine[timeLine.index>debutMT2]["numAct"].count()
#print "nbActionsCommentées", "Match",timeLine[timeLine["Spk"].notnull()]["numAct"].count()
# Out:
# nbActions Match 1782
# nbActions MT1 850
# nbActions MT2 932

# %%
#print "nbActionsCommentées", "MT1",timeLine[(timeLine.index<finMT1)&(timeLine["Spk"].notnull())]["numAct"].count()
#print "nbActionsCommentées", "MT2",timeLine[timeLine.index>debutMT2]["numAct"].count()
#print "nbActionsSansCommentaire", "Match",timeLine["numAct"].count()
#print "nbActionsSansCommentaire", "MT1",timeLine[timeLine.index<finMT1]["numAct"].count()
#print "nbActionsSansCommentaire", "MT2",timeLine[timeLine.index>debutMT2]["numAct"].count()

# %%
with codecs.open(commentairesTypesName,"wb") as output:
    pickle.dump(timeCommentType, output, pickle.HIGHEST_PROTOCOL)

# %%
with codecs.open(commentaireActionName,"wb") as output:
#    pickle.dump(timeLine[["début","fin","numEvent","événement","numAct","action","numSpk","Spk","texte"]], output, pickle.HIGHEST_PROTOCOL)
    pickle.dump(timeLine, output, pickle.HIGHEST_PROTOCOL)

# %%
timeLine
# Out:
#            timecode   début     fin numEvent     événement numAct  \
# 3220    00:12:24.60    3220    3592      NaN           NaN    NaN
# 3254    00:12:24.94    3254    3690        1  coup d'envoi      1
# 3616    00:12:28.56    3616    3852      NaN           NaN    NaN
# 3694    00:12:29.34    3694    3738        1  coup d'envoi      2
# 3806    00:12:30.46    3806    4042        2  regroupement      3
# 3960    00:12:32.00    3960    4100      NaN           NaN    NaN
# 4042    00:12:32.82    4042    4070        2  regroupement      4
# 4070    00:12:33.10    4070    4146        3         porté      5
# 4146    00:12:33.86    4146    4214        4  regroupement      6
# 4160    00:12:34.00    4160    4216      NaN           NaN    NaN
# 4218    00:12:34.58    4218    4434        4  regroupement      7
# 4232    00:12:34.72    4232    4384      NaN           NaN    NaN
# 4456    00:12:36.96    4456    4576      NaN           NaN    NaN
# 4462    00:12:37.02    4462    4478        4  regroupement      8
# 4482    00:12:37.22    4482    4578        5         passe      9
# 4582    00:12:38.22    4582    4606        5         passe     10
# 4610    00:12:38.50    4610    5030        6  coup de pied     11
# 4656    00:12:38.96    4656    4780      NaN           NaN    NaN
# 4848    00:12:40.88    4848    5000      NaN           NaN    NaN
# 5030    00:12:42.70    5030    5126        7        touche     12
# 5056    00:12:42.96    5056    5228      NaN           NaN    NaN
# 5130    00:12:43.70    5130    7634        7       touche      13
# 5300    00:12:45.40    5300    5664      NaN           NaN    NaN
# 5708    00:12:49.48    5708    5776      NaN           NaN    NaN
# 5792    00:12:50.32    5792    5904      NaN           NaN    NaN
# 5936    00:12:51.76    5936    6004      NaN           NaN    NaN
# 6236    00:12:54.76    6236    6308      NaN           NaN    NaN
# 6324    00:12:55.64    6324    6480      NaN           NaN    NaN
# 6512    00:12:57.52    6512    6616      NaN           NaN    NaN
# 6672    00:12:59.12    6672    6796      NaN           NaN    NaN
# ...             ...     ...     ...      ...           ...    ...
# 638352  01:49:28.62  638352  638596      NaN           NaN    NaN
# 638624  01:49:31.34  638624  638672      NaN           NaN    NaN
# 638684  01:49:31.94  638684  638784      NaN           NaN    NaN
# 638872  01:49:33.82  638872  639276      NaN           NaN    NaN
# 639332  01:49:38.42  639332  639512      NaN           NaN    NaN
# 639604  01:49:41.14  639604  639832      NaN           NaN    NaN
# 639888  01:49:43.98  639888  640048      NaN           NaN    NaN
# 640136  01:49:46.46  640136  640240      NaN           NaN    NaN
# 640264  01:49:47.74  640264  640384      NaN           NaN    NaN
# 640416  01:49:49.26  640416  640532      NaN           NaN    NaN
# 640576  01:49:50.86  640576  640656      NaN           NaN    NaN
# 640704  01:49:52.14  640704  640860      NaN           NaN    NaN
# 640884  01:49:53.94  640884  641108      NaN           NaN    NaN
# 641156  01:49:56.66  641156  641268      NaN           NaN    NaN
# 641296  01:49:58.06  641296  641508      NaN           NaN    NaN
# 641532  01:50:00.42  641532  641716      NaN           NaN    NaN
# 641748  01:50:02.58  641748  641936      NaN           NaN    NaN
# 641964  01:50:04.74  641964  642052      NaN           NaN    NaN
# 642088  01:50:05.98  642088  642360      NaN           NaN    NaN
# 642396  01:50:09.06  642396  642480      NaN           NaN    NaN
# 642516  01:50:10.26  642516  642632      NaN           NaN    NaN
# 642672  01:50:11.82  642672  642780      NaN           NaN    NaN
# 642812  01:50:13.22  642812  642928      NaN           NaN    NaN
# 642948  01:50:14.58  642948  643000      NaN           NaN    NaN
# 643024  01:50:15.34  643024  643096      NaN           NaN    NaN
# 643132  01:50:16.42  643132  643232      NaN           NaN    NaN
# 643248  01:50:17.58  643248  643300      NaN           NaN    NaN
# 643324  01:50:18.34  643324  643452      NaN           NaN    NaN
# 643480  01:50:19.90  643480  643556      NaN           NaN    NaN
# 643580  01:50:20.90  643580  643704      NaN           NaN    NaN
#
#                     action commentaires  numSpk   Spk  \
# 3220                   NaN                    1  spk1
# 3254    grand coup de pied     spk1-002     NaN  spk1
# 3616                   NaN                    2  spk1
# 3694             réception                  NaN  spk1
# 3806          regroupement                  NaN  spk1
# 3960                   NaN                    1  spk2
# 4042            extraction                  NaN  spk2
# 4070                 porté     spk1-003     NaN  spk2
# 4146              plaquage                  NaN  spk2
# 4160                   NaN                    2  spk2
# 4218          regroupement                  NaN  spk2
# 4232                   NaN                    3  spk1
# 4456                   NaN                    4  spk1
# 4462            extraction                  NaN  spk1
# 4482                 passe     spk1-005     NaN  spk1
# 4582             réception                  NaN  spk1
# 4610    grand coup de pied     spk1-006     NaN  spk1
# 4656                   NaN                    5  spk1
# 4848                   NaN                    6  spk1
# 5030                sortie    spk1-007      NaN  spk1
# 5056                   NaN                    7  spk1
# 5130         mise en ligne                  NaN  spk1
# 5300                   NaN                    8  spk1
# 5708                   NaN                    9  spk1
# 5792                   NaN                   10  spk1
# 5936                   NaN                   11  spk1
# 6236                   NaN                   12  spk1
# 6324                   NaN                   13  spk1
# 6512                   NaN                   14  spk1
# 6672                   NaN                   15  spk1
# ...                    ...          ...     ...   ...
# 638352                 NaN                 1577  spk1
# 638624                 NaN                 1578  spk1
# 638684                 NaN                 1579  spk1
# 638872                 NaN                 1580  spk1
# 639332                 NaN                 1581  spk1
# 639604                 NaN                 1582  spk1
# 639888                 NaN                 1583  spk1
# 640136                 NaN                 1584  spk1
# 640264                 NaN                 1585  spk1
# 640416                 NaN                 1586  spk1
# 640576                 NaN                 1587  spk1
# 640704                 NaN                 1588  spk1
# 640884                 NaN                 1589  spk1
# 641156                 NaN                 1590  spk1
# 641296                 NaN                 1591  spk1
# 641532                 NaN                 1592  spk1
# 641748                 NaN                 1593  spk1
# 641964                 NaN                 1594  spk1
# 642088                 NaN                 1595  spk1
# 642396                 NaN                 1596  spk1
# 642516                 NaN                 1597  spk1
# 642672                 NaN                 1598  spk1
# 642812                 NaN                 1599  spk1
# 642948                 NaN                 1600  spk1
# 643024                 NaN                  NaN   NaN
# 643132                 NaN                 1602  spk1
# 643248                 NaN                 1603  spk1
# 643324                 NaN                 1604  spk1
# 643480                 NaN                 1605  spk1
# 643580                 NaN                 1606  spk1
#
#                                                     texte  PxP colour support  \
# 3220     après avoir demandé si tout le monde était pr...    1    NaN     NaN
# 3254                                                  NaN  NaN    NaN     NaN
# 3616                           est donné par David Skrela    1    NaN     NaN
# 3694                                                  NaN  NaN    NaN     NaN
# 3806                                                  NaN  NaN    NaN     NaN
# 3960                      allez de suite dans le camp euh    1    NaN     NaN
# 4042                                                  NaN  NaN    NaN     NaN
# 4070                                                  NaN  NaN    NaN     NaN
# 4146                                                  NaN  NaN    NaN     NaN
# 4160                                             argentin    1    NaN     NaN
# 4218                                                  NaN  NaN    NaN     NaN
# 4232                            avec un départ de Roncero    1    NaN     NaN
# 4456                            Pichot a appelé le ballon    1    NaN     NaN
# 4462                                                  NaN  NaN    NaN     NaN
# 4482                                                  NaN  NaN    NaN     NaN
# 4582                                                  NaN  NaN    NaN     NaN
# 4610                                                  NaN  NaN    NaN     NaN
# 4656                                       pour Hernandez    1    NaN     NaN
# 4848                                   avec le pied droit    1    NaN     NaN
# 5030                                                  NaN  NaN    NaN     NaN
# 5056                   pour trouver une très jolie touche    1    NaN     NaN
# 5130                                                  NaN  NaN    NaN     NaN
# 5300     direct il en avait le droit il était à l'inté...  NaN      1     NaN
# 5708                                      dans ces cas-là  NaN      1     NaN
# 5792                           on peut trouver une touche  NaN      1     NaN
# 5936                                          directement  NaN      1     NaN
# 6236                                      alors la touche  NaN      1     NaN
# 6324          ça ça sera une des clefs de cette rencontre  NaN      1     NaN
# 6512                                     le bloc français  NaN      1     NaN
# 6672                              contre le bloc argentin  NaN      1     NaN
# ...                                                   ...  ...    ...     ...
# 638352   la bonne récupération de Traille qui avait tr...  NaN      1     NaN
# 638624                                             Martin  NaN      1     NaN
# 638684                             et puis l'Interception  NaN      1     NaN
# 638872   l'interception qui va coûter cher puisque Con...  NaN      1     NaN
# 639332       et les jambes de Corleto vont faire le reste  NaN      1     NaN
# 639604      pour aller en terre promise pour aller à dame  NaN      1     NaN
# 639888                        et marquer l'essai argentin  NaN      1     NaN
# 640136                                cinq points l'essai  NaN      1     NaN
# 640264                   et ben cinq points c'est l'écart  NaN      1     NaN
# 640416                        qui sépare les deux équipes  NaN      1     NaN
# 640576                                            ce soir  NaN      1     NaN
# 640704                              on en a fini avec euh  NaN      1     NaN
# 640884      ce France Argentine le rugby continue sur tf1  NaN      1     NaN
# 641156               vous avez rendez-vous tout à l'heure  NaN      1     NaN
# 641296   après l'émission de Julien Courbet avec Denis...  NaN      1     NaN
# 641532   pour le magazine de la coupe du monde et puis...  NaN      1     NaN
# 641748            avec Christian Jean-Pierre aubin Hueber  NaN      1     NaN
# 641964                                      et Eric Champ  NaN      1     NaN
# 642088   l'ouverture des All Black la Nouvelle-Zélande...  NaN      1     NaN
# 642396                                         à l'Italie  NaN      1     NaN
# 642516                  puis on se retrouvera demain soir  NaN      1     NaN
# 642672                            avec Jean-Michel Larqué  NaN      1     NaN
# 642812                              pour un match de foot  NaN      1     NaN
# 642948                                      et quel match  NaN      1     NaN
# 643024                                          spk1-1601  NaN      1     NaN
# 643132                                     entre l'Italie  NaN      1     NaN
# 643248                                       et la France  NaN      1     NaN
# 643324                           très bonne fin de soirée  NaN      1     NaN
# 643480                                            sur tf1  NaN      1     NaN
# 643580               merci Thierry à la semaine prochaine  NaN      1     NaN
#
#         dureeS1  dureeS2
# 3220        375      NaN
# 3254        NaN      NaN
# 3616        250      NaN
# 3694        NaN      NaN
# 3806        NaN      NaN
# 3960        NaN      150
# 4042        NaN      NaN
# 4070        NaN      NaN
# 4146        NaN      NaN
# 4160        NaN       75
# 4218        NaN      NaN
# 4232        175      NaN
# 4456        125      NaN
# 4462        NaN      NaN
# 4482        NaN      NaN
# 4582        NaN      NaN
# 4610        NaN      NaN
# 4656        125      NaN
# 4848        175      NaN
# 5030        NaN      NaN
# 5056        175      NaN
# 5130        NaN      NaN
# 5300        375      NaN
# 5708         75      NaN
# 5792        125      NaN
# 5936         75      NaN
# 6236         75      NaN
# 6324        175      NaN
# 6512        125      NaN
# 6672        125      NaN
# ...         ...      ...
# 638352      250      NaN
# 638624       50      NaN
# 638684      100      NaN
# 638872      425      NaN
# 639332      200      NaN
# 639604      250      NaN
# 639888      175      NaN
# 640136      125      NaN
# 640264      125      NaN
# 640416      125      NaN
# 640576      100      NaN
# 640704      175      NaN
# 640884      225      NaN
# 641156      125      NaN
# 641296      225      NaN
# 641532      200      NaN
# 641748      200      NaN
# 641964      100      NaN
# 642088      275      NaN
# 642396      100      NaN
# 642516      125      NaN
# 642672      125      NaN
# 642812      125      NaN
# 642948       75      NaN
# 643024      NaN      NaN
# 643132      100      NaN
# 643248       75      NaN
# 643324      150      NaN
# 643480      100      NaN
# 643580      125      NaN
#
# [4318 rows x 16 columns]
