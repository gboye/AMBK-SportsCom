# %% [markdown]
# #Version 1.0 (Python 2.7)
# Répartition des actions en fonction du temps restant à partir d'une étiquette de temps donnée (ligneUnique)

# %%
import codecs

# %%
fichier=open('./MiTemps1-v1.ass','r')
lignes=fichier.readlines()

# %%
sortie=[]
ligneUnique="0:08:38.42,0:08:39.02"
tempsFin="0:50:00.00"
nbCourtes=0
nbNormales=0
nbLongues=0
incrementCourt=0
ratioCourtNormal=5
ratioCourtLong=15
Transition=False
ActionsCourtes=["passe","réception","extraction","plaquage","récupération","lacher","rebond"]
SequencesLongues=["mise en ligne","ralenti","replay"]

# %%
for ligne in lignes:
    if 'Dialogue' in ligne:
        if ligneUnique in ligne:                
            tempsDebut=ligne.split(",")[2]
            Transition=True
        elif Transition:
            action=ligne.split(",")[9].strip()
            if action in ActionsCourtes:
                nbCourtes+=1
            elif action in SequencesLongues:
                nbLongues+=1
            else:
                nbNormales+=1

# %%
print nbCourtes, nbNormales, nbLongues, tempsDebut, tempsFin
# Out:
# 396 314 34 0:08:39.02 0:50:00.00

# %%
def calculTemps(chaine):
    heures,minutes,secondes=chaine.split(":")
    result=float(secondes)
    result+=60*float(minutes)
    result+=3600*float(heures)
    return result

def calculChaine(temps):
    heures=temps//3600
    reste=temps-heures*3600
    minutes=reste//60
    secondes=reste-minutes*60
    result="%d:%02d:%05.2f" % (heures,minutes,secondes)
    return result

def changeLigne(chaine,increment):
    champs=chaine.split(',')
    champs[1]=calculChaine(timingDebut+(nbCourtes+ratioCourtNormal*nbNormales+ratioCourtLong*nbLongues)*incrementCourt)
    champs[2]=calculChaine(timingDebut+(nbCourtes+ratioCourtNormal*nbNormales+ratioCourtLong*nbLongues)*incrementCourt+increment)
    result=",".join(champs)
    return result

# %%
timingDebut=calculTemps(tempsDebut)
timingFin=calculTemps(tempsFin)
timing=timingFin-timingDebut

# %%
equivalentCourt=nbCourtes+ratioCourtNormal*nbNormales+ratioCourtLong*nbLongues
incrementCourt=timing/equivalentCourt
incrementNormal=ratioCourtNormal*incrementCourt
incrementLong=ratioCourtLong*incrementCourt

print calculChaine(timingDebut+incrementCourt*(nbCourtes+ratioCourtNormal*nbNormales+ratioCourtLong*nbLongues))
# Out:
# 0:50:00.00

# %%
nbCourtes=0
nbNormales=0
nbLongues=0
Transition=False
for ligne in lignes:
    if 'Dialogue' in ligne:
        if ligneUnique in ligne:                
            Transition=True
            print ligne
        elif Transition:
            action=ligne.split(",")[9].strip()
            if action in ActionsCourtes:
                print changeLigne(ligne,incrementCourt)
                nbCourtes+=1
            elif action in SequencesLongues:
                print changeLigne(ligne,incrementLong)
                nbLongues+=1                
            else:
                print changeLigne(ligne,incrementNormal)
                nbNormales+=1
        else:
            print ligne
    else:
        print ligne
# print nbCourtes, nbNormales, nbLongues
# Out:
# ﻿[Script Info]
#
# ; Script generated by Aegisub 3.1.3
#
# ; http://www.aegisub.org/
#
# Title: Default Aegisub file
#
# ScriptType: v4.00+
#
# WrapStyle: 0
#
# ScaledBorderAndShadow: yes
#
# YCbCr Matrix: TV.601
#
# PlayResX: 720
#
# PlayResY: 576
#
# Export Encoding: Unicode (UTF-8)
#
# Aegisub Scroll Position: 55
#
# Aegisub Active Line: 77
#
# Aegisub Video Zoom Percent: 1.500000
#
# Video File: ../../../../../../Volumes/gilles/TV/RWC/RWC-Pool D-1 France-Argentina.avi
#
# Aegisub Video Aspect Ratio: 2
#
# Aegisub Video Position: 13707
#
#
#
# [V4+ Styles]
#
# Format: Name, Fontname, Fontsize, PrimaryColour, SecondaryColour, OutlineColour, BackColour, Bold, Italic, Underline, StrikeOut, ScaleX, ScaleY, Spacing, Angle, BorderStyle, Outline, Shadow, Alignment, MarginL, MarginR, MarginV, Encoding
#
# Style: Default,Arial,20,&H00FFFFFF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,2,2,2,10,10,10,1
#
#
#
# [Events]
#
# Format: Layer, Start, End, Style, Name, MarginL, MarginR, MarginV, Effect, Text
#
# Dialogue: 0,0:05:17.54,0:05:21.90,Default,,0,0,0,,grand coup de pied
#
# Dialogue: 0,0:05:21.94,0:05:22.38,Default,,0,0,0,,réception
#
# Dialogue: 0,0:05:23.06,0:05:25.42,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:05:25.42,0:05:25.70,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:05:25.70,0:05:26.46,Default,,0,0,0,,porté
#
# Dialogue: 0,0:05:26.46,0:05:27.14,Default,,0,0,0,,plaquage
#
# Dialogue: 0,0:05:27.18,0:05:29.34,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:05:29.62,0:05:29.78,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:05:29.82,0:05:30.78,Default,,0,0,0,,passe
#
# Dialogue: 0,0:05:30.82,0:05:31.06,Default,,0,0,0,,réception
#
# Dialogue: 0,0:05:31.10,0:05:35.30,Default,,0,0,0,,grand coup de pied
#
# Dialogue: 0,0:05:35.30,0:05:36.26,Default,,0,0,0,,sortie
#
# Dialogue: 0,0:05:36.30,0:06:01.34,Default,,0,0,0,,mise en ligne
#
# Dialogue: 0,0:06:01.38,0:06:02.62,Default,,0,0,0,,lancer introduction
#
# Dialogue: 0,0:06:02.94,0:06:03.46,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:06:03.62,0:06:04.38,Default,,0,0,0,,lacher
#
# Dialogue: 0,0:06:04.38,0:06:04.50,Default,,0,0,0,,rebond
#
# Dialogue: 0,0:06:04.70,0:06:04.94,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:06:05.02,0:06:06.74,Default,,0,0,0,,porté
#
# Dialogue: 0,0:06:06.78,0:06:08.38,Default,,0,0,0,,petit coup de pied
#
# Dialogue: 0,0:06:08.38,0:06:08.58,Default,,0,0,0,,rebond
#
# Dialogue: 0,0:06:11.14,0:06:11.46,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:06:11.46,0:06:12.74,Default,,0,0,0,,porté
#
# Dialogue: 0,0:06:12.74,0:06:14.70,Default,,0,0,0,,plaquage
#
# Dialogue: 0,0:06:15.02,0:06:18.66,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:06:18.74,0:06:19.22,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:06:19.26,0:06:20.22,Default,,0,0,0,,passe
#
# Dialogue: 0,0:06:20.26,0:06:20.34,Default,,0,0,0,,réception
#
# Dialogue: 0,0:06:20.38,0:06:25.06,Default,,0,0,0,,grand coup de pied
#
# Dialogue: 0,0:06:25.14,0:06:29.10,Default,,0,0,0,,sortie
#
# Dialogue: 0,0:06:29.26,0:06:36.62,Default,,0,0,0,,ralenti
#
# Dialogue: 0,0:06:37.18,0:06:46.70,Default,,0,0,0,,mise en ligne
#
# Dialogue: 0,0:06:49.58,0:06:51.06,Default,,0,0,0,,lancer introduction
#
# Dialogue: 0,0:06:51.78,0:06:52.54,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:06:52.90,0:06:58.50,Default,,0,0,0,,maul
#
# Dialogue: 0,0:06:58.54,0:06:58.86,Default,,0,0,0,,écroulement
#
# Dialogue: 0,0:06:58.86,0:07:00.30,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:07:00.30,0:07:00.98,Default,,0,0,0,,plaquage
#
# Dialogue: 0,0:07:01.22,0:07:06.70,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:07:06.90,0:07:07.18,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:07:07.18,0:07:08.14,Default,,0,0,0,,passe
#
# Dialogue: 0,0:07:08.14,0:07:08.42,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:07:08.46,0:07:12.66,Default,,0,0,0,,tir au but
#
# Dialogue: 0,0:07:12.66,0:07:12.74,Default,,0,0,0,,non marqué
#
# Dialogue: 0,0:07:12.74,0:07:12.86,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:07:13.46,0:07:14.78,Default,,0,0,0,,sifflet
#
# Dialogue: 0,0:07:30.10,0:07:33.30,Default,,0,0,0,,grand coup de pied
#
# Dialogue: 0,0:07:33.42,0:07:35.74,Default,,0,0,0,,sortie
#
# Dialogue: 0,0:07:35.94,0:07:43.62,Default,,0,0,0,,replay
#
# Dialogue: 0,0:07:44.02,0:07:50.66,Default,,0,0,0,,ralenti
#
# Dialogue: 0,0:07:51.38,0:08:01.94,Default,,0,0,0,,mise en ligne
#
# Dialogue: 0,0:08:02.22,0:08:03.78,Default,,0,0,0,,introduction
#
# Dialogue: 0,0:08:03.86,0:08:04.14,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:08:04.18,0:08:04.66,Default,,0,0,0,,lacher
#
# Dialogue: 0,0:08:05.26,0:08:05.50,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:08:05.50,0:08:05.62,Default,,0,0,0,,porté
#
# Dialogue: 0,0:08:06.66,0:08:07.50,Default,,0,0,0,,plaquage
#
# Dialogue: 0,0:08:07.58,0:08:09.98,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:08:10.06,0:08:10.34,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:08:10.38,0:08:11.02,Default,,0,0,0,,porté
#
# Dialogue: 0,0:08:11.26,0:08:14.58,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:08:14.74,0:08:14.98,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:08:15.02,0:08:15.58,Default,,0,0,0,,porté
#
# Dialogue: 0,0:08:15.74,0:08:23.18,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:08:24.66,0:08:24.94,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:08:24.94,0:08:25.98,Default,,0,0,0,,passe
#
# Dialogue: 0,0:08:26.06,0:08:26.18,Default,,0,0,0,,réception
#
# Dialogue: 0,0:08:26.30,0:08:26.82,Default,,0,0,0,,tir au but
#
# Dialogue: 0,0:08:26.86,0:08:28.02,Default,,0,0,0,,contré
#
# Dialogue: 0,0:08:28.82,0:08:29.02,Default,,0,0,0,,récupération
#
# Dialogue: 0,0:08:29.06,0:08:31.10,Default,,0,0,0,,porté
#
# Dialogue: 0,0:08:31.14,0:08:31.62,Default,,0,0,0,,plaquage
#
# Dialogue: 0,0:08:32.30,0:08:36.82,Default,,0,0,0,,regroupement
#
# Dialogue: 0,0:08:36.94,0:08:37.14,Default,,0,0,0,,extraction
#
# Dialogue: 0,0:08:37.46,0:08:38.18,Default,,0,0,0,,passe
#
# Dialogue: 0,0:08:38.22,0:08:38.38,Default,,0,0,0,,réception
#
# 396 314 34
