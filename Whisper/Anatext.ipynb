# %%
import pandas as pd

# %%
df=pd.read_excel("/Users/gilles/Downloads/BouleDeSuif.xlsx",skiprows=1,index_col=0)

# %%
df.columns="lemme freq ref loglike".split(" ")
df.head()
# Out:
#               lemme  freq     ref  loglike
# Rang
# 1              suif    27   1.165  363.173
# 2             comte    33  45.660  202.941
# 3          prussien    18   3.855  178.441
# 4     manufacturier     6   0.035  114.239
# 5             boule    17  45.940   82.235

# %%
df.loc[df.ref<10,:][:50]
# Out:
#               lemme  freq    ref  loglike
# Rang
# 1              suif    27  1.165  363.173
# 3          prussien    18  3.855  178.441
# 4     manufacturier     6  0.035  114.239
# 7           atteler     8  4.860   62.312
# 8            bouler     5  1.150   48.824
# 13           longue     7  9.450   43.375
# 14        diligence     5  4.045   36.072
# 15          timbale     4  1.665   34.208
# 18       reparaître     5  8.475   28.737
# 20           cocher     5  9.900   27.212
# 23         débitant     2  0.135   24.785
# 27            gelée     4  6.165   23.738
# 28            chope     3  1.735   23.663
# 29          terrine     3  1.805   23.424
# 31       enrouement     2  0.205   22.936
# 34       aubergiste     3  2.285   22.005
# 37     chaufferette     2  0.435   19.760
# 40         bravoure     3  3.910   18.797
# 41       épouvanter     3  4.375   18.131
# 42        marmotter     2  0.700   17.808
# 43          vengeur     3  4.755   17.638
# ...
