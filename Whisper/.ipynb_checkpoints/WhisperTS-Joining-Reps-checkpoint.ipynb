# %% [markdown]
# # WhisperTS joining JSON to SRT in all folders

# %%
import re,codecs,unidecode
import pandas as pd
import networkx as nx
import matplotlib.pylab as p

import json,glob,os
nMachine=os.uname()[1]
if "iMac" in nMachine:
    nMachine="iMac"
elif "MacBook" in nMachine:
    nMachine="MacBook"
print(nMachine)
# Out:
# iMac

# %%
def ding():
    os.system('afplay /System/Library/Sounds/Submarine.aiff')

# %%
pause=0.200

jsonReps=glob.glob("/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/%s/Json/*/*/"%nMachine)
jsonReps
# Out:
# ['/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/BerloinSalome/enregistrement_10/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/BerloinSalome/enregistrement_9/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 10/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 13/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 14/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 16/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 17/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 20/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 21/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 22/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 23/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 24/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 25/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 26/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 33/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 35/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 37/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 4/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 44/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 45/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 46/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 8/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/ECOLE PRIMAIRE LEOPOLD LACHAIZE 9/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Julia CE2/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Loane CM1/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Loane CM1 (1)/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Mattin/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Mayla CE2/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Mikel/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Milia/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Oihan/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Pablo CE2/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Pablo CE2 (1)/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Patxi/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Xan/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Zoé/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Zoé CM2/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/ClavereauDarrieumerlouMarcheix/Zoé CM2 (1)/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/DanielivanovRoelandtTouret/audio_locuteur_4_mp3/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/DanielivanovRoelandtTouret/audio_locuteur_5_mp3/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/EmerasPons/Femme 31 ans/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/EmerasPons/Femme 6 ans/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/EmerasPons/Femme 7 ans/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/LamourRouch/Audio 2 - Maud/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/LamourRouch/Audio 3 - Léa/',
#  '/Users/gilles/sDrive/Cours/Bordeaux/L2-Corpus/Whisper/iMac/Json/PidouxRumeau-AlvaroGuilcher/AUDIO-2024sacha anne claire /']

# %% [markdown]
# ### Gestion des timestamps

# %%
def second2timestamp(seconds):
    sHours=int(seconds/3600)
    sMinutes=int((seconds-sHours*3600)/60)
    sSeconds=int((seconds-sHours*3600-sMinutes*60))
    sMilliseconds=int((seconds%1)*1000)
    return "%02d:%02d:%02d,%03d"%(sHours,sMinutes,sSeconds,sMilliseconds)

def timestamp2second(timestamp):
    m=re.match("(\d\d):(\d\d):(\d\d),(\d\d\d)",timestamp)
    if m:
        seconds=(int(m.group(1))*60+int(m.group(2)))*60+int(m.group(3))+float(m.group(4))/1000
        return seconds
    else:
        print("problème de timestamp")
        return

def shiftTime(timestamp,decal):
    return second2timestamp(timestamp2second(timestamp)+decal)

# %%
punct = list('''!()[]{};:-'"\,<>./?@#$%^&*_~''')
maxSize=8

def removePunct(texte):
    result=texte
    for p in punct:
        result=result.replace(p,"")
    return result

# %% [markdown]
# ### Gestion des structures JSON de Whisper

# %%
def getWords(whisper):
    lWords=[]
    for segment in whisper["segments"]:
        for word in segment["words"]:
            lWords.append((second2timestamp(word["start"]),
                              second2timestamp(word["end"]),
                              word["text"],
                              word["confidence"]))        
    return [(t1,t2,w,c) for t1,t2,w,c in lWords if w!=""]

def getList(tWhisper):
    return [unidecode.unidecode(removePunct(w)).lower() for _,_,w,_ in tWhisper]

# %% [markdown]
# ### Trouver la jointure

# %%
def findSample(sample,ref):
    lowSample=[t.lower() for t in sample]
    lowRef=[t.lower() for t in ref]
    i=0
    while i<len(ref)-len(sample):
        # print("ref",i)
        if lowSample==lowRef[i:i+len(sample)]:
            return i
        else:
            i+=1
    return None

# %% [markdown]
# ### Collage des mots
# 1. on cherche la partie commune entre le nouveau segment et les sous-titres précédents
# 2. on peut régler la longueur de la partie commune pour optimiser le collage *maxSize*
# 3. on incrémente les temps de la nouvelle partie à partir du deuxième mot (pour éviter les erreurs de timestamp en début d'enregistrement)

# %%
def pasteWords(srt,whisper2):
    srtList=getList(srt)
    w2=getWords(whisper2)
    w2List=getList(w2)
    lenW2=len(w2)
    compSize=min(maxSize,lenW2)
    i=1
    print(compSize)
    while i<lenW2-compSize:
        sample=w2List[i:i+compSize]
        ref=srtList
        # print(sample)
        idx=findSample(sample,ref)
        if idx:
            print("found",i,idx)
            break
        else:
            i+=1
    if idx:
        print("found",i,idx,srtList[idx],srt[idx][0],w2List[i],w2[i][0])
        tDecal=timestamp2second(srt[idx+1][0])-timestamp2second(w2[i+1][0])
        print(second2timestamp(tDecal))
        newSrt=[]
        for n in range(i+1,lenW2):
            nWord=w2[n]
            newWord=(shiftTime(nWord[0],tDecal),shiftTime(nWord[1],tDecal),nWord[2],nWord[3])
            newSrt.append(newWord)
        print(srt[idx+1],newSrt[0])
        return srt[:idx]+newSrt
    else:
        print("problème")
        ding()
        ding()
        ding()
        return None

# %%
def makeSRT(repJson):
    segments=len(glob.glob(repJson+"*.json"))
    json1=repJson+"extrait-00.json"
    with open(json1) as inFile:
        whisper1=json.load(inFile)
    srt=getWords(whisper1)
    srtList=getList(srt)
    for i in range(1,segments):
        # print(i)
        json2=repJson+"extrait-%02d.json"%i
        with open(json2) as inFile:
            whisper2=json.load(inFile)
        newSrt=pasteWords(srt,whisper2)
        if not newSrt:
            print("pb",i-1,i)
            return
        else:
            srt=newSrt

    srtTours=[]
    srtMots=[]
    bTour=True
    prevEnd=0
    pStart=second2timestamp(0)
    pEnd=0
    
    for i,(start,end,mot,confidence) in enumerate(srt):
        # print(start,end,mot,confidence)
        tStart=timestamp2second(start)
        tEnd=timestamp2second(end)
        # print(start,tStart,prevEnd)
        if tStart-prevEnd>pause and prevEnd!=0:
            pEnd=second2timestamp(prevEnd)
            pTour=" ".join(srtMots)
            srtTours.append((pStart,pEnd,pTour))
            pStart=start
            prevEnd=tEnd
            srtMots=[mot]
            bPhrase=True
        else:
            srtMots.append(mot)
            prevEnd=tEnd
    pTour=" ".join(srtMots)
    srtTours.append((pStart,pEnd,pTour))

    srtLines=[]
    for i,(start,end,mot) in enumerate(srtTours):
        print(start,end,mot)
        n=i+1
        srtLines.append(str(n))
        srtLines.append(start+" --> "+end)
        srtLines.append(mot)
        srtLines.append("")
        
    with codecs.open(json1.replace(".json","-tours.srt"),"w",encoding="utf8") as outFile:
        for srtLine in srtLines:
            outFile.write(srtLine+"\n")
    return

# %%
for repJson in jsonReps:
    print(repJson)
    makeSRT(repJson)
# Out:
# 8
# problème
# pb 0 1
# 8
# found 11 150
# found 11 150 javais 00:01:17,939 javais 00:00:17,899
# 00:01:00,000
# ('00:01:18,480', '00:01:18,640', 'oublié', 0.993) ('00:01:18,480', '00:01:18,640', 'oublié', 0.992)
# 8
# problème
# pb 1 2
# 00:00:00,000 00:00:04,740 Je m'appelle [*] Noah, j'ai 7 ans.
# 00:00:06,179 00:00:11,919 Et sur cette image, je vois un garçon [*] qui [*] a un ballon en [*] train de courir,
# 00:00:12,339 00:00:13,740 et son ballon est en coeur.
# 00:00:14,660 00:00:18,579 La deux petites [*] filles, elles écoutent la danse.
# 00:00:19,719 00:00:21,620 [*] La petite fille, elle court.
# 00:00:23,019 00:00:29,760 Un garçon qui a des [*] lunettes et une casquette, il s'y assit. Il a des parents avec son bébé.
# 00:00:30,320 00:00:34,658 Un garçon qui a une balle avec un sac.
# 00:00:35,179 00:00:37,840 Je vois des petits oiseaux, je vois une mamie.
# 00:00:39,539 00:00:48,140 [*] Je vois un garçon en train de courir, une fille qui n'est pas contente, une fille qui a craint de marcher, [*] et une [*] fille qui est derrière là.
# 00:00:49,439 00:00:48,140 Et comme souvenir, je suis allée au parc.
# 8
# problème
# pb 0 1
# 00:00:00,000 00:00:01,399 [*] Sur l'image,
# 00:00:01,659 00:00:08,519 [*] je vois [*] des [*] filles qui ont un t-shirt en tomate,
# 00:00:09,679 00:00:16,338 il y a une [*] fille qui [*] met une botte, il y a la maîtresse,
# 00:00:17,160 00:00:29,160 il y a une fille qui fait des bulles, [*] il y a une fille qui a des lunettes, il y a des garçons qui sourient, [*] il y a le garçon qui tire la langue,
# 00:00:29,899 00:00:39,859 [*] il y a des ballons, [*] il y a des casquettes, sur le [*] tableau je vois des maths,
# 00:00:41,600 00:00:43,820 je vois la lumière, la maîtresse,
# 00:00:48,020 00:00:55,320 [*] et après [*] moi [*] j'étais à l'avion, [*] j'étais au Vietnam,
# 00:00:55,560 00:00:55,320 j'ai passé une bonne journée.
# 00:00:00,000 00:00:08,480 [*] Je m'appelle Athénaïs et sur cette image, [*] je [*] vois une fontaine, [*] des parents,
# 00:00:10,580 00:00:15,259 une petite fille [*] qui se cache derrière un arbre, [*] des oiseaux,
# 00:00:17,899 00:00:26,000 une petite fille avec son cartable, [*] un banc, [*] un portail.
# 00:00:29,899 00:00:26,000 [*] De l'herbe, [*] des maniers, [*] des murs.
# 00:00:00,000 00:00:06,280 Je m'appelle [*] Kevin et j'ai 7 [*] ans. [*] Je [*] vois un ballon au cœur,
# 00:00:06,900 00:00:09,660 je vois un garçon qui écoute de la musique,
# 00:00:09,900 00:00:16,480 je [*] vois une fille qui est cachée, je vois une grand-mère, je vois des bâtiments,
# 00:00:16,899 00:00:19,678 je vois [*] un garçon qui est assis,
# 00:00:19,899 00:00:22,559 [*] je [*] vois un bébé,
# 00:00:22,899 00:00:28,660 [*] je [*] vois un garçon qui court avec son ballon, je vois une fontaine,
# 00:00:28,899 00:00:30,500 je vois une fille qui court,
# 00:00:30,899 00:00:32,259 je vois des [*] fleurs,
# 00:00:32,899 00:00:36,618 [*] et [*] il y a un autre garçon qui court,
# 00:00:36,899 00:00:43,500 [*] et [*] il [*] y a un [*] autre garçon qui mange une glace,
# 00:00:43,899 00:00:43,500 [*] je vois un grand-papa, une maman,
# 00:00:00,000 00:00:07,299 A ses parents, [*] je vois une [*] petite fille qui se cache derrière un arbre,
# 00:00:07,559 00:00:08,859 une petite mamie,
# 00:00:11,019 00:00:15,859 un garçon qui écoute de la musique, [*] une fille avec qui mange une glace,
# 00:00:17,420 00:00:24,600 je vois un petit garçon qui court avec un ballon-cœur, [*] un portail, [*] des maisons,
# 00:00:26,920 00:00:29,079 [*] un banc,
# 00:00:29,300 00:00:44,240 [*] une [*] petite [*] fille [*] qui fait « [*] oh », [*] un [*] petit garçon et un petit garçon qui court avec son ballon.
# 00:00:46,119 00:00:44,240 C'est fini.
# 00:00:00,000 00:00:04,500 Je m'appelle Julia, j'ai 7 ans. Sur cette image, je vois des parents.
# 00:00:05,400 00:00:07,580 Je vois un portail qui est à moitié ouvert,
# 00:00:07,860 00:00:09,679 [*] une fontaine,
# 00:00:09,900 00:00:12,679 [*] des oiseaux qui ont à [*] manger,
# 00:00:13,560 00:00:15,618 une petite fille [*] avec une [*] robe,
# 00:00:15,820 00:00:18,440 un garçon qui court avec son ballon,
# 00:00:19,000 00:00:20,500 quelqu'un qui écoute de la musique,
# 00:00:20,739 00:00:23,838 [*] une fille qui mange de la glace, un sac,
# 00:00:24,100 00:00:30,420 un buisson avec des fleurs, [*] un petit garçon [*] avec une casquette et des lunettes,
# 00:00:31,219 00:00:36,899 des [*] parents avec un bébé, [*] une mamie, [*] une fille qui fait « [*] oh »,
# 00:00:37,539 00:00:42,380 une fille qui est [*] cachée derrière un arbre, [*] quelqu'un qui court avec son ballon,
# 00:00:43,340 00:00:42,380 et une fontaine, et c'est tout.
# 8
# found 6 150
# found 6 150 cognait 00:01:02,200 cognait 00:00:01,960
# 00:00:59,999
# ('00:01:02,579', '00:01:02,700', 'les', 0.996) ('00:01:02,579', '00:01:02,699', 'les', 0.99)
# 00:00:00,000 00:00:02,338 Sur cette [*] image,
# 00:00:02,560 00:00:08,640 je vois [*] une [*] petite fille qui fait une bulle de chewing-gum.
# 00:00:09,560 00:00:13,599 Je vois une fille qui croise les bras,
# 00:00:13,820 00:00:16,420 [*] une [*] fille qui sourit.
# 00:00:17,640 00:00:29,620 Je vois [*] une maîtresse [*] qui [*] a l'air d'avoir [*] chaud. Je vois un petit garçon [*] et pour moi, sur cette image, ils font une photo de classe.
# 00:00:30,760 00:00:37,500 Et [*] je vois une petite fille [*] avec une queue de cheval, un petit garçon qui tire la langue,
# 00:00:38,479 00:00:45,880 un garçon qui a des lunettes, [*] un garçon avec un pull bleu avec des rayures rouges et blanches.
# 00:00:46,219 00:00:51,118 Et aussi, comme [*] souvenir que j'aimerais dire, une fois avec [*] le centre,
# 00:00:51,700 00:00:58,780 on a été [*] à Wallys. [*] On a fait un alligator et [*] on a fait une attraction [*] où on montait dans des bouées sur l'eau.
# 00:00:59,439 00:01:02,200 Et dans ces bouées, quand on [*]
# 00:01:02,579 00:01:04,197 les murs, ça nous faisait tourner,
# 00:01:04,718 00:01:04,197 il y avait des mini-cascades, [*] et voilà.
# 00:00:00,000 00:00:02,000 [*] Sur cette image,
# 00:00:02,240 00:00:06,878 [*] je vois un portail, [*] une centaine,
# 00:00:07,120 00:00:10,778 [*] des fleurs,
# 00:00:11,039 00:00:12,919 [*] un ballon en [*] cœur,
# 00:00:13,140 00:00:18,780 [*] une fille qui mange une glace, [*] un garçon qui écoute de la musique,
# 00:00:19,219 00:00:26,719 [*] une fille qui n'est pas contente, [*] un bébé [*] avec ses parents,
# 00:00:26,960 00:00:26,719 [*] une mamie qui donne à [*] manger aux [*] oiseaux, une fille avec son cartable qui marche [*] tranquillement. [*] C'est bon.
# 00:00:00,000 00:00:06,418 [*] J'ai déjà fait ma liste de Noël, alors j'ai commandé une montre,
# 00:00:07,940 00:00:09,980 où il y a des jeux où on peut envoyer des messages,
# 00:00:10,300 00:00:10,859 un téléphone,
# 00:00:11,439 00:00:14,679 [*] une table à repasser,
# 00:00:19,660 00:00:31,420 [*] j'ai demandé [*] plein [*] de choses, d'accord ? [*] Je crois que l'été prochain,
# 00:00:31,699 00:00:34,820 [*] je [*] retournerai en Corse,
# 00:00:36,259 00:00:39,658 une [*] fois, [*] et bien ma chienne qui s'est fait mal à la patte,
# 00:00:41,880 00:00:39,658 et puis voilà.
# 8
# found 8 131
# found 8 131 un 00:01:04,019 un 00:00:03,759
# 00:01:00,040
# ('00:01:04,200', '00:01:04,319', '[*]', 0) ('00:01:04,200', '00:01:04,360', '[*]', 0)
# 8
# found 14 261
# found 14 261 toboggan 00:02:07,118 toboggan 00:00:06,879
# 00:02:00,061
# ('00:02:09,680', '00:02:09,838', 'il', 0.154) ('00:02:09,680', '00:02:09,861', 'il', 0.161)
# 8
# found 56 401
# found 56 401 il 00:03:46,860 il 00:00:46,659
# 00:03:00,102
# ('00:03:46,961', '00:03:47,139', 'y', 0.676) ('00:03:46,961', '00:03:47,181', 'y', 0.983)
# 8
# found 2 429
# found 2 429 y 00:04:01,882 y 00:00:01,080
# 00:04:00,701
# ('00:04:01,942', '00:04:03,802', '[*]', 0) ('00:04:01,942', '00:04:02,841', '[*]', 0)
# 00:00:00,000 00:00:05,580 En fait, c'est un livre où il y a des cabanes [*] dans les arbres.
# 00:00:06,419 00:00:09,618 Il y a un [*] arbre [*] blanc,
# 00:00:11,320 00:00:13,640 et [*] après il y a un arbre vert,
# 00:00:14,439 00:00:16,018 il y a des poissons,
# 00:00:17,920 00:00:19,300 il y a des papillons,
# 00:00:30,059 00:00:32,899 J'ai dit non, [*] bien [*] sûr, parce que j'avais encore Anna.
# 00:00:33,560 00:00:37,759 Et Anna a [*] commencé à pleurer parce qu'Anis a [*] commencé à faire du harcèlement,
# 00:00:38,539 00:00:40,280 et Anis de plus en plus vite,
# 00:00:40,759 00:00:43,618 et elle a commencé à comprendre que ce n'était pas bien ce qu'elle faisait.
# 00:00:44,399 00:00:48,000 Et [*] donc, elle a commencé à arrêter de moi en moi,
# 00:00:48,539 00:00:51,219 et elle a commencé à faire des câlins, à dire désolé à Anna,
# 00:00:51,780 00:00:55,118 et à me dire désolé d'être jalouse d'Anna comme ça.
# 00:00:57,000 00:00:55,118 [*] Merci.
# 00:00:00,000 00:00:04,960 Je m'appelle Georges et j'ai un peu plus de 8 ans et demi.
# 00:00:05,660 00:00:10,179 Sur cette [*] image, je vois une maîtresse qui a l'air d'avoir chaud,
# 00:00:11,699 00:00:18,859 [*] une [*] fille avec [*] un t-shirt [*] vert, enfin une blouse verte et un t-shirt avec une pomme.
# 00:00:19,920 00:00:22,359 Je vois un garçon qui tient un ballon.
# 00:00:23,399 00:00:32,039 Il y a une [*] fille qui mâche un chewing-gum. Sur cette image, [*] je [*] vois un intello, [*] un garçon avec une chemise rouge,
# 00:00:33,439 00:00:39,700 un garçon qui tire la langue, [*] une [*] fille [*] avec une robe,
# 00:00:41,600 00:00:43,798 une fille qui tient un [*] livre.
# 00:00:45,420 00:00:46,719 Et comme [*] souvenir,
# 00:00:46,920 00:00:46,719 [*] une fois je suis allé à Walibi pendant les vacances quand j'étais parti par loin de la Tour du Pain et de Lyon.
# 8
# found 2 112
# found 2 112 un 00:00:59,000 un 00:00:03,279
# 00:00:55,638
# ('00:00:59,159', '00:01:03,920', 'gorille,', 0.773) ('00:00:59,158', '00:00:59,578', 'gorille,', 0.563)
# 8
# found 12 236
# found 12 236 avec 00:01:59,497 avec 00:00:04,179
# 00:01:55,598
# ('00:01:59,978', '00:02:00,179', 'un', 0.987) ('00:01:59,977', '00:02:00,157', 'un', 0.997)
# 5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 for repJson in jsonReps:
# ----> 2     makeSRT(repJson)
#
# Cell In[15], line 13, in makeSRT(repJson)
#      11 with open(json2) as inFile:
#      12     whisper2=json.load(inFile)
# ---> 13 newSrt=pasteWords(srt,whisper2)
#      14 if not newSrt:
#      15     print("pb",i-1,i)
#
# Cell In[14], line 19, in pasteWords(srt, whisper2)
#      17     else:
#      18         i+=1
# ---> 19 if idx:
#      20     print("found",i,idx,srtList[idx],srt[idx][0],w2List[i],w2[i][0])
#      21     tDecal=timestamp2second(srt[idx+1][0])-timestamp2second(w2[i+1][0])
#
# UnboundLocalError: cannot access local variable 'idx' where it is not associated with a value

# %% [raw]
# w2=getWords(whisper2)
# w2List=getList(w2)

# %%
segments=len(glob.glob(repJson+"*.json"))
segments
pause=0.200
