# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os,re,nltk,difflib
sns.set_style("whitegrid")

def ding():
    os.system('afplay /System/Library/Sounds/Submarine.aiff')

# %% [markdown]
# ### Choisir le match

# %%
# rep="/Users/gilles/Downloads/Traitements_GB/"
rep="/Users/gilles/Github/AMBK-SportsCom/Chaines/Traitements_GB/"
match="FR-AR"
# match="FR-NZ"
nFile="Chaines-%s-fr.xlsx"%match

# %%
dfBrut=pd.read_excel(rep+nFile,index_col=None)
dfBrut.columns="transcription cat lemme referent numChaine chaineIndex chaineDep".split(" ")

# %%
df=dfBrut["transcription cat lemme referent numChaine chaineIndex chaineDep".split(" ")].copy()
df.referent=df.referent.str.strip()
df.head(50)
# Out:
#    transcription       cat     lemme referent  numChaine  chaineIndex  \
# 0          après       PRP     après      NaN        NaN          NaN
# 1          avoir  VER:infi     avoir      NaN        NaN          NaN
# 2        demandé  VER:pper  demander      NaN        NaN          NaN
# 3             si       KON        si      NaN        NaN          NaN
# 4           tout   PRO:IND      tout      NaN        NaN          NaN
# 5             le   DET:ART        le      NaN        NaN          NaN
# 6          monde       NOM     monde      NaN        NaN          NaN
# 7          était  VER:impf      être      NaN        NaN          NaN
# 8           prêt       ADJ      prêt      NaN        NaN          NaN
# 9              ,       PUN         ,      NaN        NaN          NaN
# 10            le   DET:ART        le      NaN        NaN          NaN
# 11          coup       NOM      coup      NaN        NaN          NaN
# 12            d'       PRP        de      NaN        NaN          NaN
# 13         envoi       NOM     envoi      NaN        NaN          NaN
# 14            de       PRP        de      NaN        NaN          NaN
# 15            la   DET:ART        le      NaN        NaN          NaN
# 16         coupe       NOM     coupe      NaN        NaN          NaN
# 17            du   PRP:det        du      NaN        NaN          NaN
# 18         monde       NOM     monde      NaN        NaN          NaN
# 19          deux       NUM      deux      NaN        NaN          NaN
# 20         mille       NUM     mille      NaN        NaN          NaN
# 21          sept       NUM      sept      NaN        NaN          NaN
# 22           est  VER:pres      être      NaN        NaN          NaN
# 23         donné  VER:pper    donner      NaN        NaN          NaN
# 24           par       PRP       par      NaN        NaN          NaN
# 25         David       NAM     David    J-F10        1.0          1.0
# 26        Skrela       NAM    Skrela    J-F10        1.0          1.0
# 27             .      SENT         .      NaN        NaN          NaN
# 28         allez  VER:pres     aller      NaN        NaN          NaN
# 29            de       PRP        de      NaN        NaN          NaN
# 30         suite       NOM     suite      NaN        NaN          NaN
# 31          dans       PRP      dans      NaN        NaN          NaN
# 32            le   DET:ART        le      NaN        NaN          NaN
# 33          camp       NOM      camp      NaN        NaN          NaN
# 34           euh       INT       euh      NaN        NaN          NaN
# 35      argentin       ADJ  argentin      NaN        NaN          NaN
# 36             .      SENT         .      NaN        NaN          NaN
# 37          avec       PRP      avec      NaN        NaN          NaN
# 38            un   DET:ART        un      NaN        NaN          NaN
# 39        départ       NOM    départ      NaN        NaN          NaN
# 40            de       PRP        de      NaN        NaN          NaN
# 41       Roncero       NAM   Roncero     J-A1        2.0          1.0
# 42             .      SENT         .      NaN        NaN          NaN
# 43        Pichot       NAM    Pichot     J-A9        3.0          1.0
# 44             a  VER:pres     avoir      NaN        NaN          NaN
# 45        appelé  VER:pper   appeler      NaN        NaN          NaN
# 46            le   DET:ART        le      NaN        NaN          NaN
# 47        ballon       NOM    ballon      NaN        NaN          NaN
# 48             ,       PUN         ,      NaN        NaN          NaN
# 49          pour       PRP      pour      NaN        NaN          NaN
#
#     chaineDep
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        0.0
# 26        0.0
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        0.0
# 42        NaN
# 43        0.0
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN

# %%
nbMots=len(df[~df.cat.isin(["PUN","SENT"])])
print(match,nbMots)
# Out:
# FR-AR 16961

# %% [markdown]
# ### Calcul des chaines
# - nombre de chaines par longueur
#     - une chaine = chaineDep==0
#     - longeur l = max chaineDep==l

# %%
lMax=int(df.chaineIndex.max())
nChaines={}
for l in range(1,lMax+1):
    nbChaines=len(df.loc[df.chaineIndex==l])
    nChaines[l]=nbChaines
print(nChaines)
lChaines={}
lChaines[lMax]=nChaines[lMax]
for i in range(lMax-1):
    lChaines[lMax-i-1]=nChaines[lMax-i-1]-nChaines[lMax-i]
# lChaines
# Out:
# {1: 1871, 2: 466, 3: 266, 4: 103, 5: 57, 6: 39, 7: 18, 8: 13, 9: 11, 10: 8, 11: 4, 12: 2, 13: 1, 14: 1, 15: 1}

# %% [markdown]
# ## Repérage de problèmes
# - changement de référent pour un même numéro de chaine

# %%
df.loc[df.numChaine==196]
# Out:
#      transcription      cat     lemme referent  numChaine  chaineIndex  \
# 3129           ces  PRO:DEM        ce      GTA      196.0          1.0
# 3130     argentins      NOM  argentin      GTA      196.0          1.0
# 3131           les  DET:ART        le      GTA      196.0          2.0
# 3139           ils  PRO:PER        il      GTA      196.0          3.0
# 3144           ils  PRO:PER        il      GTA      196.0          4.0
# 3149           ils  PRO:PER        il      GTA      196.0          5.0
# 3165           les  PRO:PER     la|le      GTA      196.0          6.0
#
#       chaineDep    indexType
# 3129        0.0  PRO:DEM NOM
# 3130        0.0  PRO:DEM NOM
# 3131        1.0      DET:ART
# 3139        2.0      PRO:PER
# 3144        3.0      PRO:PER
# 3149        4.0      PRO:PER
# 3165        5.0      PRO:PER

# %%
df.groupby(["numChaine","referent"]).sum().reset_index().groupby("numChaine")["referent"].sum().unique()
# Out:
# array(['J-F10', 'J-A1', 'J-A9', 'J-A10', 'GPF', 'GPA', 'J-F2', 'J-F15',
#        'thierry', 'GTA', 'J-A2', 'MS', 'GTF', 'J-F6', 'J-A5',
#        'J-A4 ou J-A8', 'J-F11', 'J-F9', 'J-F3', 'E', 'J-A12', 'MAJV',
#        'buteurS', 'J-A12 J-A13', 'MrL', 'buteur1', 'FL', 'AA', 'JM',
#        'BLE', 'J-A15', 'J-F7', 'J-A13 OU J-A8', 'J-A14', 'J-A12 ou J-A13',
#        'J-A3', 'J-F5', 'J-F8', 'J-A12 + J-A13', 'J-F12', 'J-F14', 'edf+',
#        'J-F13', 'E anglais', 'Marconnet', 'J-F21', 'J-F6 + J-F7',
#        'J-A9J-F9', 'J-F22', 'J-A7', 'MSthierry', 'J-F1', 'GTAedf+',
#        'J-F11J-F13', 'J-F4', 'JML', 'Buteur1', 'GP', 'IND', 'FA', 'J-F18',
#        'TU', 'J-F20', 'J-F17', 'J-F16', 'J-A12/A13', 'J-A18', 'Gaëtan',
#        'olivier', 'GTG', 'J-A6', 'J-A4/A8', 'J-A19', 'GTJ', 'J-A12/13',
#        'J-F19', 'R', 'GTFJ-F8', 'AAR', 'J-A22', 'JB', 'GTAIND', 'J-A16',
#        'J-A11', 'J-A4', 'J-A4+J-A1', 'GTAGTF', 'GRP', 'GRF', 'téléspé',
#        'rugbygénéral', 'J-F9+J-F8', 'J-A9+J-F9', 'GRP+téléspé', 'SB',
#        'edf', 'JD', 'IND GTF', 'IND GPF', 'J-F8 + J-F6', 'J-F10 ou J-F12',
#        'edf+rugbygénéral', 'GRPGTA', 'J-F12 + J-F13', 'MD', 'ML'],
#       dtype=object)

# %%
pbCat=df.loc[(df.chaineIndex.notnull())&df.cat.str.contains("VER")]["transcription"].unique().tolist()
print('", "'.join(pbCat))
catNAM=["Parra", "Nonu", "Carter", "Milner-Skudder", "Picamoles", "Nakaitaci", "Basta"]
# Out:
# el", "anglais", "plume", "organise", "aile

# %%
df.loc[(df.transcription.isin(catNAM))&(df.cat!="NAM"),"cat"]="NAM"

# %%
lNAM=df.loc[df.cat=="NAM","transcription"].unique().tolist()
print('", "'.join(lNAM))
# Out:
# David", "Skrela", "Roncero", "Pichot", "Hernandez", "France", "Raphaël", "Ibanez", "Cédric", "Heymans", "Thierry", "Agustin", "Ledesma", "Mario", "Monsieur", "Spreadbury", "Juan", "Martin", "Rémy", "Albacete", "Fernandez", "Lobbe", "Dominici", "Mignoni", "Villiers", "Pieter", "Bernard", "Laporte", "Felipe", "Contepomi", "Marc", "Antoine", "Jamet", "Val-de-Reuil", "Marc-Antoine", "Argentine", "Loffreda", "Leicester", "Fabrice", "Landreau", "Jo", "Nani", "Corleto", "Imanol", "Harinordoquy", "Lucas", "Borges", "Pierre", "Scelzo", "Christope", "Fabien", "Pelous", "Betsen", "Jauzion", "Rougerie", "Traille", "Serge", "Ellis", "Marconnet", "Clermont", "Damien", "Frédéric", "Michalak", "Arg", "Leguizamon", "Olivier", "Milloud", "Rodrigo", "Français", "Fred", "Angleterre", "Castres", "Bègles", "Ignacio", "Álvarez", "Kairelis", "Lacroix", "Jérôme", "Thion", "Saint-Denis", "Jean-Michel", "Larqué", "Christophe", "Brenard", "Sébastien", "Chabal", "Rémi", "Umaga", "Biarritz", "Dusautoir", "Jean-Baptiste", "Szarzewski", "Senillosa", "Gaïtan", "Arthur", "Dany", "Boon", "Christian", "Corletto", "Ostiglia", "Lobe", "#Alvarez", "Carelis#", "Yannick", "Elissalde", "#Ostiglia#", "Corletto#", "#Lucas", "Borges#", "Chapman", "Attila", "Amélie", "Mauresmo", "Millaud§", "Julien", "Bonnaire", "Dimitri", "Australie", "Felippe", "Afrique", "Lodesma", "Bonorino", "Béziers", "Rou", "Borgès", "Dickinson", "Laurens", "Alvarez", "Carelis", "Jacques", "Brunel", "Blanco", "Duron", "Austiglia", "Celin", "Celinoia", "Montpellier", "Toulouse", "Szarzweski", "Sinnilosa", "Aguila", "leguizamon", "Napoléon", "Harinordiquy", "Szarsweski", "Jean", "Dunia", "Irlande", "Cardiff", "Nouvelle-Zélande", "Ecosse", "Italie", "Paris", "Denis", "Brogniart", "Jean-Pierre", "Hueber", "Eric", "All", "Black

# %%
lNAM=sorted(["David", "Skrela", "Pichot", "Hernandez", "France", "Raphaël", "Ibanez", "Cédric", "Heymans", "Thierry", "Agustin", "Ledesma", "Mario", "Spreadbury", "Juan", "Martin", "Rémy", "Albacete", "Fernandez", "Lobbe", "Dominici", "Mignoni", "Villiers", "Pieter", "Bernard", "Laporte", "Felipe", "Contepomi", "Marc", "Antoine", "Jamet", "Val-de-Reuil", "Marc-Antoine", "Loffreda", "Leicester", "Fabrice", "Landreau", "Nani", "Corleto", "Imanol", "Harinordoquy", "Lucas", "Borges", "Pierre", "Scelzo", "Christope", "Fabien", "Pelous", "Betsen", "Jauzion", "Serge", "Ellis", "Marconnet", "Clermont", "Damien", "Frédéric", "Michalak", "Arg", "Leguizamon", "Olivier", "Milloud", "Rodrigo", "Roncero", "Français", "Fred", "Angleterre", "Castres", "Bègles", "Ignacio", "Álvarez", "Kairelis", "Lacroix", "Jérôme", "Thion", "Saint-Denis", "Jean-Michel", "Larqué", "Christophe", "Brenard", "Sébastien", "Chabal", "Rémi", "Umaga", "Biarritz", "Dusautoir", "Jean-Baptiste", "Szarzewski", "Senillosa", "Gaïtan", "Arthur", "Dany", "Boon", "Christian", "Corletto", "Ostiglia", "Lobe", "#Alvarez", "Carelis#", "Yannick", "Elissalde", "Corletto#", "#Lucas", "Borges#", "Chapman", "Attila", "Amélie", "Mauresmo", "Millaud§", "Julien", "Bonnaire", "Dimitri", "Australie", "Felippe", "Afrique", "Lodesma", "Bonorino", "Béziers", "Rou", "Borgès", "Dickinson", "Laurens", "Alvarez", "Carelis", "Jacques", "Brunel", "Blanco", "Austiglia", "Celin", "Celinoia", "Duron", "Montpellier", "Jo", "Toulouse", "Szarzweski", "Sinnilosa", "Aguila", "Napoléon", "Harinordiquy", "Szarsweski", "Jean", "Dunia", "Irlande", "Cardiff", "Nouvelle-Zélande", "Ecosse", "Italie", "Paris", "Denis", "Brogniart", "Jean-Pierre", "Hueber", "Eric", "All", "Black"]+["Rougerie","Traille","#Ostiglia#","leguizamon"])

lNAM=["Cardiff", "Bernard", "Christian", "France", "Philippe", "Saint-André", "Blacks", "Eddy", "Arous", "Guilhem", "Guirado", "Rabah", "Slimani", "Pascal", "Yohan", "Maestri", "Thierry", "Dusautoir", "Leroux", "Louis", "Picamoles", "Morgan", "Parra", "Fred", "Michalak", "Wesley", "Fofana", "Alexandre", "Dumoulin", "Scott", "Spedding", "Noa", "Nakaitaci", "Brice", "Dulin", "Tillous-Borde", "Irlande", "Bastareaud", "Steve", "Hansen", "Crockett", "Dane", "Coles", "Owen", "Franks", "Brodie", "Retallick", "Samuel", "Whitelock", "Jerôme", "Kaino", "Richie", "McCaw", "Kieran", "Read", "Aaron", "Smith", "Carter", "Ma'a", "Nonu", "Conrad", "Milner-Skudder", "Julian", "Savea", "Millenium", "Nouvelle-Zélande", "Cali", "Français", "Kapa", "Mealamu", "All", "Nigel", "Owens", "Joubert", "Barnes", "Jérôme", "Cole", "Frédéric", "Retallik", "Yannick", "Speeding", "Woodcock", "Sppeding", "Fredéric", "Rémi", "Talès", "Rizzoli", "Yoann", "Nicolas", "Milner", "Cory", "Jane", "Israel", "Dagg", "Naholo", "Joël", "Jutge", "Afrique", "Moody", "Joe", "Roumanie", "K", "T", "Jonah", "Lomu", "Black", "Califano", "Barrett", "Beauden", "Chris-", "Van", "Merwe", "Peyper", "Faumuina", "Uini", "Atonio", "Charlie", "Sunny", "B", "cali", "Dimitri", "Szarzewski", "TF1", "Australie", "Ecosse", "Delage", "Lacroix", "Benjamin", "Kayser", "Mathieu", "Kevin", "Vincent", "Debaty", "Remy", "Vito", "Kerr-Barlow", "Christiann", "Rory", "Kockott", "Basta", "Damien", "Chouly", "Tignes", "Oakland", "Haka", "Pango", "Néo-Zéd", "Toulon", "David", "Choki", "François", "Trinh-Duc", "Denis", "Brésil", "Allemagne", "Japon", "Paris"]
df.loc[(df.transcription.isin(lNAM))&(df.cat!="NAM")]
# Out:
# Empty DataFrame
# Columns: [transcription, cat, lemme, referent, numChaine, chaineIndex, chaineDep]
# Index: []

# %%
df.loc[(df.transcription.isin(lNAM))&(df.cat!="NAM"),"cat"]="NAM"
df.loc[(df.transcription=="on")&(df.cat!="PRO:PER"),"cat"]="PRO:PER"
df.loc[(df.transcription=="lui")&(df.cat!="PRO:PER"),"cat"]="PRO:PER"
df.loc[(df.transcription=="Argentine")&(df.cat!="NAM"),"cat"]="NAM"

# %%
df.loc[df.numChaine==835]
# Out:
#       transcription      cat     lemme referent  numChaine  chaineIndex  \
# 15354           les  DET:ART        le      GPA      835.0          1.0
# 15355     Argentins      NOM  argentin      GPA      835.0          1.0
# 15357           ils  PRO:PER        il      GPA      835.0          2.0
#
#        chaineDep
# 15354        0.0
# 15355        0.0
# 15357        1.0

# %%
df.to_excel(rep+nFile,index=0)

# %% [markdown]
# # Etiquettes des éléments de chaines

# %%
def getType(row):
    if row.numChaine==row.numChaine:
        return dGroupes[(row.numChaine,row.chaineIndex)]
    else:
        return "ERROR"

# %%
dfGroupes=df.loc[(df.chaineDep.notnull())].groupby(["numChaine","chaineIndex"])[["cat","transcription"]].agg(" ".join)
dfGroupes.groupby("cat").count().sort_values("transcription",ascending=0).head(50)
# Out:
#                                      transcription
# cat
# PRO:PER                                        620
# NAM                                            611
# PRO:REL                                        172
# NAM NAM                                        164
# DET:ART NAM                                     69
# DET:POS                                         62
# DET:ART NOM                                     49
# DET:ART NOM PRP NAM                             37
# DET:ART NOM ADJ                                 25
# PRP:det NOM                                     18
# PRO:PER PRO:PER                                 17
# NOM NAM                                         11
# NOM                                              8
# PRP:det NAM                                      8
# PRO:DEM NOM                                      8
# NAM PRP NAM                                      7
# DET:ART NUM                                      7
# PRO:DEM NOM PRP NAM                              6
# DET:POS ADJ NAM                                  6
# PRP NAM                                          6
# DET:ART NOM PRP:det NOM                          4
# DET:ART NUM NOM                                  4
# DET:ART ADJ                                      4
# PRO                                              4
# DET:ART NOM NUM                                  3
# DET:ART NOM PRP DET:ART NOM PRP NAM              3
# NAM NOM                                          3
# NOM ADJ                                          3
# PRP:det NOM ADJ                                  3
# NOM PRP NAM                                      3
# NAM NAM NAM                                      3
# PRO:DEM NUM NOM ADJ                              2
# NAM ADJ                                          2
# ADJ NAM                                          2
# DET:ART NUM PRP NAM                              2
# DET:POS NOM                                      2
# ADJ                                              2
# NUM NOM ADJ                                      2
# DET:ART NOM PRP NOM                              2
# DET:ART NOM PRP DET:ART NAM                      2
# PRP:det NOM PRP NAM                              2
# DET:ART                                          2
# DET:ART ADJ ADJ                                  2
# PRO:REL PRO:REL                                  2
# DET:ART NOM ADJ ADJ                              2
# DET:ART ADJ NAM                                  2
# DET:ART ADJ NOM                                  2
# PRO:PER DET:ART NOM                              1
# PRP:det NAM NAM                                  1
# NUM NOM NOM                                      1

# %%
dGroupes=dfGroupes.to_dict()["cat"]
dGroupes
# Out:
# {(1.0, 1.0): 'NAM NAM',
#  (2.0, 1.0): 'NAM',
#  (3.0, 1.0): 'NAM',
#  (4.0, 1.0): 'NAM',
#  (4.0, 2.0): 'PRO:PER',
#  (4.0, 3.0): 'PRO:PER',
#  (4.0, 4.0): 'DET:POS',
#  (5.0, 1.0): 'DET:ART NOM ADJ',
#  (6.0, 1.0): 'DET:ART NOM ADJ',
#  (7.0, 1.0): 'DET:ART NOM PRP DET:ART NOM PRP NAM',
#  (7.0, 2.0): 'NAM NAM',
#  (7.0, 3.0): 'PRO:REL',
#  (8.0, 1.0): 'NAM',
#  (9.0, 1.0): 'NAM NAM',
#  (9.0, 2.0): 'PRO:PER',
#  (10.0, 1.0): 'NAM',
#  (11.0, 1.0): 'NAM',
#  (12.0, 1.0): 'NAM NAM',
#  (13.0, 1.0): 'NAM',
#  (14.0, 1.0): 'PRO:DEM NOM',
#  (15.0, 1.0): 'NAM NAM',
#  (15.0, 2.0): 'DET:ART NOM PRP:det NOM',
#  (15.0, 3.0): 'DET:ART NOM ADJ',
#  (16.0, 1.0): 'NAM',
#  (18.0, 1.0): 'NAM',
#  (18.0, 2.0): 'NAM NAM',
#  (18.0, 3.0): 'ADJ NAM',
#  (19.0, 1.0): 'DET:ART NOM',
#  (19.0, 2.0): 'PRO:REL',
#  (20.0, 1.0): 'DET:ART NOM ADJ',
#  (21.0, 1.0): 'PRP:det NOM ADJ',
#  (22.0, 1.0): 'NAM',
#  (23.0, 1.0): 'NAM NAM',
#  (23.0, 2.0): 'PRO:REL',
#  (24.0, 1.0): 'NAM',
#  (25.0, 1.0): 'NAM NAM',
#  (26.0, 1.0): 'NAM NAM',
#  (27.0, 1.0): 'NAM NAM NAM',
#  (28.0, 1.0): 'NAM NAM',
#  (29.0, 1.0): 'DET:ART NOM PRP NAM',
#  (31.0, 1.0): 'NAM',
#  (32.0, 1.0): 'NAM NAM',
#  (32.0, 2.0): 'PRO:PER',
#  (33.0, 1.0): 'NAM NAM',
#  (34.0, 1.0): 'NAM',
#  (35.0, 1.0): 'NAM NAM',
#  (38.0, 1.0): 'NAM',
#  (38.0, 2.0): 'PRO:PER',
#  (38.0, 3.0): 'NAM',
#  (39.0, 1.0): 'NAM',
#  (40.0, 1.0): 'NAM',
#  (40.0, 2.0): 'DET:POS',
#  (41.0, 1.0): 'PRP NAM',
#  (42.0, 1.0): 'DET:ART NOM PRP NAM',
#  (43.0, 1.0): 'NAM PRP NAM',
#  (44.0, 1.0): 'NAM',
#  (45.0, 1.0): 'NAM PRP NAM',
#  (45.0, 2.0): 'PRO:PER',
#  (45.0, 3.0): 'PRO:PER',
#  (48.0, 1.0): 'NAM NAM',
#  (48.0, 2.0): 'NAM NAM',
#  (49.0, 1.0): 'DET:ART NOM PRP NAM',
#  (50.0, 1.0): 'DET:ART ADJ',
#  (50.0, 2.0): 'PRO:REL',
#  (50.0, 3.0): 'PRO:PER',
#  (50.0, 4.0): 'PRO:REL',
#  (51.0, 1.0): 'NAM NAM',
#  (52.0, 1.0): 'NAM NAM NAM',
#  (52.0, 2.0): 'DET:ART ADJ NAM NAM',
#  (52.0, 3.0): 'PRO:REL',
#  (53.0, 1.0): 'NAM',
#  (54.0, 1.0): 'NAM',
#  (55.0, 1.0): 'NAM',
#  (55.0, 2.0): 'PRO:PER',
#  (56.0, 1.0): 'NAM',
#  (56.0, 2.0): 'DET:POS',
#  (57.0, 1.0): 'DET:ART NOM',
#  (57.0, 2.0): 'PRO:PER',
#  (58.0, 1.0): 'NAM',
#  (59.0, 1.0): 'DET:ART NAM',
#  (59.0, 2.0): 'PRO:REL',
#  (60.0, 1.0): 'NAM NAM',
#  (60.0, 2.0): 'NOM ADJ',
#  (60.0, 3.0): 'ADJ NOM NOM PRP DET:ART NOM PRP NAM',
#  (60.0, 4.0): 'NOM',
#  (61.0, 1.0): 'NAM',
#  (62.0, 1.0): 'DET:ART NOM',
#  (62.0, 2.0): 'PRO:PER',
#  (62.0, 3.0): 'PRO:PER',
#  (63.0, 1.0): 'NAM NAM',
#  (64.0, 1.0): 'DET:POS NOM PRP NOM',
#  (64.0, 2.0): 'NAM NAM',
#  (64.0, 3.0): 'DET:ART NOM PRP:det NOM ADJ',
#  (64.0, 4.0): 'ADJ NOM',
#  (65.0, 1.0): 'NAM',
#  (66.0, 1.0): 'PRP NAM',
#  (67.0, 1.0): 'NAM',
#  (68.0, 1.0): 'NAM',
#  (69.0, 1.0): 'DET:ART NOM ADJ',
#  (69.0, 2.0): 'PRO:REL',
#  (70.0, 1.0): 'NAM NAM',
#  (71.0, 1.0): 'PRP:det NOM',
#  (72.0, 1.0): 'DET:ART NOM PRP NAM',
#  (73.0, 1.0): 'PRP:det NOM',
#  (74.0, 1.0): 'NAM NAM',
#  (74.0, 2.0): 'DET:POS DET:POS',
#  (74.0, 3.0): 'PRO:PER',
#  (75.0, 1.0): 'DET:ART NOM ADJ',
#  (75.0, 2.0): 'PRO:PER',
#  (75.0, 3.0): 'DET:POS',
#  (75.0, 4.0): 'PRO:PER',
#  (75.0, 5.0): 'PRO:PER',
#  (75.0, 6.0): 'PRO:PER',
#  (75.0, 7.0): 'PRO:PER',
#  (75.0, 8.0): 'PRO:PER',
#  (75.0, 9.0): 'PRO:PER',
#  (76.0, 1.0): 'DET:ART NOM PRP DET:ART NOM PRP NAM',
#  (76.0, 2.0): 'PRO:PER',
#  (76.0, 3.0): 'NAM NAM',
#  (76.0, 4.0): 'PRO:PER',
#  (76.0, 5.0): 'NAM NAM',
#  (77.0, 1.0): 'NAM ADJ',
#  (78.0, 1.0): 'NAM NAM DET:ART NOM DET:ART NOM PRP PRO:DEM NOM PRP NAM',
#  (79.0, 1.0): 'DET:ART NOM PRP NAM',
#  (80.0, 1.0): 'NAM NAM',
#  (81.0, 1.0): 'NAM',
#  (82.0, 1.0): 'NAM',
#  (83.0, 1.0): 'NAM NAM',
#  (83.0, 2.0): 'PRO:PER',
#  (83.0, 3.0): 'NAM NAM',
#  (84.0, 1.0): 'NAM NAM',
#  (85.0, 1.0): 'NAM',
#  (86.0, 1.0): 'NAM',
#  (87.0, 1.0): 'NAM',
#  (89.0, 1.0): 'DET:ART NOM ADJ',
#  (90.0, 1.0): 'NAM',
#  (91.0, 1.0): 'DET:ART NUM NOM ADJ',
#  (92.0, 1.0): 'NAM NAM',
#  (93.0, 1.0): 'DET:ART',
#  (93.0, 2.0): 'PRO:REL',
#  (94.0, 1.0): 'NAM',
#  (95.0, 1.0): 'NAM NAM',
#  (96.0, 1.0): 'DET:ART NAM',
#  (97.0, 1.0): 'PRO:PER',
#  (97.0, 2.0): 'NAM',
#  (97.0, 3.0): 'NAM PRO:PER',
#  (98.0, 1.0): 'DET:ART NOM',
#  (99.0, 1.0): 'DET:ART NAM',
#  (100.0, 1.0): 'DET:ART NOM',
#  (100.0, 2.0): 'PRO:REL',
#  (101.0, 1.0): 'DET:ART NAM',
#  (102.0, 1.0): 'NAM',
#  (102.0, 2.0): 'DET:ART NOM ADJ',
#  (102.0, 3.0): 'PRO:REL',
#  (102.0, 4.0): 'PRO:REL',
#  (103.0, 1.0): 'NAM',
#  (103.0, 2.0): 'PRO:REL',
#  (103.0, 3.0): 'PRO:REL',
#  (104.0, 1.0): 'DET:ART NAM',
#  (105.0, 1.0): 'NAM',
#  (105.0, 2.0): 'PRO:PER',
#  (106.0, 1.0): 'NAM',
#  (107.0, 1.0): 'PRP:det NOM',
#  (107.0, 2.0): 'PRO:REL',
#  (107.0, 3.0): 'PRO:REL',
#  (108.0, 1.0): 'DET:ART NOM',
#  (108.0, 2.0): 'PRO:PER',
#  (108.0, 3.0): 'PRO:PER',
#  (109.0, 1.0): 'NAM NAM',
#  (109.0, 2.0): 'PRO:REL',
#  (109.0, 3.0): 'DET:POS',
#  (110.0, 1.0): 'NAM NAM',
#  (110.0, 2.0): 'PRO:REL',
#  (111.0, 1.0): 'PRP:det NOM ADJ',
#  (112.0, 1.0): 'NAM',
#  (113.0, 1.0): 'NAM',
#  (113.0, 2.0): 'DET:POS',
#  (114.0, 1.0): 'DET:ART NAM',
#  (115.0, 1.0): 'NAM',
#  (116.0, 1.0): 'NAM NAM',
#  (117.0, 1.0): 'DET:ART NOM',
#  (117.0, 2.0): 'PRO:REL',
#  (118.0, 1.0): 'NAM',
#  (119.0, 1.0): 'DET:ART NAM',
#  (120.0, 1.0): 'NAM',
#  (120.0, 2.0): 'PRO:REL',
#  (121.0, 1.0): 'NAM',
#  (122.0, 1.0): 'NAM',
#  (122.0, 2.0): 'PRO:REL',
#  (123.0, 1.0): 'NAM NAM',
#  (124.0, 1.0): 'NAM NAM',
#  (125.0, 1.0): 'NAM',
#  (125.0, 2.0): 'NAM',
#  (126.0, 1.0): 'NAM',
#  (127.0, 1.0): 'NAM',
#  (128.0, 1.0): 'NAM',
#  (128.0, 2.0): 'PRO:PER',
#  (129.0, 1.0): 'PRO:DEM NOM',
#  (129.0, 2.0): 'DET:ART NOM',
#  (129.0, 3.0): 'VER:simp NOM',
#  (129.0, 4.0): 'NAM',
#  (130.0, 1.0): 'NAM NAM',
#  (131.0, 1.0): 'NAM',
#  (132.0, 1.0): 'PRO:PER',
#  (132.0, 2.0): 'DET:ART NOM',
#  (132.0, 3.0): 'PRO:REL',
#  (133.0, 1.0): 'NAM',
#  (134.0, 1.0): 'DET:ART NOM',
#  (135.0, 1.0): 'NAM',
#  (135.0, 2.0): 'PRO:PER',
#  (135.0, 3.0): 'NAM',
#  (135.0, 4.0): 'PRO:PER',
#  (137.0, 1.0): 'NAM',
#  (138.0, 1.0): 'NAM',
#  (140.0, 1.0): 'DET:ART NOM',
#  (141.0, 1.0): 'DET:ART NOM ADJ',
#  (142.0, 1.0): 'DET:ART NAM',
#  (143.0, 1.0): 'PRP:det NAM',
#  (144.0, 1.0): 'NAM',
#  (145.0, 1.0): 'DET:ART ADJ NAM',
#  (146.0, 1.0): 'DET:ART NUM NOM',
#  (146.0, 2.0): 'NUM ADJ',
#  (147.0, 1.0): 'NAM',
#  (148.0, 1.0): 'NAM NOM NOM NAM',
#  (149.0, 1.0): 'NAM',
#  (150.0, 1.0): 'DET:ART NOM ADJ',
#  (150.0, 2.0): 'PRO:REL',
#  (151.0, 1.0): 'NAM',
#  (152.0, 1.0): 'NAM NAM',
#  (153.0, 1.0): 'NAM PRP NAM',
#  (154.0, 1.0): 'NAM',
#  (155.0, 1.0): 'NAM',
#  (156.0, 1.0): 'NAM',
#  (157.0, 1.0): 'PRO:PER',
#  (157.0, 2.0): 'NAM NAM',
#  (158.0, 1.0): 'NAM NAM',
#  (159.0, 1.0): 'PRO:PER',
#  (160.0, 1.0): 'DET:ART NAM',
#  (161.0, 1.0): 'NAM',
#  (162.0, 1.0): 'NAM',
#  (163.0, 1.0): 'NAM',
#  (163.0, 2.0): 'PRO:REL',
#  (163.0, 3.0): 'PRO:PER',
#  (164.0, 1.0): 'NAM',
#  (165.0, 1.0): 'DET:ART NAM NAM',
#  (165.0, 2.0): 'PRO:REL',
#  (165.0, 3.0): 'DET:POS',
#  (165.0, 5.0): 'PRO:PER',
#  (165.0, 6.0): 'PRO:PER',
#  (165.0, 7.0): 'PRO:PER',
#  (165.0, 8.0): 'NOM',
#  (165.0, 9.0): 'NAM',
#  (166.0, 10.0): 'PRO:PER',
#  (166.0, 11.0): 'PRO:PER',
#  (166.0, 12.0): 'PRO:PER',
#  (167.0, 1.0): 'DET:ART NAM',
#  (168.0, 1.0): 'NAM',
#  (169.0, 1.0): 'DET:ART NAM',
#  (170.0, 1.0): 'DET:ART NOM PRP DET:ART NOM PRP NAM',
#  (170.0, 2.0): 'PRO:REL',
#  (170.0, 3.0): 'PRO:DEM NOM',
#  (170.0, 4.0): 'PRO:REL',
#  (171.0, 1.0): 'PRP:det NAM',
#  (172.0, 1.0): 'PRP:det NAM',
#  (173.0, 1.0): 'PRP:det NAM NAM',
#  (174.0, 1.0): 'NOM VER:impf',
#  (174.0, 2.0): 'PRO:REL',
#  (174.0, 3.0): 'NAM NAM',
#  (174.0, 4.0): 'PRO:REL',
#  (175.0, 1.0): 'PRP:det NOM PRP NAM',
#  (176.0, 1.0): 'NAM',
#  (177.0, 1.0): 'PRO:DEM NUM NOM ADJ',
#  (178.0, 1.0): 'NOM ADJ',
#  (178.0, 2.0): 'DET:POS',
#  (179.0, 1.0): 'DET:ART NAM',
#  (180.0, 1.0): 'NAM',
#  (180.0, 2.0): 'PRO:REL',
#  (180.0, 3.0): 'DET:POS',
#  (181.0, 1.0): 'NAM',
#  (181.0, 2.0): 'PRO:PER',
#  (181.0, 3.0): 'DET:POS',
#  (182.0, 1.0): 'NOM PRP NOM',
#  (183.0, 1.0): 'DET:ART NUM',
#  (184.0, 1.0): 'DET:ART NOM',
#  (185.0, 1.0): 'PRO:PER PRO:PER',
#  (186.0, 1.0): 'DET:ART NOM NUM',
#  (187.0, 1.0): 'DET:ART NOM ADJ ADJ',
#  (189.0, 1.0): 'DET:ART ADJ NOM',
#  (191.0, 1.0): 'NAM',
#  (192.0, 1.0): 'PRO:REL ADJ',
#  (192.0, 2.0): 'PRO:DEM NAM',
#  (192.0, 3.0): 'DET:ART ADJ ADJ',
#  (193.0, 1.0): 'DET:ART ADJ',
#  (194.0, 1.0): 'NAM',
#  (195.0, 1.0): 'NAM',
#  (196.0, 1.0): 'PRO:DEM NOM',
#  (196.0, 2.0): 'DET:ART',
#  (196.0, 3.0): 'PRO:PER',
#  (196.0, 4.0): 'PRO:PER',
#  (196.0, 5.0): 'PRO:PER',
#  (196.0, 6.0): 'PRO:PER',
#  (197.0, 1.0): 'PRO:PER',
#  (197.0, 2.0): 'PRO:PER',
#  (197.0, 3.0): 'PRO:PER',
#  (197.0, 4.0): 'NAM NAM',
#  (198.0, 1.0): 'NAM',
#  (199.0, 1.0): 'NAM',
#  (200.0, 1.0): 'NUM NOM ADJ',
#  (201.0, 2.0): 'NAM NAM',
#  (201.0, 3.0): 'PRO:PER',
#  (201.0, 4.0): 'PRO:PER',
#  (201.0, 5.0): 'PRO:PER',
#  (202.0, 1.0): 'NAM',
#  (202.0, 2.0): 'PRO:PER',
#  (202.0, 3.0): 'PRO:PER',
#  (202.0, 4.0): 'NAM',
#  (204.0, 1.0): 'NAM',
#  (205.0, 1.0): 'NAM',
#  (206.0, 1.0): 'NAM',
#  (207.0, 1.0): 'NAM',
#  (208.0, 1.0): 'NAM',
#  (208.0, 2.0): 'PRO:REL',
#  (208.0, 3.0): 'PRO:PER',
#  (208.0, 4.0): 'DET:ART NOM VER:pres',
#  (209.0, 1.0): 'PRP NAM',
#  (210.0, 1.0): 'NAM',
#  (211.0, 1.0): 'NAM',
#  (212.0, 1.0): 'DET:ART NAM',
#  (212.0, 2.0): 'PRO:REL',
#  (213.0, 1.0): 'NAM',
#  (214.0, 1.0): 'DET:ART NUM NOM',
#  (215.0, 1.0): 'NAM NAM',
#  (216.0, 1.0): 'NAM',
#  (217.0, 1.0): 'NAM',
#  (218.0, 1.0): 'NAM NAM',
#  (219.0, 1.0): 'NAM',
#  (220.0, 1.0): 'NAM NAM',
#  (221.0, 1.0): 'DET:ART NAM',
#  (222.0, 1.0): 'NAM',
#  (222.0, 2.0): 'PRO:REL',
#  (222.0, 3.0): 'PRO:PER',
#  (223.0, 1.0): 'PRO:PER',
#  (223.0, 2.0): 'NAM',
#  (224.0, 1.0): 'DET:ART NAM',
#  (224.0, 2.0): 'PRO:PER',
#  (226.0, 1.0): 'PRO:PER',
#  (227.0, 1.0): 'NAM',
#  (228.0, 1.0): 'NAM',
#  (229.0, 1.0): 'NAM NAM',
#  (229.0, 2.0): 'PRO:REL',
#  (229.0, 3.0): 'DET:POS',
#  (230.0, 1.0): 'NAM NAM',
#  (231.0, 1.0): 'NAM',
#  (231.0, 2.0): 'NAM',
#  (232.0, 1.0): 'NAM',
#  (233.0, 1.0): 'NAM NAM',
#  (234.0, 1.0): 'NAM',
#  (235.0, 1.0): 'DET:ART NOM PRP NAM',
#  (236.0, 1.0): 'NAM',
#  (236.0, 2.0): 'PRO:PER',
#  (236.0, 3.0): 'DET:POS',
#  (237.0, 1.0): 'PRO:DEM NAM NOM PRO:DEM NOM ADJ',
#  (238.0, 1.0): 'DET:ART NAM',
#  (238.0, 2.0): 'DET:POS',
#  (240.0, 1.0): 'NAM',
#  (241.0, 1.0): 'NAM',
#  (242.0, 1.0): 'NAM',
#  (243.0, 1.0): 'NAM',
#  (244.0, 1.0): 'DET:ART NOM ADJ',
#  (244.0, 2.0): 'DET:ART NOM',
#  (244.0, 3.0): 'PRO:PER',
#  (245.0, 1.0): 'PRO:PER',
#  (246.0, 1.0): 'NAM',
#  (246.0, 2.0): 'PRO:REL',
#  (246.0, 3.0): 'DET:ART NOM',
#  (246.0, 4.0): 'PRO:PER',
#  (246.0, 5.0): 'PRO:PER',
#  (246.0, 6.0): 'NAM',
#  (247.0, 1.0): 'PRO:PER',
#  (248.0, 1.0): 'NAM',
#  (248.0, 2.0): 'NAM NAM',
#  (248.0, 3.0): 'PRO:REL',
#  (249.0, 1.0): 'NAM NAM',
#  (250.0, 1.0): 'NAM',
#  (251.0, 1.0): 'NAM',
#  (252.0, 1.0): 'NAM',
#  (252.0, 2.0): 'PRO:REL',
#  (253.0, 1.0): 'DET:ART NOM',
#  (254.0, 1.0): 'NAM',
#  (255.0, 1.0): 'NAM',
#  (256.0, 1.0): 'DET:ART NUM NOM',
#  (256.0, 2.0): 'NUM NOM NOM',
#  (257.0, 1.0): 'NAM',
#  (258.0, 1.0): 'NAM',
#  (258.0, 2.0): 'DET:POS',
#  (258.0, 3.0): 'PRO:PER',
#  (259.0, 1.0): 'NAM',
#  (260.0, 1.0): 'PRO:PER',
#  (260.0, 2.0): 'PRO:PER',
#  (260.0, 3.0): 'PRO:PER',
#  (260.0, 4.0): 'PRO:PER',
#  (261.0, 1.0): 'NAM',
#  (261.0, 2.0): 'DET:POS NOM',
#  (262.0, 1.0): 'PRO:PER',
#  (262.0, 2.0): 'PRO:PER',
#  (262.0, 3.0): 'PRO:PER',
#  (262.0, 4.0): 'PRO:PER',
#  (262.0, 5.0): 'PRO:PER',
#  (262.0, 6.0): 'PRO:PER',
#  (262.0, 7.0): 'PRO:PER',
#  (262.0, 8.0): 'PRO:PER',
#  (262.0, 9.0): 'PRO:PER',
#  (263.0, 1.0): 'NOM NAM',
#  (264.0, 1.0): 'NAM',
#  (264.0, 2.0): 'PRO:PER',
#  (265.0, 1.0): 'NAM',
#  (266.0, 1.0): 'NAM',
#  (267.0, 1.0): 'NAM',
#  (268.0, 1.0): 'NAM NAM',
#  (269.0, 1.0): 'NAM',
#  (270.0, 1.0): 'NAM PRP NAM',
#  (271.0, 1.0): 'NAM NAM',
#  (272.0, 1.0): 'NAM',
#  (273.0, 1.0): 'NAM',
#  (274.0, 1.0): 'NAM',
#  (275.0, 1.0): 'NAM',
#  (275.0, 2.0): 'NAM',
#  (276.0, 1.0): 'DET:ART NOM PRP NAM',
#  (277.0, 1.0): 'DET:ART ADJ',
#  (278.0, 2.0): 'DET:ART NUM',
#  (279.0, 1.0): 'DET:ART NUM',
#  (280.0, 1.0): 'NAM NAM',
#  (281.0, 1.0): 'DET:ART NOM PRP NAM',
#  (282.0, 1.0): 'NAM',
#  (283.0, 1.0): 'DET:ART NOM PRP:det NOM',
#  (283.0, 2.0): 'PRO:PER',
#  (283.0, 3.0): 'PRO:PER',
#  (284.0, 1.0): 'NAM',
#  (285.0, 1.0): 'NAM',
#  (286.0, 1.0): 'DET:ART NAM',
#  (287.0, 1.0): 'NAM',
#  (288.0, 1.0): 'NAM',
#  (289.0, 1.0): 'DET:ART NAM',
#  (290.0, 1.0): 'NAM',
#  (291.0, 1.0): 'NAM',
#  (292.0, 1.0): 'DET:ART NAM',
#  (292.0, 2.0): 'PRP:det ADJ',
#  (293.0, 1.0): 'NAM',
#  (294.0, 1.0): 'NAM',
#  (295.0, 1.0): 'NAM',
#  (295.0, 2.0): 'PRO:REL',
#  (295.0, 3.0): 'DET:POS',
#  (296.0, 1.0): 'NAM',
#  (296.0, 2.0): 'NAM',
#  (296.0, 3.0): 'DET:POS',
#  (296.0, 4.0): 'PRO:PER',
#  (296.0, 5.0): 'NAM',
#  (296.0, 6.0): 'PRO:PER',
#  (297.0, 1.0): 'NAM',
#  (298.0, 1.0): 'PRP:det NOM',
#  (299.0, 1.0): 'NAM',
#  (300.0, 1.0): 'NAM NAM',
#  (301.0, 1.0): 'NAM',
#  (302.0, 1.0): 'DET:ART NAM',
#  (302.0, 2.0): 'DET:POS',
#  (303.0, 1.0): 'NAM NAM',
#  (304.0, 1.0): 'DET:ART NAM',
#  (304.0, 2.0): 'PRO:PER',
#  (304.0, 3.0): 'PRO:PER',
#  (305.0, 1.0): 'PRO:PER',
#  (306.0, 1.0): 'DET:ART NOM',
#  (307.0, 1.0): 'NAM',
#  (308.0, 1.0): 'PRO:PER',
#  (308.0, 2.0): 'PRO:PER',
#  (308.0, 3.0): 'DET:ART NAM',
#  (308.0, 4.0): 'PRO:REL',
#  (308.0, 5.0): 'PRO:PER PRO:REL',
#  (309.0, 1.0): 'PRP:det NOM',
#  (310.0, 1.0): 'NAM',
#  (311.0, 1.0): 'NAM',
#  (312.0, 1.0): 'NAM',
#  (313.0, 1.0): 'DET:ART NOM ADJ',
#  (313.0, 2.0): 'PRO:REL',
#  (314.0, 1.0): 'NAM',
#  (315.0, 1.0): 'NAM',
#  (315.0, 2.0): 'PRO:REL',
#  (316.0, 1.0): 'NAM',
#  (317.0, 1.0): 'NAM',
#  (318.0, 1.0): 'NAM',
#  (319.0, 1.0): 'NAM',
#  (320.0, 1.0): 'DET:ART NAM',
#  (320.0, 2.0): 'PRO:PER',
#  (320.0, 3.0): 'PRO:PER',
#  (320.0, 4.0): 'PRO:PER',
#  (320.0, 5.0): 'PRO:PER',
#  (321.0, 1.0): 'NAM',
#  (321.0, 2.0): 'DET:POS',
#  (322.0, 1.0): 'PRO:PER',
#  (322.0, 2.0): 'PRO:DEM NOM PRP NAM',
#  (322.0, 3.0): 'PRO:PER',
#  (323.0, 1.0): 'DET:POS ADJ NAM',
#  (324.0, 1.0): 'NAM NAM',
#  (325.0, 1.0): 'DET:ART NAM',
#  (325.0, 2.0): 'PRO:REL',
#  (325.0, 3.0): 'PRO:REL',
#  (326.0, 1.0): 'DET:ART NAM',
#  (327.0, 1.0): 'NAM',
#  (328.0, 1.0): 'NAM NAM',
#  (328.0, 2.0): 'PRO:PER',
#  (328.0, 3.0): 'DET:POS',
#  (329.0, 1.0): 'NAM NAM',
#  (329.0, 2.0): 'DET:POS',
#  (330.0, 1.0): 'NAM NAM',
#  (331.0, 1.0): 'NAM',
#  (332.0, 1.0): 'NAM',
#  (333.0, 1.0): 'NAM',
#  (334.0, 1.0): 'NAM NAM',
#  (335.0, 1.0): 'NAM',
#  (335.0, 2.0): 'PRO:PER',
#  (336.0, 1.0): 'NAM',
#  (337.0, 1.0): 'NAM',
#  (337.0, 2.0): 'PRO:PER',
#  (337.0, 3.0): 'NAM NAM',
#  (338.0, 1.0): 'NAM',
#  (339.0, 1.0): 'NAM',
#  (339.0, 2.0): 'PRO:REL',
#  (339.0, 3.0): 'PRO:PER',
#  (340.0, 1.0): 'NAM',
#  (341.0, 1.0): 'NAM NAM',
#  (342.0, 1.0): 'NAM',
#  (343.0, 1.0): 'DET:ART NOM ADJ',
#  (344.0, 1.0): 'NAM',
#  (345.0, 1.0): 'NAM',
#  (346.0, 1.0): 'NAM',
#  (347.0, 1.0): 'NAM',
#  (348.0, 1.0): 'NAM',
#  (349.0, 1.0): 'NAM',
#  (350.0, 1.0): 'DET:ART NAM',
#  (351.0, 1.0): 'NAM',
#  (351.0, 2.0): 'PRO:REL',
#  (351.0, 3.0): 'PRO:PER',
#  (351.0, 4.0): 'PRO:PER',
#  (352.0, 1.0): 'NAM NAM',
#  (352.0, 2.0): 'DET:POS',
#  (352.0, 3.0): 'PRO:PER',
#  (353.0, 1.0): 'NAM',
#  (354.0, 1.0): 'NAM',
#  (354.0, 2.0): 'NAM',
#  (354.0, 3.0): 'NOM',
#  (355.0, 1.0): 'PRO:PER',
#  (355.0, 2.0): 'PRO:PER',
#  (355.0, 3.0): 'PRO:PER',
#  (356.0, 4.0): 'PRO:PER',
#  (356.0, 5.0): 'PRO:PER',
#  (356.0, 6.0): 'PRO:PER',
#  (356.0, 7.0): 'PRO:PER',
#  (356.0, 8.0): 'PRO:PER',
#  (356.0, 10.0): 'PRO:PER',
#  (356.0, 11.0): 'PRO:PER',
#  (356.0, 12.0): 'PRO:PER',
#  (356.0, 13.0): 'PRO:PER',
#  (356.0, 14.0): 'PRO:PER',
#  (356.0, 15.0): 'PRO:PER',
#  (357.0, 1.0): 'DET:ART NOM',
#  (358.0, 1.0): 'NAM',
#  (359.0, 1.0): 'NAM NAM',
#  (359.0, 3.0): 'PRO:REL',
#  (359.0, 4.0): 'PRO:REL',
#  (359.0, 5.0): 'PRO:PER',
#  (359.0, 6.0): 'PRO:PER',
#  (359.0, 7.0): 'PRO:REL',
#  (359.0, 8.0): 'PRO:REL',
#  (360.0, 1.0): 'PRO:PER',
#  (361.0, 1.0): 'NAM',
#  (362.0, 1.0): 'NAM',
#  (363.0, 1.0): 'NAM NAM NAM',
#  (364.0, 1.0): 'DET:ART NOM ADJ',
#  (365.0, 1.0): 'DET:ART NOM',
#  (366.0, 1.0): 'DET:ART NOM',
#  (366.0, 2.0): 'PRO:PER',
#  (367.0, 1.0): 'PRO:PER',
#  (367.0, 2.0): 'NAM',
#  (368.0, 1.0): 'NAM',
#  (369.0, 1.0): 'NAM NAM',
#  (369.0, 2.0): 'NAM NAM',
#  (369.0, 3.0): 'PRO:REL',
#  (370.0, 1.0): 'NAM NAM',
#  (370.0, 2.0): 'PRO:REL',
#  (370.0, 3.0): 'PRO:PER',
#  (371.0, 1.0): 'NAM',
#  (372.0, 1.0): 'NAM',
#  (372.0, 2.0): 'PRO:REL',
#  (373.0, 1.0): 'NAM',
#  (374.0, 1.0): 'NAM',
#  (374.0, 2.0): 'PRO:REL',
#  (375.0, 1.0): 'NAM',
#  (376.0, 1.0): 'PRO:PER',
#  (376.0, 2.0): 'NAM NAM',
#  (376.0, 3.0): 'ADJ',
#  (377.0, 1.0): 'NAM',
#  (378.0, 1.0): 'NAM NAM',
#  (379.0, 1.0): 'NAM',
#  (380.0, 1.0): 'NAM',
#  (380.0, 2.0): 'PRO:REL',
#  (380.0, 3.0): 'PRO:REL',
#  (381.0, 1.0): 'NAM',
#  (382.0, 1.0): 'NAM NAM',
#  (383.0, 1.0): 'DET:POS ADJ NAM',
#  (384.0, 1.0): 'PRO:PER',
#  (384.0, 2.0): 'PRO:PER',
#  (384.0, 3.0): 'PRO:PER',
#  (385.0, 1.0): 'PRO:PER',
#  (385.0, 2.0): 'PRO:DEM NOM PRO:PER',
#  (385.0, 3.0): 'PRO:PER PRO:PER',
#  (385.0, 4.0): 'PRO:PER PRO:PER',
#  (385.0, 5.0): 'PRO:PER PRO:PER',
#  (385.0, 6.0): 'PRO:PER',
#  (386.0, 1.0): 'NAM',
#  (387.0, 1.0): 'DET:ART NOM ADJ',
#  (387.0, 2.0): 'PRO:PER',
#  (388.0, 1.0): 'PRO:PER',
#  (388.0, 2.0): 'PRO:PER',
#  (388.0, 3.0): 'PRO:PER',
#  (389.0, 1.0): 'NAM',
#  (390.0, 1.0): 'NAM',
#  (391.0, 1.0): 'NAM NAM',
#  (391.0, 2.0): 'PRO:PER',
#  (391.0, 3.0): 'PRO:PER',
#  (392.0, 1.0): 'DET:ART NOM',
#  (393.0, 1.0): 'NAM',
#  (393.0, 2.0): 'PRO:PER',
#  (393.0, 3.0): 'PRO:PER',
#  (394.0, 1.0): 'NAM',
#  (395.0, 1.0): 'NAM',
#  (396.0, 1.0): 'NAM',
#  (397.0, 1.0): 'NAM',
#  (398.0, 1.0): 'DET:ART NOM PRP NAM',
#  (398.0, 2.0): 'PRO:PER',
#  (398.0, 3.0): 'PRO:PER',
#  (398.0, 4.0): 'PRO:PER',
#  (399.0, 1.0): 'NAM',
#  (399.0, 2.0): 'PRO:PER',
#  (400.0, 1.0): 'NAM',
#  (400.0, 2.0): 'NAM',
#  (401.0, 1.0): 'NAM NAM',
#  (402.0, 1.0): 'PRO:PER',
#  (402.0, 2.0): 'NAM NAM',
#  (402.0, 3.0): 'PRO:PER',
#  (402.0, 4.0): 'PRO:PER',
#  (402.0, 5.0): 'PRO:PER',
#  (402.0, 6.0): 'PRO:PER',
#  (402.0, 7.0): 'PRO:PER',
#  (402.0, 8.0): 'PRO:PER',
#  (402.0, 9.0): 'NAM NAM',
#  (402.0, 10.0): 'DET:POS',
#  (403.0, 1.0): 'DET:ART NAM',
#  (404.0, 1.0): 'NAM NAM',
#  (405.0, 1.0): 'NAM',
#  (406.0, 1.0): 'NAM',
#  (407.0, 1.0): 'NAM',
#  (407.0, 2.0): 'PRO:REL',
#  (407.0, 3.0): 'PRO:REL',
#  (407.0, 4.0): 'DET:POS',
#  (408.0, 1.0): 'NAM',
#  (408.0, 2.0): 'PRO:PER',
#  (408.0, 3.0): 'DET:ART NOM NUM',
#  (409.0, 1.0): 'PRO:PER',
#  (410.0, 1.0): 'NAM NAM',
#  (411.0, 1.0): 'PRO:PER',
#  (412.0, 1.0): 'DET:ART NOM ADJ',
#  (412.0, 2.0): 'PRO:PER',
#  (413.0, 1.0): 'PRP NAM',
#  (413.0, 2.0): 'PRO:REL',
#  (414.0, 1.0): 'NAM',
#  (414.0, 2.0): 'PRO:REL',
#  (414.0, 3.0): 'PRO:REL',
#  (415.0, 1.0): 'NAM',
#  (416.0, 1.0): 'NAM',
#  (417.0, 1.0): 'NAM PRP NAM',
#  (417.0, 2.0): 'PRO:REL',
#  (418.0, 1.0): 'NAM',
#  (419.0, 1.0): 'NAM',
#  (421.0, 1.0): 'NAM',
#  (422.0, 1.0): 'NAM',
#  (423.0, 1.0): 'NAM',
#  (424.0, 1.0): 'NAM',
#  (425.0, 1.0): 'DET:ART NOM PRP NAM',
#  (426.0, 1.0): 'NAM',
#  (427.0, 1.0): 'PRP:det NOM',
#  (427.0, 2.0): 'PRO:PER',
#  (428.0, 1.0): 'NAM',
#  (429.0, 1.0): 'NAM NAM',
#  (429.0, 2.0): 'PRO:PER',
#  (429.0, 3.0): 'PRO:PER',
#  (430.0, 1.0): 'NAM NAM',
#  (431.0, 1.0): 'NAM NAM',
#  (432.0, 1.0): 'NAM',
#  (432.0, 2.0): 'NAM NAM',
#  (433.0, 1.0): 'NAM NAM',
#  (433.0, 2.0): 'PRO:REL',
#  (433.0, 3.0): 'DET:POS',
#  (434.0, 1.0): 'DET:ART NOM PRP NAM',
#  (435.0, 1.0): 'NAM NAM',
#  (436.0, 1.0): 'DET:ART NAM',
#  (436.0, 2.0): 'PRO:PER',
#  (437.0, 1.0): 'DET:ART NAM',
#  (437.0, 2.0): 'PRP:det NOM',
#  (438.0, 1.0): 'NAM',
#  (438.0, 2.0): 'PRO:PER',
#  (438.0, 3.0): 'PRO:PER',
#  (439.0, 1.0): 'NAM',
#  (440.0, 1.0): 'NAM',
#  (441.0, 1.0): 'NAM',
#  (441.0, 2.0): 'PRO:PER',
#  (442.0, 1.0): 'NAM',
#  (443.0, 1.0): 'NAM',
#  (444.0, 1.0): 'NAM NAM',
#  (445.0, 1.0): 'DET:ART NAM',
#  (446.0, 1.0): 'NAM',
#  (447.0, 1.0): 'NAM',
#  (447.0, 2.0): 'PRO:REL',
#  (447.0, 3.0): 'PRO:PER',
#  (448.0, 1.0): 'NAM',
#  (449.0, 1.0): 'PRP:det NAM',
#  (449.0, 2.0): 'PRO:REL',
#  (450.0, 1.0): 'NAM NAM',
#  (451.0, 1.0): 'NAM',
#  (452.0, 1.0): 'NAM',
#  (453.0, 1.0): 'NAM',
#  (454.0, 1.0): 'DET:ART NOM',
#  (454.0, 2.0): 'PRO:REL',
#  (454.0, 3.0): 'PRO:REL',
#  (455.0, 1.0): 'PRO:PER',
#  (455.0, 2.0): 'PRO:PER',
#  (455.0, 3.0): 'PRO:PER',
#  (456.0, 1.0): 'NAM',
#  (456.0, 2.0): 'PRO:PER',
#  (457.0, 1.0): 'NAM',
#  (457.0, 2.0): 'PRO:PER',
#  (457.0, 3.0): 'PRO:REL',
#  (458.0, 1.0): 'PRO:PER',
#  (458.0, 2.0): 'DET:ART NOM',
#  (458.0, 3.0): 'PRO:PER',
#  (459.0, 1.0): 'NAM NAM',
#  (459.0, 2.0): 'PRO:REL',
#  (460.0, 1.0): 'DET:ART NAM',
#  (460.0, 2.0): 'PRO:PER',
#  (461.0, 1.0): 'DET:ART NOM',
#  (461.0, 2.0): 'PRO:PER',
#  (461.0, 3.0): 'PRO:PER',
#  (462.0, 2.0): 'NAM',
#  (462.0, 3.0): 'PRO:PER',
#  (462.0, 4.0): 'PRO:PER',
#  (463.0, 1.0): 'PRO:PER',
#  (463.0, 2.0): 'NAM NAM',
#  (464.0, 1.0): 'NAM',
#  (465.0, 1.0): 'NAM',
#  (466.0, 1.0): 'NAM',
#  (466.0, 2.0): 'PRO:REL',
#  (466.0, 3.0): 'PRO:PER',
#  (466.0, 4.0): 'NAM NAM',
#  (466.0, 5.0): 'PRO:PER',
#  (466.0, 6.0): 'PRO:PER',
#  (467.0, 1.0): 'NAM NAM',
#  (467.0, 2.0): 'PRO:REL',
#  (467.0, 3.0): 'DET:POS',
#  (467.0, 4.0): 'PRO:REL',
#  (467.0, 5.0): 'PRO:PER',
#  (467.0, 6.0): 'DET:ART NOM ADJ',
#  (467.0, 7.0): 'PRO:REL',
#  (468.0, 1.0): 'PRP:det NOM ADJ',
#  (469.0, 1.0): 'DET:ART NUM NOM',
#  (469.0, 2.0): 'PRO:PER',
#  (470.0, 1.0): 'NAM',
#  (471.0, 1.0): 'NAM',
#  (472.0, 1.0): 'PRO:PER',
#  (472.0, 2.0): 'PRO:PER',
#  (473.0, 1.0): 'NAM',
#  (474.0, 1.0): 'NAM NAM',
#  (474.0, 2.0): 'PRO:REL',
#  (474.0, 3.0): 'PRO:REL',
#  (475.0, 1.0): 'NAM',
#  (476.0, 1.0): 'NAM',
#  (477.0, 1.0): 'NAM',
#  (478.0, 1.0): 'NAM',
#  (479.0, 1.0): 'NAM',
#  (479.0, 2.0): 'PRO:REL',
#  (479.0, 3.0): 'PRO:PER',
#  (479.0, 4.0): 'PRO:PER',
#  (479.0, 5.0): 'PRO:PER',
#  (480.0, 1.0): 'DET:ART NOM',
#  (481.0, 1.0): 'DET:ART NOM PRP NAM',
#  (481.0, 2.0): 'PRO:PER',
#  (481.0, 3.0): 'PRO:PER',
#  (481.0, 4.0): 'PRO:PER',
#  (481.0, 5.0): 'PRO:PER',
#  (481.0, 6.0): 'PRO:PER',
#  (482.0, 1.0): 'NOM PRP NAM',
#  (482.0, 2.0): 'DET:POS',
#  (482.0, 3.0): 'PRP:det NOM',
#  (483.0, 1.0): 'NAM NAM',
#  (484.0, 1.0): 'NAM NAM',
#  (485.0, 1.0): 'NAM',
#  (486.0, 1.0): 'NAM',
#  (487.0, 1.0): 'NAM',
#  (488.0, 1.0): 'NAM',
#  (490.0, 1.0): 'PRO:PER',
#  (491.0, 1.0): 'PRO:PER',
#  (491.0, 2.0): 'PRO:PER',
#  (491.0, 3.0): 'PRO:PER',
#  (492.0, 1.0): 'PRP:det NOM',
#  (493.0, 1.0): 'DET:ART NOM PRP:det NOM',
#  (494.0, 1.0): 'NAM',
#  (495.0, 1.0): 'NAM',
#  (496.0, 1.0): 'NAM',
#  (497.0, 1.0): 'NAM',
#  (498.0, 1.0): 'NAM',
#  (498.0, 2.0): 'PRO:REL',
#  (499.0, 1.0): 'DET:ART NOM ADJ',
#  (499.0, 2.0): 'PRO:REL',
#  (500.0, 1.0): 'NAM',
#  (501.0, 1.0): 'NAM',
#  (502.0, 1.0): 'NAM PRP NAM',
#  (502.0, 2.0): 'PRP NAM',
#  (503.0, 1.0): 'NAM',
#  (504.0, 1.0): 'NAM',
#  (505.0, 1.0): 'DET:ART NOM PRP NAM',
#  (505.0, 2.0): 'PRO:PER',
#  (505.0, 3.0): 'PRO:PER',
#  (505.0, 4.0): 'PRO:PER',
#  (505.0, 5.0): 'PRO:PER',
#  (506.0, 1.0): 'DET:ART NOM ADJ',
#  (507.0, 1.0): 'NAM',
#  (507.0, 2.0): 'PRO:REL',
#  (507.0, 3.0): 'PRO:PER',
#  (507.0, 4.0): 'PRO:PER',
#  (509.0, 1.0): 'NAM',
#  (510.0, 1.0): 'NAM',
#  (510.0, 2.0): 'PRO:PER',
#  (510.0, 3.0): 'PRO:PER',
#  (510.0, 4.0): 'PRO:PER',
#  (512.0, 1.0): 'PRO:PER',
#  (512.0, 2.0): 'NAM NAM',
#  (512.0, 3.0): 'PRO:PER',
#  (512.0, 4.0): 'DET:POS',
#  (513.0, 1.0): 'NOM',
#  (513.0, 2.0): 'PRO:REL',
#  (514.0, 1.0): 'NAM',
#  (515.0, 1.0): 'NAM',
#  (516.0, 1.0): 'NAM',
#  (517.0, 1.0): 'NAM',
#  (519.0, 1.0): 'NAM',
#  (519.0, 2.0): 'PRO:PER',
#  (519.0, 3.0): 'PRO:PER',
#  (520.0, 1.0): 'PRO:PER PRO:PER',
#  (520.0, 2.0): 'PRO:PER',
#  (520.0, 3.0): 'PRO:PER',
#  (521.0, 1.0): 'PRO:PER',
#  (521.0, 2.0): 'PRO:PER',
#  (521.0, 3.0): 'DET:POS',
#  (521.0, 4.0): 'PRO:PER PRO:PER',
#  (522.0, 1.0): 'NAM NAM',
#  (523.0, 2.0): 'NAM NAM',
#  (524.0, 1.0): 'DET:ART NOM PRP NAM',
#  (524.0, 2.0): 'PRO:PER',
#  (525.0, 1.0): 'DET:ART NUM PRP NAM',
#  (525.0, 2.0): 'DET:ART NOM PRP NAM',
#  (526.0, 1.0): 'DET:ART NAM',
#  (527.0, 1.0): 'NAM NAM',
#  (528.0, 1.0): 'NAM NAM',
#  (528.0, 2.0): 'PRO:PER',
#  (528.0, 3.0): 'PRO:PER',
#  (529.0, 1.0): 'PRO:PER DET:ART NAM',
#  (529.0, 3.0): 'DET:POS',
#  (530.0, 1.0): 'DET:ART NAM',
#  (530.0, 2.0): 'PRO:PER',
#  (530.0, 4.0): 'PRO:PER',
#  (530.0, 5.0): 'PRO:PER',
#  (530.0, 6.0): 'PRO:PER',
#  (530.0, 7.0): 'PRO:PER',
#  (530.0, 8.0): 'PRO:PER',
#  (531.0, 1.0): 'NAM NAM',
#  (532.0, 1.0): 'DET:ART NUM ADJ NAM',
#  (533.0, 1.0): 'DET:ART NAM',
#  (534.0, 1.0): 'NAM NAM',
#  (535.0, 1.0): 'NAM NAM',
#  (536.0, 1.0): 'PRP:det NOM PRP NAM',
#  (537.0, 1.0): 'DET:ART NOM PRP NAM',
#  (537.0, 2.0): 'PRO:REL',
#  (537.0, 3.0): 'PRO:REL',
#  (537.0, 4.0): 'PRO:PER',
#  (537.0, 5.0): 'PRO:PER',
#  (537.0, 6.0): 'PRO:DEM NOM',
#  (537.0, 7.0): 'PRO:PER',
#  (537.0, 8.0): 'PRO:PER',
#  (538.0, 1.0): 'DET:ART NOM ADJ',
#  (540.0, 1.0): 'DET:ART NAM',
#  (541.0, 1.0): 'NAM',
#  (542.0, 1.0): 'NAM',
#  (543.0, 1.0): 'DET:ART NAM',
#  (543.0, 2.0): 'PRO:PER',
#  (544.0, 1.0): 'DET:ART NOM PRP NAM',
#  (545.0, 1.0): 'NAM',
#  (546.0, 1.0): 'NAM',
#  (547.0, 1.0): 'NAM',
#  (548.0, 1.0): 'NAM NAM',
#  (548.0, 2.0): 'PRO:REL',
#  (548.0, 3.0): 'PRO:PER',
#  (549.0, 1.0): 'NAM NAM',
#  (550.0, 1.0): 'NAM',
#  (550.0, 2.0): 'PRO:PER',
#  (550.0, 3.0): 'NAM NAM',
#  (550.0, 4.0): 'PRO:PER',
#  (552.0, 1.0): 'NAM',
#  (552.0, 2.0): 'PRO:REL',
#  (553.0, 1.0): 'PRP:det NOM',
#  (554.0, 1.0): 'NAM',
#  (554.0, 2.0): 'PRO:REL',
#  (555.0, 1.0): 'NAM',
#  (556.0, 1.0): 'NAM',
#  (557.0, 1.0): 'NAM',
#  (557.0, 2.0): 'PRO:REL',
#  (557.0, 3.0): 'PRO:PER',
#  (558.0, 1.0): 'NAM',
#  (559.0, 1.0): 'NAM',
#  (560.0, 1.0): 'NAM',
#  (562.0, 1.0): 'NAM',
#  (562.0, 2.0): 'PRO:REL',
#  (563.0, 1.0): 'NAM NAM',
#  (564.0, 1.0): 'NAM',
#  (565.0, 1.0): 'PRO:PER',
#  (566.0, 1.0): 'DET:POS ADJ NAM',
#  (567.0, 1.0): 'NOM NAM',
#  (568.0, 1.0): 'NAM NAM',
#  (568.0, 2.0): 'PRO:PER',
#  (568.0, 3.0): 'NAM',
#  (569.0, 1.0): 'PRO:PER',
#  (571.0, 1.0): 'NAM NAM',
#  (573.0, 1.0): 'NAM',
#  (574.0, 1.0): 'NAM',
#  (574.0, 3.0): 'DET:POS',
#  (575.0, 1.0): 'NOM',
#  (576.0, 1.0): 'NAM',
#  (577.0, 1.0): 'NOM NAM',
#  (578.0, 1.0): 'NAM',
#  (579.0, 1.0): 'NAM',
#  (580.0, 1.0): 'NAM',
#  (581.0, 1.0): 'NAM',
#  (581.0, 2.0): 'NAM',
#  (585.0, 1.0): 'DET:POS NOM',
#  (585.0, 2.0): 'PRO:PER',
#  (586.0, 1.0): 'DET:ART NOM',
#  (586.0, 2.0): 'PRO:PER',
#  (586.0, 3.0): 'PRO:PER',
#  (586.0, 4.0): 'PRO:PER',
#  (587.0, 1.0): 'DET:ART NAM',
#  (587.0, 2.0): 'PRO:REL',
#  (588.0, 1.0): 'DET:ART NOM PRP DET:ART NAM',
#  (589.0, 1.0): 'NAM',
#  (590.0, 1.0): 'NAM',
#  (590.0, 2.0): 'PRO:REL',
#  (590.0, 3.0): 'PRO:REL',
#  (590.0, 4.0): 'PRO:REL',
#  (591.0, 1.0): 'NAM',
#  (592.0, 1.0): 'NAM',
#  (592.0, 2.0): 'PRO:PER',
#  (592.0, 3.0): 'NOM PRP:det NAM ADJ',
#  (593.0, 1.0): 'NAM',
#  (593.0, 2.0): 'PRO:REL',
#  (594.0, 1.0): 'NAM',
#  (594.0, 2.0): 'PRO:REL',
#  (594.0, 3.0): 'PRO:REL',
#  (595.0, 1.0): 'DET:ART NOM',
#  (595.0, 2.0): 'PRO:REL',
#  (595.0, 3.0): 'PRO:PER DET:ART NOM',
#  (595.0, 4.0): 'DET:ART NOM',
#  (596.0, 1.0): 'NOM NAM',
#  (597.0, 1.0): 'PRO:PER',
#  (597.0, 2.0): 'NAM NAM',
#  (597.0, 3.0): 'PRO:PER',
#  (597.0, 4.0): 'PRO:PER',
#  (597.0, 5.0): 'PRO:PER',
#  (597.0, 6.0): 'PRO:PER',
#  (598.0, 1.0): 'NAM',
#  (599.0, 1.0): 'NAM',
#  (600.0, 1.0): 'DET:ART NAM',
#  (600.0, 2.0): 'PRO:REL',
#  (601.0, 1.0): 'DET:ART NAM',
#  (602.0, 1.0): 'NAM',
#  (605.0, 1.0): 'NAM NAM',
#  (605.0, 2.0): 'PRO:REL',
#  (606.0, 1.0): 'DET:ART NOM PRP NAM',
#  (606.0, 2.0): 'PRO:REL',
#  (606.0, 3.0): 'DET:ART NOM ADJ',
#  (607.0, 1.0): 'DET:ART NOM',
#  (608.0, 1.0): 'DET:ART NOM PRP NAM',
#  (609.0, 1.0): 'NOM NAM',
#  (609.0, 2.0): 'DET:ART NOM',
#  (610.0, 1.0): 'DET:ART NAM',
#  (610.0, 2.0): 'PRO:REL',
#  ...}

# %% [raw]
# df.loc[df.chaineIndex.notnull(),"indexType"]=df.loc[df.chaineIndex.notnull()].apply(getType,axis=1)
# df.to_excel(rep+nFile.replace(".xlsx","-Type.xlsx"),index=0)

# %%
dfType=pd.read_excel(rep+nFile.replace(".xlsx","-Type.xlsx"),index_col=None)

# %%
dfType.loc[(dfType.chaineDep.notnull())].groupby(["numChaine","chaineIndex"])[["indexType"]].first().groupby("numChaine").agg(" ".join).reset_index().groupby("indexType").count().sort_values("numChaine",ascending=False).head(50)
# Out:
#                                                     numChaine
# indexType
# NAM                                                       583
# PRO:PER                                                   126
# GN                                                        108
# NAM PRO:REL                                                46
# NAM PRO:PER                                                29
# PRO:PER PRO:PER                                            22
# PRO:PER PRO:PER PRO:PER                                    21
# NAM PRO:PER PRO:PER                                        16
# NAM NAM                                                    14
# GN PRO:REL                                                 13
# GNUM                                                       13
# GN PRO:PER                                                 12
# NAM PRO:REL PRO:REL                                        12
# NAM PRO:REL PRO:PER                                        11
# NAM POSS                                                   10
# PRO:PER NAM                                                 9
# NAM PRO:PER NAM                                             8
# NAM PRO:REL POSS                                            6
# GN PRO:PER PRO:PER                                          6
# NAM NAM PRO:REL                                             5
# NAM GN                                                      4
# GN PRO:PER PRO:PER PRO:PER                                  4
# NAM PRO:PER POSS                                            4
# GN GN                                                       4
# NAM PRO:PER PRO:PER PRO:PER PRO:PER                         4
# NAM PRO:PER NAM PRO:PER                                     3
# PRO:PER GN PRO:PER                                          3
# NAM NAM PRO:PER                                             3
# NAM POSS PRO:PER                                            3
# NAM PRO:REL PRO:PER PRO:PER                                 3
# GN PRO:PER PRO:PER PRO:PER PRO:PER PRO:PER                  3
# PRO:PER PRO:PER PRO:PER PRO:PER                             3
# NAM PRO:REL NAM                                             3
# GN PRO:REL PRO:REL                                          2
# PRO:PER POSS                                                2
# GN NAM GN                                                   2
# PRO:PER PRO:PER PRO:PER PRO:PER PRO:PER PRO:PER...          2
# NAM PRO:REL PRO:PER PRO:PER POSS                            2
# NAM PRO:PER GN                                              2
# NAM NAM NAM                                                 2
# NAM PRO:REL PRO:PER PRO:PER PRO:PER                         2
# PRO:PER NAM PRO:PER POSS                                    2
# GN PRO:REL PRO:PER                                          2
# NAM PRO:PER PRO:PER PRO:PER                                 2
# NAM PRO:REL PRO:REL PRO:REL                                 1
# POSS                                                        1
# NAM PRO:REL PRO:REL PRO:PER PRO:PER PRO:REL PRO...          1
# NAM PRO:REL PRO:PER PRO:PER POSS PRO:PER                    1
# NAM PRO:REL PRO:PER PRO:REL                                 1
# NAM PRO:REL PRO:REL NAM PRO:REL                             1

# %% [markdown]
# # Nombre de chaines par élément initial

# %%
dfAnchors=df.loc[(df.chaineDep==0)].groupby("numChaine")[["cat","transcription"]].agg(" ".join)
dfAnchors.loc[dfAnchors.cat=="NOM","transcription"].unique()

# %%
dfAnchors.loc[(~dfAnchors.cat.str.contains("NAM"))&(~dfAnchors.cat.str.contains("PRO"))&(~dfAnchors.cat.str.contains("NOM"))&(~dfAnchors.cat.str.contains("POS"))]

# %%
df.loc[(df.chaineDep==0)].groupby(["referent","numChaine"])[["cat","transcription"]].agg(" ".join).to_excel(rep+"Anchors-%s.xlsx"%match)

# %%
dfAnchors.loc[dfAnchors.cat.str.startswith("NAM")].groupby("cat").count()#.sum()

# %%
dfAnchors.loc[dfAnchors.cat=="NAM NAM DET:ART NOM DET:ART NOM PRP PRO:DEM NOM PRP NAM"]

# %%
print(dfGroupes.groupby("cat").first().to_string())

# %%
dfAnchors.loc[dfAnchors.cat.str.startswith("PRO")].groupby("cat").count()#.sum()

# %%
set(dfAnchors.groupby("cat").count().sort_values("transcription",ascending=False).to_dict()["transcription"].keys())

# %%
df.loc[(df.cat=="NAM")&(df.chaineDep==0)].groupby("numChaine").first()

# %% [markdown]
# ## Extraction des chaines par numéro

# %%
chaineIndex={}
numChaines=df.numChaine.dropna().astype(int).unique().tolist()
for numChaine in numChaines:
    chaineIndex[numChaine]=df.loc[df.numChaine==numChaine].index.tolist()
# print(chaineIndex)
sentIndex=df.loc[df.cat=="SENT"].index.tolist()
# print(sentIndex)

# %%
def findSent(cMin,cMax):
    if cMin==cMax:
        lSentIndex=sorted(sentIndex+[cMin])
    else:
        lSentIndex=sorted(sentIndex+[cMin,cMax])
    if lSentIndex.index(cMin)>0:
        sMin=lSentIndex[lSentIndex.index(cMin)-1]
    else:
        sMin=-1
    sMax=lSentIndex[lSentIndex.index(cMax)+1]
    return sMin+1,sMax

# %%
lMin=5
fExtraction=rep+"Extract-%d+.csv"%lMin
for numChaine,indexChaine in chaineIndex.items():
    lRef=df.loc[df.numChaine==numChaine].referent.unique().tolist()
    lChaine=df.loc[df.numChaine==numChaine].chaineIndex.max()
    try:
        refChaine=", ".join(lRef)
    except:
        print(numChaine,lRef)
    cMin=min(indexChaine)
    cMax=max(indexChaine)
    sMin,sMax=findSent(cMin,cMax)
    if len(lRef)==1 and lChaine>=lMin:
        with open(fExtraction,"a") as outFile:
            outFile.write("%d\t\t\t\t%s\t%d\n"%(lChaine,refChaine,numChaine))
        df.iloc[sMin:sMax].to_csv(fExtraction,mode="a",sep="\t")
        with open(fExtraction,"a") as outFile:
            outFile.write("\n")

# %% [markdown]
# ## Extraction des chaines longues
# - longueur >= 4

# %%
index4=df.loc[df.chaineIndex==4].to_dict(orient="index")
for k,v in index4.items():
    print(k,v["referent"],v["numChaine"])
    display(df.loc[df.numChaine==v["numChaine"]])

# %% [raw]
# chaines={}
# lChaines={}
# for num in range(maxNumChaine):
#     n=num+1
#     dfChaine=df.loc[df.numChaine==n]
#     try:
#         chaines[n]={"ref":dfChaine.Referent.values[0],"chaine":{}}
#         indexMax=int(dfChaine.chaineIndex.max())
#         if indexMax not in lChaines:
#             lChaines[indexMax]=0
#         lChaines[indexMax]+=1
#         for ind in range(indexMax):
#             i=ind+1
#             dfIndex=dfChaine.loc[dfChaine.chaineIndex==i]
#             chaines[n]["chaine"][i]=dfIndex[["Cat","Transcription"]].to_dict()
#     except:
#         print("pb",n,end=", ")
#         # display(dfChaine)
# print()
# print(lChaines)

# %% [markdown]
# #### Calcul de la longueur maximale des chaines

# %%
maxLChaines=max(lChaines.keys())
for l in range(maxLChaines):
    if l+1 not in lChaines:
        lChaines[l+1]=0
colors = sns.color_palette('pastel',n_colors=maxLChaines)

# %% [markdown]
# #### Nombre de chaines par longueur

# %%
pieCut=3
dfDistLong=pd.DataFrame.from_dict(lChaines,orient="index").sort_index()
dfDistLong.name="Longueur de chaine"
dfDistLong.plot.bar(y=0,color=colors,ylabel="Nombre",xlabel="Longeur",title="Distribution des longueurs de chaîne",legend=False)
plt.savefig("JE-BP-LongChaines-%s.pdf"%match)
dfTemp=dfDistLong[:pieCut].copy()
autres=dfDistLong[pieCut:].sum()
autres.index=["%d+"%(pieCut+1)]
dfTemp=pd.concat([dfTemp,autres])
ax=dfTemp.plot.pie(y=0,colors=colors, autopct='%.0f%%',title="Distribution des longueurs de chaîne",figsize=(7,7),legend=False)
ax.set_ylabel(None)
dfTemp.to_excel("DistLongChaine-%s.xlsx"%match)
plt.savefig("JE-PC-LongChaines-%s.pdf"%match)

# %% [markdown]
# #### Nombre de chaines par longueur par référent

# %%
refChaines={}
lRefChaines={}#
# print(lRefChaines)
for k,v in chaines.items():
    ref=chaines[k]["ref"]
    chaine=chaines[k]["chaine"]
    if ref not in refChaines:
        refChaines[ref]=[]
        lRefChaines[ref]={i:0 for i in range(1,maxLChaines+1)}
    refChaines[ref].append(chaines[k]["chaine"])
    longueur=max(chaines[k]["chaine"].keys())
    if longueur not in lRefChaines[ref]:
        lRefChaines[ref][longueur]=0
    lRefChaines[ref][longueur]+=1
dfRefChaines=pd.DataFrame.from_dict(lRefChaines).sort_index().T

dfRefChaines["sum"]=dfRefChaines.iloc[:,0:maxLChaines].sum(axis=1)
dfRefChaines=dfRefChaines.sort_values(by='sum',ascending=False)
dfRefChaines=dfRefChaines.drop(columns="sum")
display(dfRefChaines.head())

# %%
dfRefChaines.plot(kind="bar",stacked=True,figsize=(50,5))
plt.savefig("JE-SB-DistChaines-%s.pdf"%match)

# %% [markdown]
# #### Calcul du nombre de reprises par catégorie
# - chaineIndex renseignée
# - chaineDep différent de root (≠0)

# %%
df.head()

# %%
print(match)
df[(df.chaineIndex.notnull())&(df.chaineDep>0)&(df.Cat=="PRO:PER")].groupby("Transcription").count()[["Cat"]]

# %%
print(match)
catTable=df[(df.chaineIndex.notnull())&(df.chaineDep>0)].groupby("Cat").count()[["Lemme"]].loc["NAM PRO:REL PRO:PER NOM DET:POS PRO:DEM PRO:IND".split(" ")]
display(catTable)
print(catTable.sum())

# %% [markdown]
# #### Détail des reprises

# %%
dfGroupReprises=df[(df.chaineIndex.notnull())&(df.chaineDep>0)].groupby(["numChaine","chaineIndex"])[["Cat","Transcription"]].sum()
dfGroupReprises

# %%
print(match,len(dfGroupReprises),nbMots,"%2.1f%%"%(len(dfGroupReprises)/nbMots*100))

# %% [markdown]
# #### Détail des références

# %%
dfGroupeReferents=df[(df.chaineIndex.notnull())].groupby(["numChaine","chaineIndex"])[["Cat","Transcription"]].agg(" ".join)
dfGroupeReferents

# %%
print(match,len(dfGroupeReferents),nbMots,"%2.1f%%"%(len(dfGroupeReferents)/nbMots*100))

# %%
print(dfGroupeReferents.to_string())

# %% [markdown]
# # Rapprochements entre chaines et autres données

# %%
import nltk,difflib,re,unidecode

# %% [markdown]
# ### Sélection du tableau des tours

# %%
def getCommType(row):
    if row["PxP"]==1:
        return "Play by play"
    elif row["Color"]==1:
        return "Color commentary"
    else:
        return "Autre"

# %%
if match=="FR-AR":
    dfGen=pd.read_csv(rep+"CorrespondancesAction-PlayVsColourVsSupportaire.csv",sep=";")
    
    dfGen.columns="lNum tDeb tFin penalite type event action actComm comm rem1 rem2 err1 err2 commType commTypeCorr".split(" ")
    dTours=dfGen.loc[dfGen.comm.notnull()][["comm","commType","tDeb","tFin"]].to_dict(orient="index")
    lTours=[v for k,v in dTours.items()]
    nTours={}
    for nT,tour in enumerate(lTours):
        if not tour["comm"].startswith("PROB"):
            refComm,comm=tour["comm"].split(" ",1)
            nTours[nT]=(nltk.wordpunct_tokenize(comm), 
                        refComm, tour["commType"], tour["tDeb"], tour["tFin"])

elif match=="FR-NZ" and "fr-GB" in nFile:
    dfGen=pd.read_csv(rep+"Fr-NZ_Tours.csv",sep="\t")
    dfGen["nTour speaker startTime endTime tour nActions PxP Color Supporter".split(" ")]
    dfGen["commType"]=dfGen.apply(getCommType,axis=1)
    dfGen.rename(columns={"tour":"comm","startTime":"tDeb","endTime":"tFin"},errors="raise",inplace=True)
    dTours=dfGen.loc[dfGen.comm.notnull()][["comm","commType","tDeb","tFin","nTour","speaker"]].to_dict(orient="index")
    lTours=[v for k,v in dTours.items()]
    nTours={}
    for nT,tour in enumerate(lTours):
        refComm=str(tour["nTour"])+"-"+tour["speaker"]
        comm=tour["comm"]
        nTours[nT]=(nltk.wordpunct_tokenize(comm), 
                    refComm, tour["commType"], tour["tDeb"], tour["tFin"])
nTours

# %% [raw]
# lTours=[v for k,v in dTours.items()]
# # lTours
#
# nTours={}
# for nT,tour in enumerate(lTours):
#     if match=="FR-AR"
#     if not tour["comm"].startswith("PROB"):
#         refComm,comm=tour["comm"].split(" ",1)
#         nTours[nT]=(nltk.wordpunct_tokenize(comm),
#                     refComm, tour["commType"], tour["tDeb"], tour["tFin"])
# nTours

# %% [markdown]
# ### Essais

# %% [raw]
# nSkips=[312,330,1000,1106,1112,1124,18,96,108,128,172,184,193,
#         200,247,256,257,269,445,480,498,504,515,533,547,550,
#         636,668,717,747,754,775,788,799,806,832,838,979,
#         1036,1049,1050,1051,1064,1065,1067,1068,1069,1071,
#         1101,1114,1119,1173,1175,1222,1227,1228,1233,1235,1246,1261,1262,
#         1310,1332,1354,1413,1496,1528,1550,1563,1570,1571,1592,1595,
#         1658,1681,1694,1700,1715,1721,1726,1728,1758,1764,1823,1943,2007,2031,2082,2123,
#         2332,
#         192,423,645,725,794,1023,1307,1702,1760,1762,1781,1795,1796,1824,1838,1876,
#         1915,1928,1933,1934,1936,1937,1948,1950,1951,1958,1974,1996,
#         2009,2013,2025,2027,2036,2079,2114,2121,2128,2132,2133,2136,2138,2140,2177,
#         2180,2207,2225,2235,2288,2311,2318,2320,2357,2367,
#         2400,2444,2449,2450,2462,2465,2483,2502,2503,2547,2556,2596,2628,2654]

# %% [markdown]
# # Réassemblage des phrases

# %%
stopSigns=list(".?!")
skipSigns=list("',;-*:()[]/$")

# %% [markdown]
# ## Découpage syntaxique

# %%
transTexte=df.Transcription.to_dict()
lTexte=len(transTexte)
transPhrases={}
nPhrase=0
lPhraseIx=[]
lPhraseMots=[]
for n in range(lTexte):
    lPhraseIx.append(n)
    lPhraseMots.append(str(transTexte[n]))
    df.loc[n,"nPhrase"]=nPhrase
    if str(transTexte[n]) in stopSigns:
        transPhrases[nPhrase]=(lPhraseMots,lPhraseIx)
        nPhrase+=1
        lPhraseIx=[]
        lPhraseMots=[]

# %%
transPhrases[0][0]

# %%
# df.head()
transPhrases
contPhrases=[]
for k,v in transPhrases.items():
    if isinstance(v,tuple):
        contPhrases.extend(v[0])
# contPhrases

# %% [markdown]
# ## Mise en table des tours par mot

# %%
dfTours=pd.DataFrame(nTours).T.set_index([1,2,3,4]).apply(lambda x: x.explode()).reset_index()[[0,1,2,3,4]]
dfTours.columns="mot tour type tDeb tFin".split(" ")
dfTours

# %% [markdown]
# ## Assemblage

# %%
def alignAB(limit,pStart=0):
    bN=0
    for aN in range(limit):
        a=contPhrases[aN].strip("'")
        if a not in stopSigns+skipSigns+["..."] and aN not in skips:
            aChunks=[unidecode.unidecode(chunk).lower() for chunk in re.split("[-']",a) if chunk!=""]
            for aChunk in aChunks:
                skipB=0
                while unidecode.unidecode(dfTours.iloc[bN].mot).lower()!=aChunk:
                    bN+=1
                    skipB+=1
                    if skipB>100:
                        print(aN,a)
                        return
                df.loc[aN,"tour"]=dfTours.iloc[bN].tour
                df.loc[aN,"type"]=dfTours.iloc[bN].type
                df.loc[aN,"tDeb"]=dfTours.iloc[bN].tDeb
                df.loc[aN,"tFin"]=dfTours.iloc[bN].tFin
                b=dfTours.iloc[bN].mot
                if aN>=pStart:
                    print (aN,bN,a,b)
        else:
            if aN>=pStart:
                print (aN," ",a)

# %% [markdown]
# Tous les skips indiquent des problèmes de cohérence entre le texte ponctué des annotations syntaxiques et le texte du fichier tours avec les types de commentaires

# %% [raw]
# skips=[750,751,752,753,754,755,756,829,830,852,861,863,879,
#        1266,1580,1779,1783,2100,2190,2226,2227,2346,2358,2359,2360,2361,
#        2421,2422,2476,2478,2617,2618,2619,2998,
#        3114,3640,3753,3953,3954,4357,4478,4479,4481,4482,4483,
#        4522,4523,4528,4529,4530,4833,4936,
#        5154,5155,5156,5481,5482,5483,5484,5486,5487,5488,5489,5490,5491,
#        6381,6487,6488,6489,6771,6787,6788,6789,
#        7835,7880,8052,8053,8054,8128,8129,8130,8131,8132,8133,8134,8167,8168,8181,8276,8277,8278,8279,8280,8281,8282,8283,8284,8285,8286,8465,8543,8544,8583,8664,9049,9163,9444,9445,9446,9620,9685,9984,9997,
#        10381,10421,10422,10423,
#        10504,10505,10506,10507,10508,
#        10510,10511,10512,10513,10514,10515,
#        10516,10518,10519,10520,10521,
#        10522,10523,10524,10525,10526,
#        10527,10528,
#        10585,10586,10587,10588,10589,10590,
#        10729,10730,10731,10732,10733,10734,10735,10736,
#        10756,10757,
#        10923,10925,11835,
#        13046,13047,13958,13959,
#        14278,14279,
#        14645,
#        15103,15105,
#        16051,16052,
#        16298,
#        16387,16389,
#        16491,
#        16537,
#        16671,16672,16673,
#        16690,
#        16712,16714,
#        16770,16771,16772,16773,16774,16775,
#        16776,16777,16778,16779,16780,
#        17567,
#        17614,
#        17928,
#        17949,
#        18077,
#        18187,
#        18288,
#        18976,
#        18993,
#        19357,
#        19893]

# %%
alignAB(21942,10000)

# %%
skips=[1470,1471,1472,1473,
       1572,
       1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,
       1994,1995,1996,1997,1998,1999,
       2603,2604,2605,2606,2607,2608,2609,2610,2611,2612,2613,
       2802,2803,2804,2805,2806,2807,2808,
       3986,
       4186,4187,4188,4189,4190,4191,4192,
       4800,4801,
       5594,5595,5596,5597,5598,5599,5600,5601,5602,5603,5604,5605,
       5606,5607,5608,5609,5610,5611,5612,5613,5614,5615,
       5616,5617,5618,5619,5620,5621,5622,5623,5624,5625,
       5626,5627,5628,5629,
       5752,5753,5754,5755,5756,5757,5758,5759,5760,
       6294,6295,6296,
       8205,
       8791,8792,8793,8794,8795,8796,
       10296,
       10341,
       11559,
       13974,
       13978,
       17624,17625,17626,17627,17628,17629,17630,17631,17632,17633,
       17634,17635,17636,17637,17638,17639,17640,17641,17642,17643,
       17644,17645,17646,17647,17648,
       21280,
       21294]

# %%
def getSpeaker(row):
    return row["tour"].split("-")[-1]
    
if "FR-NZ-fr" in nFile:
    df["speaker"]=df.apply(getSpeaker,axis=1)
    df.to_excel(rep+"FrNz-RefSynTour.xlsx")

# %%
df

# %%
for i in range(17624,17649):
    print(i,end=",")

# %%
chaine="3210"
chaine[-2:]
