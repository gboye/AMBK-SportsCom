# %%
import pandas as pd
import numpy as np
import re

# %%
repChaines="/Users/gilles/pCloud Drive/FOD/GB/Copy/Recherche/Rugby/ChainesReferences/"
fChaines=repChaines+"FR-AR-fr.xlsx"
# fChaines=repChaines+"FR-NZ-en.xlsx"



dfBrut=pd.read_excel(fChaines, sheet_name="Sheet1")

# %%
colSelection=dfBrut.columns[:10]
print ", ".join(colSelection)
dfChaines=dfBrut[colSelection]
# Out:
# Transcription, Cat, Lemme, Modif, Referent, numChaineRef, numChaine, chaineIndex, chaineDep, MentionChaine

# %%
colSelection=dfBrut.columns[:10]
print ", ".join(colSelection)
dfChaines=dfBrut[colSelection]
dfChaines.head(50)
# Out:
#    Transcription       Cat     Lemme Modif Referent  numChaineRef  numChaine  \
# 0          après       PRP     après   NaN      NaN           NaN        NaN
# 1          avoir  VER:infi     avoir   NaN      NaN           NaN        NaN
# 2        demandé  VER:pper  demander   NaN      NaN           NaN        NaN
# 3             si       KON        si   NaN      NaN           NaN        NaN
# 4           tout   PRO:IND      tout   NaN      NaN           NaN        NaN
# 5             le   DET:ART        le   NaN      NaN           NaN        NaN
# 6          monde       NOM     monde   NaN      NaN           NaN        NaN
# 7          était  VER:impf      être   NaN      NaN           NaN        NaN
# 8           prêt       ADJ      prêt   NaN      NaN           NaN        NaN
# 9              ,       PUN         ,   NaN      NaN           NaN        NaN
# 10            le   DET:ART        le   NaN      NaN           NaN        NaN
# 11          coup       NOM      coup   NaN      NaN           NaN        NaN
# 12            d'       PRP        de   NaN      NaN           NaN        NaN
# 13         envoi       NOM     envoi   NaN      NaN           NaN        NaN
# 14            de       PRP        de   NaN      NaN           NaN        NaN
# 15            la   DET:ART        le   NaN      NaN           NaN        NaN
# 16         coupe       NOM     coupe   NaN      NaN           NaN        NaN
# 17            du   PRP:det        du   NaN      NaN           NaN        NaN
# 18         monde       NOM     monde   NaN      NaN           NaN        NaN
# 19          deux       NUM      deux   NaN      NaN           NaN        NaN
# 20         mille       NUM     mille   NaN      NaN           NaN        NaN
# 21          sept       NUM      sept   NaN      NaN           NaN        NaN
# 22           est  VER:pres      être   NaN      NaN           NaN        NaN
# 23         donné  VER:pper    donner   NaN      NaN           NaN        NaN
# 24           par       PRP       par   NaN      NaN           NaN        NaN
# 25         David       NAM     David   NaN    J-F10           1.0        1.0
# 26        Skrela       NAM    Skrela   NaN    J-F10           NaN        NaN
# 27             .      SENT         .   NaN      NaN           NaN        NaN
# 28         allez  VER:pres     aller   NaN      NaN           NaN        NaN
# 29            de       PRP        de   NaN      NaN           NaN        NaN
# 30         suite       NOM     suite   NaN      NaN           NaN        NaN
# 31          dans       PRP      dans   NaN      NaN           NaN        NaN
# 32            le   DET:ART        le   NaN      NaN           NaN        NaN
# 33          camp       NOM      camp   NaN      NaN           NaN        NaN
# 34           euh       INT       euh   NaN      NaN           NaN        NaN
# 35      argentin       ADJ  argentin   NaN      NaN           NaN        NaN
# 36             .      SENT         .   NaN      NaN           NaN        NaN
# 37          avec       PRP      avec   NaN      NaN           NaN        NaN
# 38            un   DET:ART        un   NaN      NaN           NaN        NaN
# 39        départ       NOM    départ   NaN      NaN           NaN        NaN
# 40            de       PRP        de   NaN      NaN           NaN        NaN
# 41       Roncero       NOM   Roncero   NaN     J-A1           1.0        2.0
# 42             .      SENT         .   NaN      NaN           NaN        NaN
# 43        Pichot       NAM    Pichot   NaN     J-A9           1.0        3.0
# 44             a  VER:pres     avoir   NaN      NaN           NaN        NaN
# 45        appelé  VER:pper   appeler   NaN      NaN           NaN        NaN
# 46            le   DET:ART        le   NaN      NaN           NaN        NaN
# 47        ballon       NOM    ballon   NaN      NaN           NaN        NaN
# 48             ,       PUN         ,   NaN      NaN           NaN        NaN
# 49          pour       PRP      pour   NaN      NaN           NaN        NaN
#
#     chaineIndex  chaineDep  MentionChaine
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# 5           NaN        NaN            NaN
# 6           NaN        NaN            NaN
# 7           NaN        NaN            NaN
# 8           NaN        NaN            NaN
# 9           NaN        NaN            NaN
# 10          NaN        NaN            NaN
# 11          NaN        NaN            NaN
# 12          NaN        NaN            NaN
# 13          NaN        NaN            NaN
# 14          NaN        NaN            NaN
# 15          NaN        NaN            NaN
# 16          NaN        NaN            NaN
# 17          NaN        NaN            NaN
# 18          NaN        NaN            NaN
# 19          NaN        NaN            NaN
# 20          NaN        NaN            NaN
# 21          NaN        NaN            NaN
# 22          NaN        NaN            NaN
# 23          NaN        NaN            NaN
# 24          NaN        NaN            NaN
# 25          1.0        0.0            1.0
# 26          1.0        0.0            NaN
# 27          NaN        NaN            NaN
# 28          NaN        NaN            NaN
# 29          NaN        NaN            NaN
# 30          NaN        NaN            NaN
# 31          NaN        NaN            NaN
# 32          NaN        NaN            NaN
# 33          NaN        NaN            NaN
# 34          NaN        NaN            NaN
# 35          NaN        NaN            NaN
# 36          NaN        NaN            NaN
# 37          NaN        NaN            NaN
# 38          NaN        NaN            NaN
# 39          NaN        NaN            NaN
# 40          NaN        NaN            NaN
# 41          1.0        0.0            1.0
# 42          NaN        NaN            NaN
# 43          1.0        0.0            1.0
# 44          NaN        NaN            NaN
# 45          NaN        NaN            NaN
# 46          NaN        NaN            NaN
# 47          NaN        NaN            NaN
# 48          NaN        NaN            NaN
# 49          NaN        NaN            NaN

# %% [markdown]
# ## Ajout de chaînes supplémentaires

# %%
numChainSupp=10001

def addChains(row):
    global numChainSupp
    if pd.notnull(row["Modif"]):
        modif=row["Modif"]
        if modif=="IND":
            row["numChaine"]=numChainSupp
            numChainSupp+=1
        m=re.match(ur"C\s*[+=]\s*((\w|-)+)",modif)
        if m:
            newRef=m.group(1)
            print newRef,modif
            row["Referent"]=newRef
        m=re.match(ur"(NC|NR)(.*)",modif)
        if m:
            mType=m.group(1)
            mModif=m.group(2)
            if mType=="NC" or mType=="NR":
                if pd.isna(row["numChaine"]) or row["numChaine"]<10000:
                    row["numChaine"]=numChainSupp
                    numChainSupp+=1
                if mModif:
                    mRef=re.match(ur"(=|\+)(.*)",mModif)
                    if mRef:
                        newRef=mRef.group(2)
                        row["Referent"]=newRef
    return row

# %%
dfChaines=dfChaines.apply(addChains,axis=1)
# Out:
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# J-F9 C=J-F9
# J-F9 C=J-F9
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# 462 C=462
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# J-F7 C=J-F7
# J-F4 C=J-F4
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# R C=R 798
# R C=R 805
# R C=R 805
# R C=R 806
# R C=R 806
# IND C=IND
# R C=R 835
# GPA C=GPA
# AA C=AA
# R C=R 832
# AA C=AA
# AA C=AA
# AA C=AA
# R C=R 832
# A C=A
# A C=A
# A C=A
# A C=A
# R C=R 20004
# A C=A
# A C=A
# A C=A
# A C=A
# J-A6 C=J-A6
# J-A6 C=J-A6
# J-A6 C=J-A6
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# IND C=IND
# J-A1 C=J-A1
# J-A1 C=J-A1
# J-A1 C=J-A1
# J-A5 C=J-A5
# IND C=IND
# IND C=IND
# J-F11 C=J-F11
# J-F11 C=J-F11
# IND C=IND
# 1046 C=1046+1047
# IND C=IND

# %%
dfChaines[dfChaines["numChaine"]>10000]
# Out:
#       Transcription      Cat     Lemme     Modif Referent  numChaineRef  \
# 233              on  PRO:PER        on       IND      NaN           NaN
# 274              on  PRO:PER        on       IND      NaN           NaN
# 289              on  PRO:PER        on       IND      NaN           NaN
# 439              on  PRO:PER        on       IND      GTF           NaN
# 443              se  PRO:PER        se       IND      NaN           NaN
# 445              on  PRO:PER        on       IND      GTF           NaN
# 486              se  PRO:PER        se       IND      NaN           NaN
# 565              on  PRO:PER        on       IND      GTF           2.0
# 570              on  PRO:PER        on       IND      GTF           NaN
# 641              on  PRO:PER        on       IND      NaN           NaN
# 646              on  PRO:PER        on       IND      NaN           NaN
# 654              on  PRO:PER        on       IND      NaN           NaN
# 666              s'  PRO:PER        se       IND      NaN           NaN
# 686              on  PRO:PER        on       IND      NaN           NaN
# 719             ils  PRO:PER        il       IND      GPA           NaN
# 722             ils  PRO:PER        il       IND      GPA           NaN
# 728            nous  PRO:PER      nous       IND      GTF           4.0
# 738              on  PRO:PER        on       IND      NaN           NaN
# 778              on  PRO:PER        on       IND      NaN           NaN
# 1009             on  PRO:PER        on       IND      NaN           NaN
# 1096             on  PRO:PER        on       IND      NaN           NaN
# 1171             on  PRO:PER        on       IND      GTF           NaN
# 1207             on  PRO:PER        on       IND      NaN           NaN
# 1415             on  PRO:PER        on       IND      NaN           NaN
# 1555         Pichot      NAM    Pichot        NC     J-A9           NaN
# 1625             on  PRO:PER        on       IND      NaN           NaN
# 1636             on  PRO:PER        on       IND      NaN           NaN
# 1699             on  PRO:PER        on       IND      NaN           NaN
# 1704             on  PRO:PER        on       IND      NaN           NaN
# 1708             on  PRO:PER        on       IND      NaN           NaN
# ...             ...      ...       ...       ...      ...           ...
# 17939          vous  PRO:PER      vous       IND      NaN           NaN
# 18043            on  PRO:PER        on       IND      NaN           NaN
# 18244            on  PRO:PER        on       IND      NaN           NaN
# 18245            se  PRO:PER        se       IND      NaN           NaN
# 18254            on  PRO:PER        on       IND      NaN           NaN
# 18308            on  PRO:PER        on       IND      NaN           NaN
# 18311            on  PRO:PER        on       IND      NaN           NaN
# 18320            on  PRO:PER        on       IND      NaN           NaN
# 18435           ils  PRO:PER        il       IND      GPF           NaN
# 18446      Dominici      NAM  Dominici  NM J-F11    J-F11           NaN
# 18582            on  PRO:PER        on       IND      NaN           NaN
# 18614          nous  PRO:PER      nous       IND      GTF          97.0
# 18619          nous  PRO:PER      nous       IND      GTF           NaN
# 18631          vous  PRO:PER      vous       IND      NaN           NaN
# 18661            on  PRO:PER        on       IND      NaN           NaN
# 19034            on  PRO:PER        on       IND      NaN           NaN
# 19083            on  PRO:PER        on       IND      NaN           NaN
# 19092            on  PRO:PER        on       IND      NaN           NaN
# 19133          vous  PRO:PER      vous       IND      NaN           NaN
# 19177          nous  PRO:PER      nous       IND      GTF         104.0
# 19178            on  PRO:PER        on       IND      GTF           NaN
# 19218          nous  PRO:PER      nous       IND      NaN           NaN
# 19246          Jean      NAM      Jean     NM=JD      NaN           NaN
# 19376            on  PRO:PER        on       IND      NaN           NaN
# 19862           aux  PRP:det        au    NM GTA      GTA          97.0
# 19950            on  PRO:PER        on       IND      NaN           NaN
# 19978            on  PRO:PER        on       IND      NaN           NaN
# 20079            on  PRO:PER        on       IND      NaN           NaN
# 20096          vous  PRO:PER      vous       IND      NaN           NaN
# 20147            on  PRO:PER        on       IND      NaN           NaN
#
#        numChaine  chaineIndex  chaineDep  MentionChaine
# 233      10001.0          NaN        NaN            NaN
# 274      10002.0          NaN        NaN            NaN
# 289      10003.0          NaN        NaN            NaN
# 439      10004.0          2.0        1.0            NaN
# 443      10005.0          NaN        NaN            NaN
# 445      10006.0          3.0        2.0            NaN
# 486      10007.0          NaN        NaN            NaN
# 565      10008.0          1.0        0.0            2.0
# 570      10009.0          2.0        1.0            NaN
# 641      10010.0          NaN        NaN            NaN
# 646      10011.0          NaN        NaN            NaN
# 654      10012.0          NaN        NaN            NaN
# 666      10013.0          NaN        NaN            NaN
# 686      10014.0          NaN        NaN            NaN
# 719      10015.0          2.0        1.0            NaN
# 722      10016.0          3.0        2.0            NaN
# 728      10017.0          1.0        0.0            1.0
# 738      10018.0          NaN        NaN            NaN
# 778      10019.0          NaN        NaN            NaN
# 1009     10020.0          NaN        NaN            NaN
# 1096     10021.0          NaN        NaN            NaN
# 1171     10022.0          2.0        1.0            NaN
# 1207     10023.0          NaN        NaN            NaN
# 1415     10024.0          NaN        NaN            NaN
# 1555     10025.0          1.0        0.0            2.0
# 1625     10026.0          NaN        NaN            NaN
# 1636     10027.0          NaN        NaN            NaN
# 1699     10028.0          NaN        NaN            NaN
# 1704     10029.0          NaN        NaN            NaN
# 1708     10030.0          NaN        NaN            NaN
# ...          ...          ...        ...            ...
# 17939    10244.0          NaN        NaN            NaN
# 18043    10245.0          NaN        NaN            NaN
# 18244    10246.0          NaN        NaN            NaN
# 18245    10247.0          NaN        NaN            NaN
# 18254    10248.0          NaN        NaN            NaN
# 18308    10249.0          NaN        NaN            NaN
# 18311    10250.0          NaN        NaN            NaN
# 18320    10251.0          NaN        NaN            NaN
# 18435    10252.0          2.0        1.0            NaN
# 18446    20010.0          1.0        0.0            2.0
# 18582    10253.0          NaN        NaN            NaN
# 18614    10254.0          1.0        0.0            2.0
# 18619    10255.0          2.0        1.0            NaN
# 18631    10256.0          NaN        NaN            NaN
# 18661    10257.0          NaN        NaN            NaN
# 19034    10258.0          NaN        NaN            NaN
# 19083    10259.0          NaN        NaN            NaN
# 19092    10260.0          NaN        NaN            NaN
# 19133    10261.0          NaN        NaN            NaN
# 19177    10262.0          1.0        0.0            2.0
# 19178    10263.0          2.0        1.0            NaN
# 19218    10264.0          NaN        NaN            NaN
# 19246    20011.0          1.0        0.0            NaN
# 19376    10265.0          NaN        NaN            NaN
# 19862    20012.0          1.0        0.0            NaN
# 19950    10266.0          NaN        NaN            NaN
# 19978    10267.0          NaN        NaN            NaN
# 20079    10268.0          NaN        NaN            NaN
# 20096    10269.0          NaN        NaN            NaN
# 20147    10270.0          NaN        NaN            NaN
#
# [284 rows x 10 columns]

# %%
# colonne pour appositions
dfChaines["chaineApp"]=pd.np.nan
# oldX
dfChaines["oldReferent"]=dfChaines.Referent
dfChaines["oldNumChaine"]=dfChaines.numChaine.astype("Int64")
dfChaines["oldChaineIndex"]=dfChaines.chaineIndex#.astype("Int64")
dfChaines["oldChaineDep"]=dfChaines.chaineDep.astype("Int64")

# %%
# RAZ colonnes à modifier
dfChaines["numChaine"]=pd.np.nan
dfChaines["chaineIndex"]=pd.np.nan
dfChaines["chaineDep"]=pd.np.nan

# %%
dfChaines[dfChaines["numChaine"]>1000]
# Out:
#         Modif  Referent  newNumChaine  newChaineIndex  newChaineDep  \
# 233       IND       NaN           NaN             NaN           NaN
# 274       IND       NaN           NaN             NaN           NaN
# 289       IND       NaN           NaN             NaN           NaN
# 439       IND       GTF           NaN             NaN           NaN
# 443       IND       NaN           NaN             NaN           NaN
# 445       IND       GTF           NaN             NaN           NaN
# 486       IND       NaN           NaN             NaN           NaN
# 565       IND       GTF           NaN             NaN           NaN
# 570       IND       GTF           NaN             NaN           NaN
# 641       IND       NaN           NaN             NaN           NaN
# 646       IND       NaN           NaN             NaN           NaN
# 654       IND       NaN           NaN             NaN           NaN
# 666       IND       NaN           NaN             NaN           NaN
# 686       IND       NaN           NaN             NaN           NaN
# 719       IND       GPA           NaN             NaN           NaN
# 722       IND       GPA           NaN             NaN           NaN
# 728       IND       GTF           NaN             NaN           NaN
# 738       IND       NaN           NaN             NaN           NaN
# 778       IND       NaN           NaN             NaN           NaN
# 1009      IND       NaN           NaN             NaN           NaN
# 1096      IND       NaN           NaN             NaN           NaN
# 1171      IND       GTF           NaN             NaN           NaN
# 1207      IND       NaN           NaN             NaN           NaN
# 1415      IND       NaN           NaN             NaN           NaN
# 1555       NC      J-A9           NaN             NaN           NaN
# 1625      IND       NaN           NaN             NaN           NaN
# 1636      IND       NaN           NaN             NaN           NaN
# 1699      IND       NaN           NaN             NaN           NaN
# 1704      IND       NaN           NaN             NaN           NaN
# 1708      IND       NaN           NaN             NaN           NaN
# ...       ...       ...           ...             ...           ...
# 19457     NaN      J-A1           NaN             NaN           NaN
# 19465     NaN     J-A22           NaN             NaN           NaN
# 19468     NaN     J-A19           NaN             NaN           NaN
# 19473       D       GPA           NaN             NaN           NaN
# 19479     NaN     J-F21           NaN             NaN           NaN
# 19494     NaN        MS           NaN             NaN           NaN
# 19505     NaN       GTF           NaN             NaN           NaN
# 19517     NaN       GTA           NaN             NaN           NaN
# 19642     NaN   thierry           NaN             NaN           NaN
# 19669     NaN       GTF           NaN             NaN           NaN
# 19672     NaN       GTA           NaN             NaN           NaN
# 19768     NaN       GTF           NaN             NaN           NaN
# 19824     NaN      J-A9           NaN             NaN           NaN
# 19860     NaN      J-A9           NaN             NaN           NaN
# 19862  NM GTA       GTA           NaN             NaN           NaN
# 19923     NaN       GTF           NaN             NaN           NaN
# 19938     NaN      J-A9           NaN             NaN           NaN
# 19950     IND       NaN           NaN             NaN           NaN
# 19978     IND       NaN           NaN             NaN           NaN
# 19992       D     J-A10           NaN             NaN           NaN
# 19997       D     J-F13           NaN             NaN           NaN
# 20009     NaN      J-F6           NaN             NaN           NaN
# 20023     NaN  J-A12/13           NaN             NaN           NaN
# 20026     NaN     J-A15           NaN             NaN           NaN
# 20079     IND       NaN           NaN             NaN           NaN
# 20087     NaN       GTF           NaN             NaN           NaN
# 20088     NaN       GTA           NaN             NaN           NaN
# 20096     IND       NaN           NaN             NaN           NaN
# 20147     IND       NaN           NaN             NaN           NaN
# 20184     NaN   thierry           NaN             NaN           NaN
#
#        newChaineApp  numChaineRef  numChaine  chaineIndex  chaineDep  \
# 233             NaN           NaN      10001          NaN        NaN
# 274             NaN           NaN      10002          NaN        NaN
# 289             NaN           NaN      10003          NaN        NaN
# 439             NaN           NaN      10004          2.0          1
# 443             NaN           NaN      10005          NaN        NaN
# 445             NaN           NaN      10006          3.0          2
# 486             NaN           NaN      10007          NaN        NaN
# 565             NaN           2.0      10008          1.0          0
# 570             NaN           NaN      10009          2.0          1
# 641             NaN           NaN      10010          NaN        NaN
# 646             NaN           NaN      10011          NaN        NaN
# 654             NaN           NaN      10012          NaN        NaN
# 666             NaN           NaN      10013          NaN        NaN
# 686             NaN           NaN      10014          NaN        NaN
# 719             NaN           NaN      10015          2.0          1
# 722             NaN           NaN      10016          3.0          2
# 728             NaN           4.0      10017          1.0          0
# 738             NaN           NaN      10018          NaN        NaN
# 778             NaN           NaN      10019          NaN        NaN
# 1009            NaN           NaN      10020          NaN        NaN
# 1096            NaN           NaN      10021          NaN        NaN
# 1171            NaN           NaN      10022          2.0          1
# 1207            NaN           NaN      10023          NaN        NaN
# 1415            NaN           NaN      10024          NaN        NaN
# 1555            NaN           NaN      10025          1.0          0
# 1625            NaN           NaN      10026          NaN        NaN
# 1636            NaN           NaN      10027          NaN        NaN
# 1699            NaN           NaN      10028          NaN        NaN
# 1704            NaN           NaN      10029          NaN        NaN
# 1708            NaN           NaN      10030          NaN        NaN
# ...             ...           ...        ...          ...        ...
# 19457           NaN          11.0       1065          1.0          0
# 19465           NaN           2.0       1066          1.0          0
# 19468           NaN           4.0       1067          1.0          0
# 19473           NaN          35.0       1068          1.0          1
# 19479           NaN          18.0       1069          1.0          0
# 19494           NaN          23.0       1070          1.0          0
# 19505           NaN         106.0       1071          1.0          0
# 19517           NaN          95.0       1072          1.0          0
# 19642           NaN          46.0       1073          1.0          0
# 19669           NaN         107.0       1074          1.0          0
# 19672           NaN          96.0       1075          1.0          0
# 19768           NaN         108.0       1076          1.0          0
# 19824           NaN          43.0       1077          1.0          0
# 19860           NaN          44.0       1078          1.0          0
# 19862           NaN          97.0      20012          1.0          0
# 19923           NaN         109.0       1079          1.0          0
# 19938           NaN          45.0       1080          1.0          3
# 19950           NaN           NaN      10266          NaN        NaN
# 19978           NaN           NaN      10267          NaN        NaN
# 19992           NaN          42.0       1081          1.0          0
# 19997           NaN          28.0       1082          1.0          0
# 20009           NaN          32.0       1083          1.0          0
# 20023           NaN          26.0       1084          1.0          0
# 20026           NaN          17.0       1085          1.0          0
# 20079           NaN           NaN      10268          NaN        NaN
# 20087           NaN         110.0       1086          1.0          0
# 20088           NaN          97.0       1087          1.0          0
# 20096           NaN           NaN      10269          NaN        NaN
# 20147           NaN           NaN      10270          NaN        NaN
# 20184           NaN          47.0       1088          1.0          0
#
#        MentionChaine Transcription      Cat      Lemme
# 233              NaN            on  PRO:PER         on
# 274              NaN            on  PRO:PER         on
# 289              NaN            on  PRO:PER         on
# 439              NaN            on  PRO:PER         on
# 443              NaN            se  PRO:PER         se
# 445              NaN            on  PRO:PER         on
# 486              NaN            se  PRO:PER         se
# 565                2            on  PRO:PER         on
# 570              NaN            on  PRO:PER         on
# 641              NaN            on  PRO:PER         on
# 646              NaN            on  PRO:PER         on
# 654              NaN            on  PRO:PER         on
# 666              NaN            s'  PRO:PER         se
# 686              NaN            on  PRO:PER         on
# 719              NaN           ils  PRO:PER         il
# 722              NaN           ils  PRO:PER         il
# 728                1          nous  PRO:PER       nous
# 738              NaN            on  PRO:PER         on
# 778              NaN            on  PRO:PER         on
# 1009             NaN            on  PRO:PER         on
# 1096             NaN            on  PRO:PER         on
# 1171             NaN            on  PRO:PER         on
# 1207             NaN            on  PRO:PER         on
# 1415             NaN            on  PRO:PER         on
# 1555               2        Pichot      NAM     Pichot
# 1625             NaN            on  PRO:PER         on
# 1636             NaN            on  PRO:PER         on
# 1699             NaN            on  PRO:PER         on
# 1704             NaN            on  PRO:PER         on
# 1708             NaN            on  PRO:PER         on
# ...              ...           ...      ...        ...
# 19457              2       Roncero      NOM    Roncero
# 19465              1            le  DET:ART         le
# 19468              1            le  DET:ART         le
# 19473              2           des  PRP:det         du
# 19479              1     Elissalde      NOM  Elissalde
# 19494              2      Monsieur      NAM   Monsieur
# 19505              2            l'  DET:ART         le
# 19517              1            l'  DET:ART         le
# 19642              1       Thierry      NAM    Thierry
# 19669              2            la  DET:ART         le
# 19672              2            l'  DET:ART         le
# 19768              2            la  DET:ART         le
# 19824              2       Agustin      NAM    Agustin
# 19860              1        Pichot      NAM     Pichot
# 19862            NaN           aux  PRP:det         au
# 19923              1            la  DET:ART         le
# 19938              2            il  PRO:PER         il
# 19950            NaN            on  PRO:PER         on
# 19978            NaN            on  PRO:PER         on
# 19992              1            la  DET:ART         le
# 19997              2            la  DET:ART         le
# 20009              1        Martin      NAM     Martin
# 20023              1     Contepomi      NAM  Contepomi
# 20026              2      Corletto      NAM   Corletto
# 20079            NaN            on  PRO:PER         on
# 20087              1        France      NAM     France
# 20088              1     Argentine      ADJ   argentin
# 20096            NaN          vous  PRO:PER       vous
# 20147            NaN            on  PRO:PER         on
# 20184              1       Thierry      NAM    Thierry
#
# [370 rows x 14 columns]

# %% [markdown]
# ## Traitement des modifications de chaînes

# %% [markdown]
# - ajouter les nouvelles chaines avant de propager

# %%
dfChaines.oldNumChaine=dfChaines[dfChaines.Referent.notnull()].oldNumChaine.ffill()

# %%
def updateRows(row):
    numChaine=np.NaN
    chaineIndex=np.NaN
    chaineDep=np.NaN
    idx=row.index
    if pd.isna(row["Modif"]):
        row["numChaine"]=row["oldNumChaine"]
        row["chaineIndex"]=row["oldChaineIndex"]
        row["chaineDep"]=row["oldChaineDep"]
    else:
        modif=row["Modif"]
        print modif, row["numChaine"]
        m=re.match(ur"R\s*\+\s*(\d+)\s*",modif)
        if row["Modif"]=="A":
            row["numChaine"]=np.NaN
            row["chaineApp"]=row["oldNumChaine"]
        elif row["Modif"]=="D":
            row["Referent"]=np.NaN
        elif row["Modif"]=="IND":
            if pd.isna(row["Referent"]) or row["Referent"]=="IND":
                oldRef=""
            else:
                oldRef=" "+str(row["Referent"])
            row["Referent"]="IND"+oldRef
            row["newNumChaine"]=row["numChaine"]
        elif m:
            row["newNumChaine"]=int(m.group(1))            
            row["newChaineIndex"]=row["chaineIndex"]
            row["newChaineDep"]=row["chaineDep"]
            if pd.isna(row["Referent"]):
                row["Referent"]="REPORT"
        else:
            row["numChaine"]=row["oldNumChaine"]
            row["chaineIndex"]=row["oldChaineIndex"]
            row["chaineDep"]=row["oldChaineDep"]            
    return row

# %%
dfResult=dfChaines.apply(updateRows,axis=1)
# Out:
# A 7
# A 7
# A 7
# A 7
# A 7
# A 7
# A 7
# D 15
# D 15
# D 15
# D 15
# D 15
# D 15
# D 15
# IND nan
# IND nan
# D 17
# D 17
# D 17
# D 17
# IND nan
# A 18
# A 18
# A 18
# A 18
# IND 10004
# IND nan
# IND 10006
# D 30
# D 30
# D 30
# D nan
# D 30
# D 30
# D nan
# D 30
# IND nan
# D 32
# IND 10008
# IND 10009
# D 37
# D 37
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# D 46
# D 46
# IND 10015
# IND 10016
# IND 10017
# IND nan
# IND nan
# D 50
# R+50 nan
# A 52
# A 52
# A 52
# A 52
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# A 60
# IND nan
# R62 nan
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# A 64
# IND nan
# D 71
# D 71
# IND 10022
# IND nan
# R 78
# R 78
# R 78
# R 78
# R 78
# R 78
# R 78
# R 78
# R 78
# IND nan
# D 88
# D 88
# D 97
# NC 10025
# R 97 nan
# IND nan
# IND nan
# A 102
# A 102
# A 102
# IND nan
# IND nan
# IND nan
# IND nan
# R 108 nan
# R 108 nan
# D 111
# D 111
# D 111
# D 111
# IND nan
# IND nan
# IND nan
# IND nan
# D 129
# D 129
# D 129
# D 129
# R 132 132
# IND nan
# IND nan
# IND nan
# IND nan
# R 132 135
# R 132 136
# IND nan
# R 137 138
# D 139
# D 139
# D 139
# IND nan
# R 142+143 143
# D 146
# D 146
# D 146
# D 146
# D 146
# C=IND 159
# IND nan
# IND nan
# R  163 163
# D 165
# IND nan
# D 166
# D 166
# R 165 166
# R 165 166
# R 165 166
# IND nan
# R 174 175
# R 174 175
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# D 183
# D 183
# D 183
# D 183
# D 183
# IND nan
# D 183
# D 183
# D 183
# D 184
# D 184
# D 184
# D 184
# D 184
# D 185
# D 185
# D 185
# D 188
# D nan
# D 188
# D nan
# D 190
# D 190
# D 190
# D 192
# D 192
# A 192
# A 192
# A 192
# IND nan
# IND nan
# IND nan
# D 198
# D 198
# D 198
# D 199
# D 199
# D 199
# D 200
# D 200
# D 200
# A 201
# A 201
# A 201
# R 201 202
# R 202 202
# R 201 202
# R 202 202
# D 204
# D 204
# D 204
# D 208
# D 208
# D 208
# D 208
# D 208
# D 208
# D 208
# D 208
# D 216
# D 216
# D 216
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND 10068
# C=IND 10068
# C=IND 10068
# C=IND 10068
# C=IND 10068
# NC 20001
# D 232
# D 232
# D 232
# IND nan
# IND nan
# D 237
# C=IND 238
# C=IND 238
# C=IND 239
# C=IND 239
# D 243
# D 243
# D 243
# IND nan
# C=IND 245
# IND nan
# R 246 247
# R 246 247
# C=IND 260
# C=IND 260
# C=IND 260
# C=IND 260
# C=IND 262
# C=IND 262
# C=IND 262
# C=IND 262
# C=IND 262
# C=IND 262
# C=IND 262
# C=IND 262
# IND nan
# C=IND 262
# R 263 264
# J-F1 + J-A3 nan
# R 268+269 269
# R 268+269 269
# R 268+269 269
# IND nan
# C=J-F9 277
# C=J-F9 277
# IND nan
# A 278
# A 278
# R 278+279 279
# R 278+279 279
# R 278+279 279
# IND nan
# IND nan
# D 282
# D 282
# D 282
# D 282
# D 282
# IND nan
# D 284
# D 284
# D 284
# IND nan
# R 286 287
# R 286 nan
# C=IND 288
# IND nan
# C=IND 288
# C=IND 288
# IND nan
# IND nan
# IND nan
# A 291
# A 291
# R 296 296
# D 298
# D 298
# IND nan
# IND nan
# C=IND 304
# C=IND 304
# IND nan
# IND nan
# IND nan
# C=IND 305
# C=IND 308
# C=IND 308
# C=IND 308
# R 308 308
# C=IND 320
# C=IND 320
# C=IND 320
# C=IND 320
# IND nan
# R 321 321
# IND nan
# C=IND 323
# C=IND 323
# IND nan
# C=IND 323
# C=IND 323
# C=IND 323
# C=IND 323
# C=IND 323
# C=IND 323
# C=IND 323
# R GTA 325 326
# R GTA 325 326
# IND nan
#  A 331+332 330
#  A 331+332 330
#  A 331+332 330
# IND nan
# IND nan
# IND nan
# D 351
# D 351
# D 351
# R 351 351
# IND nan
# IND nan
# IND nan
# IND nan
# D 353
# C=IND 355
# IND nan
# IND nan
# C=IND 355
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# C=IND 356
# IND nan
# IND nan
# C=IND 356
# A 359
# A 359
# A 359
# A 359
# C=IND 360
# R GTF  nan
# C=IND 366
# R 372 372
# C=IND 384
# C=IND 384
# IND nan
# C=IND 385
# R 385 385
# R 385 385
# C=IND 385
# C=IND 385
# IND nan
# C=IND 388
# C=IND 388
# C=IND 388
# D 389
# D 389
# D 389
# IND nan
# IND nan
# D 393
# D 393
# D 393
# D 393
# D 393
# A 393
# A 393
# R 393 393
# D 396
# D 396
# D 396
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# R 401 402
# D 408
# D 408
# D 408
# C=IND 409
# C=IND 411
# C=IND 412
# D 420
# C=IND 426
# C=IND 426
# C=IND 427
# R 427 427
# R 430 430
# R J-F13 431 432
# R J-F13 431 432
# R J-F13 431 432
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# C=IND 455
# C=IND 455
# IND nan
# C=IND 455
# C=IND 455
# C=IND 455
# C=IND 455
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# R 456 459
# R 456 459
# IND nan
# C=462 461
# R 464 465
# R 464 465
# D 466
# R 464 466
# IND nan
# IND nan
# IND nan
# C=IND 472
# C=IND 472
# IND nan
# R 481 481
# R 481 481
# C=IND 482
# R 482 482
# R 482 482
# D 484
# D 484
# D 484
# C=IND 484
# D 488
# D 489
# D 489
# NM 20001
# NC 20002
# NC 10135
# IND nan
# A 10135
# A 10135
# A 10135
# C=IND 490
# C=IND 491
# C=IND 491
# C=IND 491
# D 492
# D 492
# D 492
# D 492
# C=IND 492
# C=IND 492
# C=IND 494
# C=IND 494
# C=IND 494
# C=IND 497
# C=IND 497
# C=IND 497
# R 498 500
# IND nan
# D 503
# D 503
# D 503
# C=IND 505
# IND nan
# C=IND 505
# C=IND 505
# D 508
# D 508
# D 508
# D 508
# R 507 509
# C=IND 509
# IND nan
# D 511
# D 511
# D 511
# A 514
# A 514
# A 514
# A 514
# A 514
# A 514
# A 514
# A 514
# A 514
# A 514
# D 518
# D 518
# D 518
# D 518
# D 518
# D 518
# IND nan
# C=IND 520
# C=IND 520
# C=IND 520
# C=IND 520
# IND nan
# IND nan
# A 523
# A 523
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# C=IND 529
# IND nan
# R 529 530
# C=IND 530
# C=IND 530
# C=IND 530
# IND nan
# C=IND 530
# C=IND 530
# C=IND 530
# IND nan
# C=IND 530
# C=IND 530
# C=IND 530
# C=IND 530
# IND nan
# IND nan
# C=IND 537
# R 537 538
# R 537 nan
# D 539
# D 539
# IND nan
# IND nan
# IND nan
# C=IND 540
# IND nan
# C=IND 544
# IND nan
# D 546
# D 546
# D 546
# D 551
# D 551
# D 551
# D 561
# D 561
# C=IND 565
# C=IND 566
# C=IND 566
# C=IND 566
# IND nan
# D 567
# C=IND 569
# D 570
# D 570
# IND nan
# IND nan
# D 572
# D 572
# D 572
# A 574
# A 574
# A 576
# A 576
# A 576
# A 576
# A 576
# A 577
# A 577
# D 582
# D 582
# D 582
# D 583
# D 583
# D 583
# D 584
# D 584
# C=IND 585
# C=IND 585
# C=IND 585
# R 597 598
# IND nan
# IND nan
# IND nan
# R 597 601
# IND nan
# D 603
# D 603
# D 604
# D 604
# IND nan
# IND nan
# D 617
# D 617
# D 617
# D 617
# D 617
# D 617
# D 617
# D 617
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# D 622
# D 622
# D 622
# D 622
# C=IND 623
# C=IND 623
# C=IND 623
# A 625
# A 625
# A 625
# A 625
# R J-F11 624 625
# A 626
# A 626
# A 626
# D 627
# D 627
# D 627
# IND nan
# IND nan
# D 638
# D 638
# A 641
# A 641
# A 641
# A 641
# D 642
# D 642
# D 642
# A 642
# A 642
# A 642
# A 642
# A 642
# IND nan
# D 653
# D 653
# IND nan
# IND nan
# D 666
# IND nan
# IND nan
# C=IND 666
# C=IND 666
# C=IND 666
# C=IND 666
# IND nan
# IND nan
# R 668 668
# D 670
# D 670
# D 670
# D 670
# D 671
# D 671
# D 672
# D 672
# D 673
# D 673
# D 674
# D 674
# D 677
# D 677
# R 678 678
# IND nan
# C=IND 682
# C=IND 682
# C=IND 682
# C=IND 683
# C=IND 683
# C=IND 683
# IND nan
# IND nan
# NC 20003
# C=IND 684
# D 688
# D 688
# D 690
# D 690
# D 690
# D 692
# D 692
# D 692
# IND nan
# C=IND 695
# C=J-F7 698
# J-F7 + J-F4 698
# J-F7 + J-F4 698
# C=J-F4 698
# R 698 698
# R 714 713
# C=IND 718
# C=IND 718
# C=IND 718
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# D 723
# R 728 728
# D 729
# D 729
# D 729
# D 730
# D 730
# D 730
# IND nan
# IND nan
# IND nan
# C=IND 734
# IND nan
# D 737
# D 738
# D 738
# D 738
# D 738
# D 738
# IND nan
# R 742 743
# IND nan
# A nan
# A nan
# A nan
# A nan
# A nan
# IND nan
# IND nan
# R 754 754
# R 754 754
# D 756
# D 756
# IND nan
# IND nan
# IND nan
# C=IND 759
# C=IND 759
# C=IND 760
# D 761
# D 761
# D 761
# D 763
# D 763
# D 763
# D 764
# D 770
# D 770
# D 770
# D 770
# D 770
# D 770
# D 770
# D 770
# C=IND 773
# IND nan
# C=IND 776
# C=IND 785
# R 786 787
# R 787 788
# D 794
# D 794
# D 794
# R  797 797
# D 798
# D 798
# D 798
# R 798 799
# C=R 798 799
# D 801
# D 801
# D 801
# IND nan
# IND nan
# R 802 nan
# R 802 803
# D 804
# D 804
# C=R 805 804
# C=R 805 804
# D 804
# C=R 806 804
# C=R 806 804
# R 807 809
# D 809
# R 807 810
# IND nan
# IND nan
# IND nan
# IND nan
# R 816 816
# A 818
# A 818
# R 818 818
# D 825
# D 825
# D 825
# D 831
# D 831
# D 831
# R 830 831
# C=IND 833
# C=R 835 834
# C=GPA 835
# C=AA 835
# C=R 832 836
# C=AA 836
# C=AA 836
# C=AA 836
# C=R 832 836
# R 832 nan
# NC 20004
# C=A 20004
# C=A 20004
# C=A 20004
# C=A 20004
# R 20004 nan
# C=R 20004 837
# R 837 837
# R 837 837
# R 841 842
# IND nan
# IND nan
# C=A 846
# C=A 846
# C=A 846
# C=A 846
# R 844 846
# R 844 846
# J-A22 nan
# IND nan
# IND nan
# D 865
# D 865
# D 865
# IND nan
# R 867 867
# R866 867
# IND nan
# IND nan
# D 877
# D 877
# D 877
# D 877
# D 877
# D 877
# R 879 879
# NC 20005
# IND nan
# IND nan
# C=J-A6 887
# C=J-A6 887
# C=J-A6 887
# NM 20006
# R 20006 893
# R 20006 893
# IND nan
# R 901 901
# R 902 903
# IND nan
# D 907
# D 907
# IND nan
# IND nan
# D 909
# D 909
# IND nan
# IND nan
# IND nan
# NM MD 20007
# NM ML 20008
# IND nan
# IND nan
# IND nan
# R 918 919
# R 918 919
# IND nan
# R 920 920
# R 920 921
# IND nan
# IND nan
# C=IND 924
# IND nan
# C=IND 924
# C=IND 924
# IND nan
# C=IND 929
# C=IND 929
# D 930
# D 930
# IND nan
# IND nan
# D 936
# D 936
# D 936
# IND nan
# C=IND 941
# C=IND 942
# IND nan
# C=IND 942
# C=IND 942
# C=IND 944
# NC nan
# NM nan
# NM nan
# C=IND 945
# C=IND 945
# C=IND 945
# C=IND 951
# C=IND 952
# C=IND 952
# C=IND 952
# C=IND 952
# C=IND 953
# R 964 964
# IND nan
# R 968 969
# IND nan
# IND nan
# R 979 979
# D 980
# D 980
# D 980
# D 980
# D 980
# D 980
# C=J-A1 980
# C=J-A1 980
# C=J-A1 980
# C=J-A5 980
# IND nan
# IND nan
# IND nan
# D 984
# D 984
# D 984
# D 984
# IND nan
# C=IND 992
# C=IND 992
# A 1000
# A 1000
# A 1000
# R 1000 1001
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# IND nan
# D 1009
# D 1015
# D 1015
# IND 10252
# NM J-F11 20010
# C=J-F11 20010
# C=J-F11 20010
# C=IND 1020
# R 1021 1022
# R 1021 1022
# R 1021 1022
# R 1021 1022
# R 1021 1022
# IND nan
# R 1021 1022
# R 1021 1022
# R 1021 1022
# IND 10254
# IND 10255
# IND nan
# IND nan
# D 1029
# D 1029
# D 1029
# D 1030
# D 1030
# D 1030
# D 1030
# R 1030 1030
# IND nan
# IND nan
# IND nan
# IND nan
# C=1046+1047 1048
# IND 10262
# IND 10263
# IND nan
# NM=JD nan
# NM=JD nan
# IND nan
# C=IND 1058
# D 1068
# D 1068
# NM GTA 20012
# NM GTA 20012
# R 20012 20012
# R 20012 20012
# R 20012 20012
# R 20012 20012
# IND nan
# IND nan
# D 1081
# D 1081
# D 1081
# D 1082
# D 1082
# D 1082
# D 1082
# D 1085
# D 1085
# D 1085
# IND nan
# IND nan
# IND nan

# %%
dfResult.to_excel(fChaines.replace(".xls","-GB.xls"),index=None)
